# %% [markdown]
# # SimpleTMG all rest

# %%
# !pip install PyWavelets gdown --quiet
import os
import json
import shutil
import subprocess
import pandas as pd
import torch

print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
# Out:
# PyTorch version: 2.10.0+cu128
# CUDA available: True
# GPU: Tesla T4

# %%
# REPO_URL = "https://github.com/agamswami/SimpleTMG.git"
REPO_URL = "https://github.com/agamswami/simpleTM-show.git"

REPO_DIR = "/kaggle/working/SimpleTM"

if not os.path.exists(REPO_DIR):
    # !git clone {REPO_URL} {REPO_DIR}

os.chdir(REPO_DIR)
print(f"Working directory: {os.getcwd()}")
# !sed -i 's/np\.Inf/np.inf/g' utils/tools.py
# Out:
# Cloning into '/kaggle/working/SimpleTM'...
# remote: Enumerating objects: 245, done.
# remote: Counting objects: 100% (245/245), done.
# remote: Compressing objects: 100% (138/138), done.
# remote: Total 245 (delta 115), reused 220 (delta 90), pack-reused 0 (from 0)
# Receiving objects: 100% (245/245), 25.93 MiB | 35.93 MiB/s, done.
# Resolving deltas: 100% (115/115), done.
# Working directory: /kaggle/working/SimpleTM

# %%
FILE_ID = "1JOgmL2ntyxKg6eB132ytCbVZumiHnDLR"
OUTPUT_PATH = "/kaggle/working/dataset.zip"
DATASET_DIR = "./dataset"

if not os.path.exists(DATASET_DIR):
    # !gdown https://drive.google.com/uc?id={FILE_ID} -O {OUTPUT_PATH}
    import zipfile
    os.makedirs(DATASET_DIR, exist_ok=True)
    with zipfile.ZipFile(OUTPUT_PATH, 'r') as zip_ref:
        zip_ref.extractall(DATASET_DIR)
    print("Dataset extracted successfully.")
else:
    print("Dataset already exists.")

for root, dirs, files in os.walk(DATASET_DIR):
    level = root.replace(DATASET_DIR, '').count(os.sep)
    indent = ' ' * 2 * level
    print(f'{indent}{os.path.basename(root)}/')
    subindent = ' ' * 2 * (level + 1)
    for file in files[:10]:
        print(f'{subindent}{file}')
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1JOgmL2ntyxKg6eB132ytCbVZumiHnDLR
# From (redirected): https://drive.google.com/uc?id=1JOgmL2ntyxKg6eB132ytCbVZumiHnDLR&confirm=t&uuid=b42f9c79-7eba-4bde-a691-c01429e9d886
# To: /kaggle/working/dataset.zip
# 100%|████████████████████████████████████████| 172M/172M [00:01<00:00, 98.0MB/s]
# Dataset extracted successfully.
# dataset/
#   __MACOSX/
#     ._SimpleTM_datasets
#     SimpleTM_datasets/
#       ._.DS_Store
#       ._PEMS
#       ._electricity
#       ._weather
#       ._ETT-small
#       ._traffic
#       ._Solar
#       traffic/
#         ._.DS_Store
#         ._traffic.csv
#       electricity/
#         ._.DS_Store
#         ._electricity.csv
#       Solar/
#         ._solar_AL.txt
#       ETT-small/
#         ._ETTm1.csv
#         ._ETTm2.csv
#         ._ETTh2.csv
#         ._ETTh1.csv
#       weather/
#         ._weather.csv
#       PEMS/
#         ._PEMS07.npz
#         ._PEMS04.npz
#         ._PEMS03.npz
#         ._PEMS08.npz
#   SimpleTM_datasets/
#     .DS_Store
#     traffic/
#       .DS_Store
#       traffic.csv
#     electricity/
#       .DS_Store
#       electricity.csv
#     Solar/
#       solar_AL.txt
#     ETT-small/
#       ETTm2.csv
#       ETTm1.csv
#       ETTh1.csv
#       ETTh2.csv
#     weather/
#       weather.csv
#     smartbuilding/
#       smart.csv
#     PEMS/
#       PEMS04.npz
#       PEMS03.npz
#       PEMS08.npz
#       PEMS07.npz

# %%
SELECTED_DATASETS = None
# Example: SELECTED_DATASETS = ["ETTh1", "ETTm1", "smartbuilding"]

all_datasets = [
    # Official SimpleTM paper script settings for pred_len=96
    {"name": "ETTh1", "data": "ETTh1", "root": "./dataset/SimpleTM_datasets/ETT-small", "path": "ETTh1.csv", "enc_in": 7, "d_model": 32, "d_ff": 32, "e_layers": 1, "wv": "db1", "m": 3, "alpha": 0.3, "learning_rate": 0.02, "batch_size": 256, "train_epochs": 10, "patience": 3, "use_norm": 1, "lradj": "TST", "freq": "h", "itr": 3, "l1_weight": 0.0005},
    # {"name": "ETTh2", "data": "ETTh2", "root": "./dataset/SimpleTM_datasets/ETT-small", "path": "ETTh2.csv", "enc_in": 7, "d_model": 32, "d_ff": 32, "e_layers": 1, "wv": "bior3.1", "m": 1, "alpha": 0.1, "learning_rate": 0.006, "batch_size": 256, "train_epochs": 10, "patience": 3, "use_norm": 1, "lradj": "TST", "freq": "h", "itr": 3, "l1_weight": 0.0005},
    {"name": "ETTm1", "data": "ETTm1", "root": "./dataset/SimpleTM_datasets/ETT-small", "path": "ETTm1.csv", "enc_in": 7, "d_model": 32, "d_ff": 32, "e_layers": 1, "wv": "db1", "m": 3, "alpha": 0.1, "learning_rate": 0.02, "batch_size": 256, "train_epochs": 10, "patience": 3, "use_norm": 1, "lradj": "TST", "freq": "t", "itr": 3, "l1_weight": 0.005},
    # {"name": "ETTm2", "data": "ETTm2", "root": "./dataset/SimpleTM_datasets/ETT-small", "path": "ETTm2.csv", "enc_in": 7, "d_model": 32, "d_ff": 32, "e_layers": 1, "wv": "bior3.1", "m": 3, "alpha": 0.3, "learning_rate": 0.006, "batch_size": 256, "train_epochs": 10, "patience": 3, "use_norm": 1, "lradj": "TST", "freq": "t", "itr": 3, "l1_weight": 0.0005},
    {"name": "weather", "data": "custom", "root": "./dataset/SimpleTM_datasets/weather", "path": "weather.csv", "enc_in": 21, "d_model": 32, "d_ff": 32, "e_layers": 4, "wv": "db4", "m": 1, "alpha": 0.3, "learning_rate": 0.01, "batch_size": 256, "train_epochs": 10, "patience": 3, "use_norm": 1, "lradj": "TST", "freq": "h", "itr": 3, "l1_weight": 5e-05},
    # {"name": "electricity", "data": "custom", "root": "./dataset/SimpleTM_datasets/electricity", "path": "electricity.csv", "enc_in": 321, "d_model": 256, "d_ff": 1024, "e_layers": 1, "wv": "db1", "m": 3, "alpha": 0.0, "learning_rate": 0.01, "batch_size": 256, "train_epochs": 10, "patience": 3, "use_norm": 1, "lradj": "TST", "freq": "h", "itr": 1, "l1_weight": 0.0},
    # {"name": "traffic", "data": "custom", "root": "./dataset/SimpleTM_datasets/traffic", "path": "traffic.csv", "enc_in": 862, "d_model": 512, "d_ff": 1024, "e_layers": 2, "wv": "db1", "m": 3, "alpha": 0.1, "learning_rate": 0.003, "batch_size": 24, "train_epochs": 10, "patience": 3, "use_norm": 1, "lradj": "TST", "freq": "h", "itr": 1, "l1_weight": 0.0},
    # {"name": "Solar", "data": "Solar", "root": "./dataset/SimpleTM_datasets/Solar", "path": "solar_AL.txt", "enc_in": 137, "d_model": 128, "d_ff": 256, "e_layers": 1, "wv": "db8", "m": 3, "alpha": 0.0, "learning_rate": 0.01, "batch_size": 256, "train_epochs": 10, "patience": 3, "use_norm": 0, "lradj": "TST", "freq": "h", "itr": 3, "l1_weight": 0.005},
    # {"name": "PEMS03", "data": "PEMS", "root": "./dataset/SimpleTM_datasets/PEMS", "path": "PEMS03.npz", "enc_in": 358, "d_model": 256, "d_ff": 1024, "e_layers": 1, "wv": "bior3.1", "m": 3, "alpha": 0.1, "learning_rate": 0.002, "batch_size": 16, "train_epochs": 20, "patience": 10, "use_norm": 0, "lradj": "TST", "freq": "h", "itr": 3, "l1_weight": 0.005},
    # {"name": "PEMS04", "data": "PEMS", "root": "./dataset/SimpleTM_datasets/PEMS", "path": "PEMS04.npz", "enc_in": 307, "d_model": 256, "d_ff": 1024, "e_layers": 1, "wv": "bior3.1", "m": 3, "alpha": 0.1, "learning_rate": 0.002, "batch_size": 16, "train_epochs": 20, "patience": 10, "use_norm": 0, "lradj": "TST", "freq": "h", "itr": 3, "l1_weight": 5e-05},
    # {"name": "PEMS07", "data": "PEMS", "root": "./dataset/SimpleTM_datasets/PEMS", "path": "PEMS07.npz", "enc_in": 883, "d_model": 256, "d_ff": 512, "e_layers": 1, "wv": "db1", "m": 3, "alpha": 0.1, "learning_rate": 0.002, "batch_size": 16, "train_epochs": 20, "patience": 10, "use_norm": 0, "lradj": "TST", "freq": "h", "itr": 3, "l1_weight": 5e-05},
    # {"name": "PEMS08", "data": "PEMS", "root": "./dataset/SimpleTM_datasets/PEMS", "path": "PEMS08.npz", "enc_in": 170, "d_model": 256, "d_ff": 1024, "e_layers": 1, "wv": "db12", "m": 3, "alpha": 0.0, "learning_rate": 0.001, "batch_size": 16, "train_epochs": 20, "patience": 10, "use_norm": 0, "lradj": "TST", "freq": "h", "itr": 3, "l1_weight": 0.0},

    # No official script exists for smartbuilding, so use one fixed recipe for every variant on this dataset.
    # {"name": "smartbuilding", "data": "custom", "root": "./dataset/SimpleTM_datasets/smartbuilding", "path": "smart.csv", "enc_in": 37, "d_model": 64, "d_ff": 128, "e_layers": 1, "wv": "db4", "m": 3, "alpha": 0.3, "learning_rate": 0.003, "batch_size": 64, "train_epochs": 20, "patience": 5, "use_norm": 1, "lradj": "TST", "freq": "h", "itr": 3, "l1_weight": 5e-05, "target": "Floor_Total(kW)"},
]

experiments = [
    {"tag": "SWT_original", "model": "SimpleTM_SWT", "attention_mode": "original"},
    {"tag": "SWT_dual", "model": "SimpleTM_SWT", "attention_mode": "dual"},
    {"tag": "FFT_original", "model": "SimpleTM_FFT", "attention_mode": "original"},
    {"tag": "FFT_dual", "model": "SimpleTM_FFT", "attention_mode": "dual"},
    {"tag": "Conv_original", "model": "SimpleTM_Conv", "attention_mode": "original"},
    {"tag": "Conv_dual", "model": "SimpleTM_Conv", "attention_mode": "dual"},
    {"tag": "Hybrid_original", "model": "SimpleTM_Hybrid", "attention_mode": "original"},
    {"tag": "Hybrid_dual", "model": "SimpleTM_Hybrid", "attention_mode": "dual"},
]

if SELECTED_DATASETS is not None:
    datasets = [ds for ds in all_datasets if ds["name"] in SELECTED_DATASETS]
else:
    datasets = all_datasets

print("Datasets selected:")
for ds in datasets:
    print(f"- {ds['name']}: e_layers={ds['e_layers']}, d_model={ds['d_model']}, d_ff={ds['d_ff']}, lr={ds['learning_rate']}, batch={ds['batch_size']}, itr={ds['itr']}, wv={ds['wv']}, m={ds['m']}, alpha={ds['alpha']}, l1={ds['l1_weight']}")

print("\nExperiments selected:")
for exp in experiments:
    print(f"- {exp['tag']}")

OUTPUT_DIR = "/kaggle/working/SimpleTM_Paper96_AllVariants_Results"
if os.path.exists(OUTPUT_DIR):
    shutil.rmtree(OUTPUT_DIR)
os.makedirs(OUTPUT_DIR, exist_ok=True)

if os.path.exists('./checkpoints'):
    shutil.rmtree('./checkpoints')
if os.path.exists('result_long_term_forecast.txt'):
    os.remove('result_long_term_forecast.txt')
# Out:
# Datasets selected:
# - ETTh1: e_layers=1, d_model=32, d_ff=32, lr=0.02, batch=256, itr=3, wv=db1, m=3, alpha=0.3, l1=0.0005
# - ETTm1: e_layers=1, d_model=32, d_ff=32, lr=0.02, batch=256, itr=3, wv=db1, m=3, alpha=0.1, l1=0.005
# - weather: e_layers=4, d_model=32, d_ff=32, lr=0.01, batch=256, itr=3, wv=db4, m=1, alpha=0.3, l1=5e-05
#
# Experiments selected:
# - SWT_original
# - SWT_dual
# - FFT_original
# - FFT_dual
# - Conv_original
# - Conv_dual
# - Hybrid_original
# - Hybrid_dual

# %%
for ds in datasets:
    print("\n" + "=" * 100)
    print(f"DATASET: {ds['name']} | variates={ds['enc_in']} | official_pred96_recipe")
    print("=" * 100 + "\n")

    for exp in experiments:
        print(f">>> Training {exp['tag']} on {ds['name']} <<<\n")
        unique_model_id = f"{ds['name']}_{exp['model']}_{exp['attention_mode']}"

        cmd = [
            "python", "-u", "run.py",
            "--is_training", "1",
            "--model", exp["model"],
            "--attention_mode", exp["attention_mode"],
            "--model_id", unique_model_id,
            "--data", ds["data"],
            "--root_path", ds["root"],
            "--data_path", ds["path"],
            "--features", "M",
            "--freq", ds["freq"],
            "--seq_len", "96",
            "--pred_len", "96",
            "--e_layers", str(ds["e_layers"]),
            "--d_model", str(ds["d_model"]),
            "--d_ff", str(ds["d_ff"]),
            "--enc_in", str(ds["enc_in"]),
            "--dec_in", str(ds["enc_in"]),
            "--c_out", str(ds["enc_in"]),
            "--wv", ds["wv"],
            "--m", str(ds["m"]),
            "--alpha", str(ds["alpha"]),
            "--l1_weight", str(ds["l1_weight"]),
            "--learning_rate", str(ds["learning_rate"]),
            "--batch_size", str(ds["batch_size"]),
            "--train_epochs", str(ds["train_epochs"]),
            "--patience", str(ds["patience"]),
            "--itr", str(ds["itr"]),
            "--num_workers", "2",
            "--lradj", ds["lradj"],
            "--use_norm", str(ds["use_norm"]),
            "--checkpoints", f"{OUTPUT_DIR}/checkpoints/",
            "--fix_seed", "2025",
            "--des", "Paper96",
        ]

        if "conv_kernel_sizes" in ds:
            cmd.extend(["--conv_kernel_sizes", ds["conv_kernel_sizes"]])

        if "target" in ds:
            cmd.extend(["--target", ds["target"]])

        process = subprocess.Popen(
            cmd,
            stdout=subprocess.PIPE,
            stderr=subprocess.STDOUT,
            text=True,
        )
        for line in process.stdout:
            print(line, end="")
        process.wait()

        if process.returncode == 0:
            print(f"\nSUCCESS: Finished {exp['tag']} on {ds['name']}\n")
        else:
            raise RuntimeError(f"Run failed for {ds['name']} | {exp['tag']} with exit code {process.returncode}")

print("\nGathering generated PDF plots...")
if os.path.exists('./checkpoints'):
    for root_dir, dirs, files in os.walk('./checkpoints'):
        for file in files:
            if file.endswith('.pdf') or file.endswith('.png'):
                folder_name = os.path.basename(root_dir)
                source_path = os.path.join(root_dir, file)
                target_plot_dir = os.path.join(OUTPUT_DIR, 'plots', folder_name)
                os.makedirs(target_plot_dir, exist_ok=True)
                shutil.copy(source_path, os.path.join(target_plot_dir, file))
    print(f"Copied PDF plots to {OUTPUT_DIR}/plots/")

if os.path.exists('result_long_term_forecast.txt'):
    shutil.copy('result_long_term_forecast.txt', os.path.join(OUTPUT_DIR, 'result_long_term_forecast.txt'))
    print("Copied metric text results to output directory.")
# Out:
# ====================================================================================================
# DATASET: ETTh1 | variates=7 | official_pred96_recipe
# ====================================================================================================
#
# >>> Training SWT_original on ETTh1 <<<
#
# Args in experiment:
# Namespace(is_training=1, model_id='ETTh1_SimpleTM_SWT_original', model='SimpleTM_SWT', data='ETTh1', root_path='./dataset/SimpleTM_datasets/ETT-small', data_path='ETTh1.csv', features='M', target='OT', freq='h', checkpoints='/kaggle/working/SimpleTM_Paper96_AllVariants_Results/checkpoints/', seq_len=96, label_len=0, pred_len=96, enc_in=7, dec_in=7, c_out=7, n_heads=8, d_layers=1, moving_avg=25, factor=1, distil=True, dropout=0.1, geomattn_dropout=0.5, embed='timeF', activation='gelu', do_predict=False, num_workers=2, itr=3, train_epochs=10, batch_size=256, patience=3, learning_rate=0.02, des='Paper96', loss='MSE', lradj='TST', pct_start=0.2, use_amp=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', exp_name='MTSF', channel_independence=False, inverse=False, class_strategy='projection', target_root_path='./data/electricity/', target_data_path='electricity.csv', efficient_training=False, use_norm=1, partial_start_index=0, requires_grad=True, wv='db1', m=3, kernel_size=None, conv_kernel_sizes=None, alpha=0.3, l1_weight=0.0005, d_model=32, d_ff=32, e_layers=1, compile=False, output_attention=False, attention_mode='original', fix_seed=2025)
# Use GPU: cuda:0
# Total trainable parameters: 12856
# Memory usage for trainable parameters: 0.05 MB
# Static memory footprint (allocated): 0.06 MB
# Static memory footprint (reserved): 2.00 MB
# >>>>>>>start training : ETTh1_SimpleTM_SWT_original_SimpleTM_SWT_original_ETTh1_96_96_32_32_1_db1_None_None_3_0.3_0.0005_0.02_TST_256_2025_1_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8449
# val 2785
# test 2785
# 	iters: 30, epoch: 1 | loss: 0.4355321
# 	speed: 0.1545s/iter; left time: 46.5156s
# Epoch: 1 cost time: 4.918433904647827
# Epoch: 1, Steps: 33 | Train Loss: 0.5122802 Vali Loss: 0.7648493 Test Loss: 0.4342277
# Validation loss decreased (inf --> 0.764849).  Saving model ...
# Updating learning rate to 0.010631971954266867
# 	iters: 30, epoch: 2 | loss: 0.3691771
# 	speed: 0.1055s/iter; left time: 28.2843s
# Epoch: 2 cost time: 2.7101521492004395
# Epoch: 2, Steps: 33 | Train Loss: 0.3849422 Vali Loss: 0.7066466 Test Loss: 0.3852118
# Validation loss decreased (0.764849 --> 0.706647).  Saving model ...
# Updating learning rate to 0.019999291964499063
# 	iters: 30, epoch: 3 | loss: 0.3458501
# 	speed: 0.1413s/iter; left time: 33.1952s
# Epoch: 3 cost time: 3.3079395294189453
# Epoch: 3, Steps: 33 | Train Loss: 0.3649371 Vali Loss: 0.6962830 Test Loss: 0.3779373
# Validation loss decreased (0.706647 --> 0.696283).  Saving model ...
# Updating learning rate to 0.019192606265404512
# 	iters: 30, epoch: 4 | loss: 0.3400123
# 	speed: 0.1054s/iter; left time: 21.2976s
# Epoch: 4 cost time: 2.7179412841796875
# Epoch: 4, Steps: 33 | Train Loss: 0.3581325 Vali Loss: 0.6929207 Test Loss: 0.3750716
# Validation loss decreased (0.696283 --> 0.692921).  Saving model ...
# Updating learning rate to 0.01698643568322283
# 	iters: 30, epoch: 5 | loss: 0.3398223
# 	speed: 0.1010s/iter; left time: 17.0676s
# Epoch: 5 cost time: 2.643609046936035
# Epoch: 5, Steps: 33 | Train Loss: 0.3525008 Vali Loss: 0.6986319 Test Loss: 0.3678255
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 0.013716649690105047
# 	iters: 30, epoch: 6 | loss: 0.3171009
# 	speed: 0.1052s/iter; left time: 14.3113s
# Epoch: 6 cost time: 2.740243673324585
# Epoch: 6, Steps: 33 | Train Loss: 0.3486916 Vali Loss: 0.6865767 Test Loss: 0.3671216
# Validation loss decreased (0.692921 --> 0.686577).  Saving model ...
# Updating learning rate to 0.00988104356281951
# 	iters: 30, epoch: 7 | loss: 0.3380896
# 	speed: 0.1026s/iter; left time: 10.5707s
# Epoch: 7 cost time: 2.6932270526885986
# Epoch: 7, Steps: 33 | Train Loss: 0.3466878 Vali Loss: 0.6865834 Test Loss: 0.3669731
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 0.006063553564389314
# 	iters: 30, epoch: 8 | loss: 0.3376036
# 	speed: 0.1035s/iter; left time: 7.2455s
# Epoch: 8 cost time: 2.6806411743164062
# Epoch: 8, Steps: 33 | Train Loss: 0.3441770 Vali Loss: 0.6781377 Test Loss: 0.3648604
# Validation loss decreased (0.686577 --> 0.678138).  Saving model ...
# Updating learning rate to 0.002845357941442444
# 	iters: 30, epoch: 9 | loss: 0.3371115
# 	speed: 0.1021s/iter; left time: 3.7777s
# Epoch: 9 cost time: 2.6937787532806396
# Epoch: 9, Steps: 33 | Train Loss: 0.3421556 Vali Loss: 0.6815789 Test Loss: 0.3646216
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 0.000716397804556595
# 	iters: 30, epoch: 10 | loss: 0.3370314
# 	speed: 0.1053s/iter; left time: 0.4210s
# Epoch: 10 cost time: 2.7020668983459473
# Epoch: 10, Steps: 33 | Train Loss: 0.3415510 Vali Loss: 0.6788388 Test Loss: 0.3643096
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 7.880355009381883e-07
# >>>>>>>testing : ETTh1_SimpleTM_SWT_original_SimpleTM_SWT_original_ETTh1_96_96_32_32_1_db1_None_None_3_0.3_0.0005_0.02_TST_256_2025_1_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2785
# test shape: (10, 256, 96, 7) (10, 256, 96, 7)
# test shape: (2560, 96, 7) (2560, 96, 7)
# Collected 16 examples for combined_prediction_examples.png
# mse:0.

# Collected 16 examples for combined_prediction_examples.png
# mse:0.16216997802257538, mae:0.2095405012369156
# rmse:0.40270334482192993, mape:0.5007309913635254, mspe:12364406.0
# rse:0.530115008354187, corr:43.34443283081055, smape:0.5406392216682434, wape:0.3461776375770569, r2:0.7189780473709106
#
# SUCCESS: Finished Hybrid_dual on weather
#
#
# Gathering generated PDF plots...
# Copied PDF plots to /kaggle/working/SimpleTM_Paper96_AllVariants_Results/plots/
# Copied metric text results to output directory.

# %%
import re

results_file = os.path.join(OUTPUT_DIR, 'result_long_term_forecast.txt')
metric_order = ['MSE', 'MAE', 'RMSE', 'MAPE', 'WAPE', 'R2']
pattern = re.compile(r'^(?P<dataset>[^_]+)_(?P<model>SimpleTM_(?:SWT|FFT|Conv|Hybrid))_(?P<attention>original|dual)_')
metric_pattern = re.compile(r'([a-zA-Z0-9_]+):([^,]+)')

if os.path.exists(results_file):
    with open(results_file, 'r', encoding='utf-8') as f:
        content = f.read().strip()

    entries = content.split('\n\n') if content else []
    rows = []
    for entry in entries:
        lines = [line.strip() for line in entry.splitlines() if line.strip()]
        if len(lines) < 2:
            continue
        setting = lines[0]
        metrics_line = lines[-1]
        match = pattern.search(setting)
        if not match:
            continue

        model_type = match.group('model')
        attention_mode = match.group('attention')
        tokenization = model_type.replace('SimpleTM_', '')
        row = {
            'Dataset': match.group('dataset'),
            'Model': model_type,
            'AttentionMode': attention_mode,
            'Variant': f'{tokenization}_{attention_mode}',
            'Setting': setting,
        }
        for metric_name, value in metric_pattern.findall(metrics_line):
            try:
                row[metric_name.upper()] = float(value.strip())
            except ValueError:
                pass
        rows.append(row)

    if rows:
        raw_df = pd.DataFrame(rows).sort_values(['Dataset', 'Model', 'AttentionMode', 'Setting']).reset_index(drop=True)
        value_columns = [col for col in metric_order if col in raw_df.columns]
        raw_columns = ['Dataset', 'Model', 'AttentionMode', 'Variant', 'Setting'] + value_columns
        raw_df = raw_df[raw_columns]
        print('Raw runs:')
        print(raw_df.to_string(index=False))

        raw_path = os.path.join(OUTPUT_DIR, 'raw_metrics.csv')
        raw_df.to_csv(raw_path, index=False)

        agg_df = raw_df.groupby(['Dataset', 'Variant'], as_index=False)[value_columns].mean()
        counts_df = raw_df.groupby(['Dataset', 'Variant'], as_index=False).size().rename(columns={'size': 'NumRuns'})
        agg_df = agg_df.merge(counts_df, on=['Dataset', 'Variant'], how='left')
        ordered_columns = ['Dataset', 'Variant'] + value_columns + ['NumRuns']
        agg_df = agg_df[ordered_columns]
        print('\nAveraged results across repeated itr runs:')
        print(agg_df.sort_values(['Dataset', 'Variant']).to_string(index=False))

        averaged_path = os.path.join(OUTPUT_DIR, 'averaged_metrics.csv')
        agg_df.to_csv(averaged_path, index=False)

        pivot_df = agg_df.pivot(index='Dataset', columns='Variant', values=value_columns)
        variant_order = ['SWT_original', 'SWT_dual', 'FFT_original', 'FFT_dual', 'Conv_original', 'Conv_dual', 'Hybrid_original', 'Hybrid_dual']
        pivot_df = pivot_df.reindex(columns=variant_order, level=1)
        final_path = os.path.join(OUTPUT_DIR, 'final_metrics.csv')
        pivot_df.to_csv(final_path)

        print(f'\nSaved raw results to: {raw_path}')
        print(f'Saved averaged results to: {averaged_path}')
        print(f'Saved final table to: {final_path}')
    else:
        print('No valid metrics found in result file.')
else:
    print('Result file not found.')
# Out:
# Raw runs:
# Dataset           Model AttentionMode         Variant                                                                                                                        Setting      MSE      MAE     RMSE     MAPE     WAPE       R2
#   ETTh1   SimpleTM_Conv          dual       Conv_dual               ETTh1_SimpleTM_Conv_dual_SimpleTM_Conv_dual_ETTh1_96_96_32_32_1_db1_None_None_3_0.3_0.0005_0.02_TST_256_2025_1_0 0.368271 0.394686 0.606854 0.662441 0.493308 0.666054
#   ETTh1   SimpleTM_Conv          dual       Conv_dual               ETTh1_SimpleTM_Conv_dual_SimpleTM_Conv_dual_ETTh1_96_96_32_32_1_db1_None_None_3_0.3_0.0005_0.02_TST_256_2025_1_1 0.368494 0.395854 0.607037 0.664089 0.494769 0.665852
#   ETTh1   SimpleTM_Conv          dual       Conv_dual               ETTh1_SimpleTM_Conv_dual_SimpleTM_Conv_dual_ETTh1_96_96_32_32_1_db1_None_None_3_0.3_0.0005_0.02_TST_256_2025_1_2 0.373983 0.397060 0.611542 0.663761 0.496275 0.660874
#   ETTh1   SimpleTM_Conv      original   Conv_original       ETTh1_SimpleTM_Conv_original_SimpleTM_Conv_original_ETTh1_96_96_32_32_1_db1_None_None_3_0.3_0.0005_0.02_TST_256_2025_1_0 0.367101 0.393900 0.605889 0.662012 0.492326 0.667114
#   ETTh1   SimpleTM_Conv      original   Conv_original       ETTh1_SimpleTM_Conv_original_SimpleTM_Conv_original_ETTh1_96_96_32_32_1_db1_None_None_3_0.3_0.0005_0.02_TST_256_2025_1_1 0.368454 0.393414 0.607004 0.658717 0.491718 0.665888
#   ETTh1   SimpleTM_Conv      original   Conv_original       ETTh1_SimpleTM_Conv_original_SimpleTM_Conv_original_ETTh1_96_96_32_32_1_db1_None_None_3_0.3_0.0005_0.02_TST_256_2025_1_2 0.369720 0.394864 0.608046 0.663188 0.493531 0.664740
#   ETTh1    SimpleTM_FFT          dual        FFT_dual                 ETTh1_SimpleTM_FFT_dual_SimpleTM_FFT_dual_ETTh1_96_96_32_32_1_db1_None_None_3_0.3_0.0005_0.02_TST_256_2025_1_0 0.365649 0.394826 0.604689 0.666407 0.493483 0.668432
#   ETTh1    SimpleTM_FFT          dual        FFT_dual                 ETTh1_SimpleTM_FFT_dual_SimpleTM_FFT_dual_ETTh1_96_96_32_32_1_db1_None_None_3_0.3_0.0005_0.02_TST_256_2025_1_1 0.366956 0.394425 0.605769 0.663526 0.492983 0.667247
#   ETTh1    SimpleTM_FFT          dual        FFT_dual                 ETTh1_SimpleTM_FFT_dual_SimpleTM_FFT_dual_ETTh1_96_96_32_32_1_db1_None_None_3_0.3_0.0005_0.02_TST_256_2025_1_2 0.370753 0.396793 0.608895 0.668894 0.495942 0.663803
#   ETTh1    SimpleTM_FFT      original    FFT_original         ETTh1_SimpleTM_FFT_original_SimpleTM_FFT_original_ETTh1_96_96_32_32_1_db1_None_None_3_0.3_0.0005_0.02_TST_256_2025_1_0 0.368598 0.393462 0.607123 0.660424 0.491779 0.665757
#   ETTh1    SimpleTM_FFT      original    FFT_original         ETTh1_SimpleTM_FFT_original_SimpleTM_FFT_original_ETTh1_96_96_32_32_1_db1_None_None_3_0.3_0.0005_0.02_TST_256_2025_1_1 0.370590 0.394627 0.608761 0.662866 0.493234 0.663951
#   ETTh1    SimpleTM_FFT      original    FFT_original         ETTh1_SimpleTM_FFT_original_SimpleTM_FFT_original_ETTh1_96_96_32_32_1_db1_None_None_3_0.3_0.0005_0.02_TST_256_2025_1_2 0.371262 0.395206 0.609313 0.662592 0.493958 0.663342
#   ETTh1 SimpleTM_Hybrid          dual     Hybrid_dual           ETTh1_SimpleTM_Hybrid_dual_SimpleTM_Hybrid_dual_ETTh1_96_96_32_32_1_db1_None_None_3_0.3_0.0005_0.02_TST_256_2025_1_0 0.371997 0.397750 0.609916 0.670139 0.497138 0.662675
#   ETTh1 SimpleTM_Hybrid          dual     Hybrid_dual           ETTh1_SimpleTM_Hybrid_dual_SimpleTM_Hybrid_dual_ETTh1_96_96_32_32_1_db1_None_None_3_0.3_0.0005_0.02_TST_256_2025_1_1 0.371623 0.397851 0.609609 0.668049 0.497264 0.663014
#   ETTh1 SimpleTM_Hybrid          dual     Hybrid_dual           ETTh1_SimpleTM_Hybrid_dual_SimpleTM_Hybrid_dual_ETTh1_96_96_32_32_1_db1_None_None_3_0.3_0.0005_0.02_TST_256_2025_1_2 0.374511 0.400587 0.611973 0.674655 0.500683 0.660396
#   ETTh1 SimpleTM_Hybrid      original Hybrid_original   ETTh1_SimpleTM_Hybrid_original_SimpleTM_Hybrid_original_ETTh1_96_96_32_32_1_db1_None_None_3_0.3_0.0005_0.02_TST_256_2025_1_0 0.369085 0.394203 0.607524 0.659931 0.492704 0.665315
#   ETTh1 SimpleTM_Hybrid      original Hybrid_original   ETTh1_SimpleTM_Hybrid_original_SimpleTM_Hybrid_original_ETTh1_96_96_32_32_1_db1_None_None_3_0.3_0.0005_0.02_TST_256_2025_1_1 0.371329 0.396241 0.609368 0.665117 0.495252 0.663281
#   ETTh1 SimpleTM_Hybrid      original Hybrid_original   ETTh1_SimpleTM_Hybrid_original_SimpleTM_Hybrid_original_ETTh1_96_96_32_32_1_db1_None_None_3_0.3_0.0005_0.02_TST_256_2025_1_2 0.372874 0.399213 0.610634 0.673098 0.498966 0.661880
#   ETTh1    SimpleTM_SWT          dual        SWT_dual                 ETTh1_SimpleTM_SWT_dual_SimpleTM_SWT_dual_ETTh1_96_96_32_32_1_db1_None_None_3_0.3_0.0005_0.02_TST_256_2025_1_0 0.367640 0.395184 0.606333 0.664405 0.493930 0.666626
#   ETTh1    SimpleTM_SWT          dual        SWT_dual                 ETTh1_SimpleTM_SWT_dual_SimpleTM_SWT_dual_ETTh1_96_96_32_32_1_db1_None_None_3_0.3_0.0005_0.02_TST_256_2025_1_1 0.365687 0.393186 0.604721 0.661382 0.491433 0.668397
#   ETTh1    SimpleTM_SWT          dual        SWT_dual                 ETTh1_SimpleTM_SWT_dual_SimpleTM_SWT_dual_ETTh1_96_96_32_32_1_db1_None_None_3_0.3_0.0005_0.02_TST_256_2025_1_2 0.370187 0.396886 0.608430 0.668154 0.496058 0.664316
#   ETTh1    SimpleTM_SWT      original    SWT_original         ETTh1_SimpleTM_SWT_original_SimpleTM_SWT_original_ETTh1_96_96_32_32_1_db1_None_None_3_0.3_0.0005_0.02_TST_256_2025_1_0 0.364860 0.392333 0.604037 0.660345 0.490367 0.669147
#   ETTh1    SimpleTM_SWT      original    SWT_original         ETTh1_SimpleTM_SWT_original_SimpleTM_SWT_original_ETTh1_96_96_32_32_1_db1_None_None_3_0.3_0.0005_0.02_TST_256_2025_1_1 0.370545 0.395753 0.608724 0.662311 0.494642 0.663992
#   ETTh1    SimpleTM_SWT      original    SWT_original         ETTh1_SimpleTM_SWT_original_SimpleTM_SWT_original_ETTh1_96_96_32_32_1_db1_None_None_3_0.3_0.0005_0.02_TST_256_2025_1_2 0.366896 0.393790 0.605720 0.661138 0.492189 0.667300
#   ETTm1   SimpleTM_Conv          dual       Conv_dual                ETTm1_SimpleTM_Conv_dual_SimpleTM_Conv_dual_ETTm1_96_96_32_32_1_db1_None_None_3_0.1_0.005_0.02_TST_256_2025_1_0 0.321237 0.360622 0.566777 0.651616 0.454813 0.710337
#   ETTm1   SimpleTM_Conv          dual       Conv_dual                ETTm1_SimpleTM_Conv_dual_SimpleTM_Conv_dual_ETTm1_96_96_32_32_1_db1_None_None_3_0.1_0.005_0.02_TST_256_2025_1_1 0.324323 0.363149 0.569493 0.654975 0.458001 0.707554
#   ETTm1   SimpleTM_Conv          dual       Conv_dual                ETTm1_SimpleTM_Conv_dual_SimpleTM_Conv_dual_ETTm1_96_96_32_32_1_db1_None_None_3_0.1_0.005_0.02_TST_256_2025_1_2 0.322769 0.363885 0.568128 0.657721 0.458929 0.708955
#   ETTm1   SimpleTM_Conv      original   Conv_original        ETTm1_SimpleTM_Conv_original_SimpleTM_Conv_original_ETTm1_96_96_32_32_1_db1_None_None_3_0.1_0.005_0.02_TST_256_2025_1_0 0.323508 0.361730 0.568778 0.649422 0.456212 0.708289
#   ETTm1   SimpleTM_Conv      original   Conv_original        ETTm1_SimpleTM_Conv_original_SimpleTM_Conv_original_ETTm1_96_96_32_32_1_db1_None_None_3_0.1_0.005_0.02_TST_256_2025_1_1 0.321659 0.360240 0.567150 0.648688 0.454332 0.709956
#   ETTm1   SimpleTM_Conv      original   Conv_original        ETTm1_SimpleTM_Conv_original_SimpleTM_Conv_original_ETTm1_96_96_32_32_1_db1_None_None_3_0.1_0.005_0.02_TST_256_2025_1_2 0.321296 0.360236 0.566830 0.649829 0.454327 0.710284
#   ETTm1    SimpleTM_FFT          dual        FFT_dual                  ETTm1_SimpleTM_FFT_dual_SimpleTM_FFT_dual_ETTm1_96_96_32_32_1_db1_None_None_3_0.1_0.005_0.02_TST_256_2025_1_0 0.333656 0.368740 0.577630 0.657570 0.465052 0.699138
#   ETTm1    SimpleTM_FFT          dual        FFT_dual                  ETTm1_SimpleTM_FFT_dual_SimpleTM_FFT_dual_ETTm1_96_96_32_32_1_db1_None_None_3_0.1_0.005_0.02_TST_256_2025_1_1 0.327642 0.365265 0.572400 0.655774 0.460670 0.704561
#   ETTm1    SimpleTM_FFT          dual        FFT_dual                  ETTm1_SimpleTM_FFT_dual_SimpleTM_FFT_dual_ETTm1_96_96_32_32_1_db1_None_None_3_0.1_0.005_0.02_TST_256_2025_1_2 0.330558 0.366763 0.574942 0.657651 0.462559 0.701931
#   ETTm1    SimpleTM_FFT      original    FFT_original          ETTm1_SimpleTM_FFT_original_SimpleTM_FFT_original_ETTm1_96_96_32_32_1_db1_None_None_3_0.1_0.005_0.02_TST_256_2025_1_0 0.328648 0.364484 0.573279 0.655156 0.459684 0.703654
#   ETTm1    SimpleTM_FFT      original    FFT_original          ETTm1_SimpleTM_FFT_original_SimpleTM_FFT_original_ETTm1_96_96_32_32_1_db1_None_None_3_0.1_0.005_0.02_TST_256_2025_1_1 0.326095 0.362884 0.571047 0.651455 0.457666 0.705956
#   ETTm1    SimpleTM_FFT      original    FFT_original          ETTm1_SimpleTM_FFT_original_SimpleTM_FFT_original_ETTm1_96_96_32_32_1_db1_None_None_3_0.1_0.005_0.02_TST_256_2025_1_2 0.325854 0.362185 0.570836 0.650040 0.456785 0.706173
#   ETTm1 SimpleTM_Hybrid          dual     Hybrid_dual            ETTm1_SimpleTM_Hybrid_dual_SimpleTM_Hybrid_dual_ETTm1_96_96_32_32_1_db1_None_None_3_0.1_0.005_0.02_TST_256_2025_1_0 0.320874 0.359712 0.566458 0.652440 0.453666 0.710664
#   ETTm1 SimpleTM_Hybrid          dual     Hybrid_dual            ETTm1_SimpleTM_Hybrid_dual_SimpleTM_Hybrid_dual_ETTm1_96_96_32_32_1_db1_None_None_3_0.1_0.005_0.02_TST_256_2025_1_1 0.321181 0.359911 0.566728 0.649822 0.453917 0.710387
#   ETTm1 SimpleTM_Hybrid          dual     Hybrid_dual            ETTm1_SimpleTM_Hybrid_dual_SimpleTM_Hybrid_dual_ETTm1_96_96_32_32_1_db1_None_None_3_0.1_0.005_0.02_TST_256_2025_1_2 0.329401 0.367788 0.573934 0.661675 0.463852 0.702975
#   ETTm1 SimpleTM_Hybrid      original Hybrid_original    ETTm1_SimpleTM_Hybrid_original_SimpleTM_Hybrid_original_ETTm1_96_96_32_32_1_db1_None_None_3_0.1_0.005_0.02_TST_256_2025_1_0 0.320098 0.357918 0.565772 0.647282 0.451403 0.711363
#   ETTm1 SimpleTM_Hybrid      original Hybrid_original    ETTm1_SimpleTM_Hybrid_original_SimpleTM_Hybrid_original_ETTm1_96_96_32_32_1_db1_None_None_3_0.1_0.005_0.02_TST_256_2025_1_1 0.328214 0.365377 0.572899 0.656405 0.460811 0.704046
#   ETTm1 SimpleTM_Hybrid      original Hybrid_original    ETTm1_SimpleTM_Hybrid_original_SimpleTM_Hybrid_original_ETTm1_96_96_32_32_1_db1_None_None_3_0.1_0.005_0.02_TST_256_2025_1_2 0.321081 0.359105 0.566640 0.647973 0.452901 0.710478
#   ETTm1    SimpleTM_SWT          dual        SWT_dual                  ETTm1_SimpleTM_SWT_dual_SimpleTM_SWT_dual_ETTm1_96_96_32_32_1_db1_None_None_3_0.1_0.005_0.02_TST_256_2025_1_0 0.326667 0.365055 0.571548 0.656690 0.460405 0.705440
#   ETTm1    SimpleTM_SWT          dual        SWT_dual                  ETTm1_SimpleTM_SWT_dual_SimpleTM_SWT_dual_ETTm1_96_96_32_32_1_db1_None_None_3_0.1_0.005_0.02_TST_256_2025_1_1 0.318765 0.358537 0.564593 0.649432 0.452184 0.712565
#   ETTm1    SimpleTM_SWT          dual        SWT_dual                  ETTm1_SimpleTM_SWT_dual_SimpleTM_SWT_dual_ETTm1_96_96_32_32_1_db1_None_None_3_0.1_0.005_0.02_TST_256_2025_1_2 0.328981 0.367102 0.573569 0.660535 0.462986 0.703354
#   ETTm1    SimpleTM_SWT      original    SWT_original          ETTm1_SimpleTM_SWT_original_SimpleTM_SWT_original_ETTm1_96_96_32_32_1_db1_None_None_3_0.1_0.005_0.02_TST_256_2025_1_0 0.322685 0.362550 0.568054 0.653641 0.457246 0.709031
#   ETTm1    SimpleTM_SWT      original    SWT_original          ETTm1_SimpleTM_SWT_original_SimpleTM_SWT_original_ETTm1_96_96_32_32_1_db1_None_None_3_0.1_0.005_0.02_TST_256_2025_1_1 0.322770 0.361588 0.568128 0.652538 0.456033 0.708954
#   ETTm1    SimpleTM_SWT      original    SWT_original          ETTm1_SimpleTM_SWT_original_SimpleTM_SWT_original_ETTm1_96_96_32_32_1_db1_None_None_3_0.1_0.005_0.02_TST_256_2025_1_2 0.319460 0.358619 0.565208 0.647131 0.452288 0.711939
# weather   SimpleTM_Conv          dual       Conv_dual             weather_SimpleTM_Conv_dual_SimpleTM_Conv_dual_custom_96_96_32_32_4_db4_None_None_1_0.3_5e-05_0.01_TST_256_2025_1_0 0.162301 0.208235 0.402866 0.502585 0.344022 0.718751
# weather   SimpleTM_Conv          dual       Conv_dual             weather_SimpleTM_Conv_dual_SimpleTM_Conv_dual_custom_96_96_32_32_4_db4_None_None_1_0.3_5e-05_0.01_TST_256_2025_1_1 0.167485 0.215376 0.409249 0.508039 0.355819 0.709768
# weather   SimpleTM_Conv          dual       Conv_dual             weather_SimpleTM_Conv_dual_SimpleTM_Conv_dual_custom_96_96_32_32_4_db4_None_None_1_0.3_5e-05_0.01_TST_256_2025_1_2 0.162931 0.210978 0.403648 0.504421 0.348553 0.717659
# weather   SimpleTM_Conv      original   Conv_original     weather_SimpleTM_Conv_original_SimpleTM_Conv_original_custom_96_96_32_32_4_db4_None_None_1_0.3_5e-05_0.01_TST_256_2025_1_0 0.158860 0.204581 0.398572 0.490590 0.337985 0.724714
# weather   SimpleTM_Conv      original   Conv_original     weather_SimpleTM_Conv_original_SimpleTM_Conv_original_custom_96_96_32_32_4_db4_None_None_1_0.3_5e-05_0.01_TST_256_2025_1_1 0.159163 0.204883 0.398952 0.494211 0.338483 0.724189
# weather   SimpleTM_Conv      original   Conv_original     weather_SimpleTM_Conv_original_SimpleTM_Conv_original_custom_96_96_32_32_4_db4_None_None_1_0.3_5e-05_0.01_TST_256_2025_1_2 0.157758 0.203298 0.397188 0.492364 0.335865 0.726623
# weather    SimpleTM_FFT          dual        FFT_dual               weather_SimpleTM_FFT_dual_SimpleTM_FFT_dual_custom_96_96_32_32_4_db4_None_None_1_0.3_5e-05_0.01_TST_256_2025_1_0 0.169128 0.215663 0.411251 0.505389 0.356292 0.706921
# weather    SimpleTM_FFT          dual        FFT_dual               weather_SimpleTM_FFT_dual_SimpleTM_FFT_dual_custom_96_96_32_32_4_db4_None_None_1_0.3_5e-05_0.01_TST_256_2025_1_1 0.163893 0.211213 0.404837 0.501780 0.348941 0.715993
# weather    SimpleTM_FFT          dual        FFT_dual               weather_SimpleTM_FFT_dual_SimpleTM_FFT_dual_custom_96_96_32_32_4_db4_None_None_1_0.3_5e-05_0.01_TST_256_2025_1_2 0.164794 0.211879 0.405949 0.501956 0.350041 0.714431
# weather    SimpleTM_FFT      original    FFT_original       weather_SimpleTM_FFT_original_SimpleTM_FFT_original_custom_96_96_32_32_4_db4_None_None_1_0.3_5e-05_0.01_TST_256_2025_1_0 0.178230 0.216344 0.422173 0.496330 0.357417 0.691148
# weather    SimpleTM_FFT      original    FFT_original       weather_SimpleTM_FFT_original_SimpleTM_FFT_original_custom_96_96_32_32_4_db4_None_None_1_0.3_5e-05_0.01_TST_256_2025_1_1 0.179518 0.217785 0.423696 0.498440 0.359798 0.688916
# weather    SimpleTM_FFT      original    FFT_original       weather_SimpleTM_FFT_original_SimpleTM_FFT_original_custom_96_96_32_32_4_db4_None_None_1_0.3_5e-05_0.01_TST_256_2025_1_2 0.178434 0.217039 0.422414 0.496947 0.358566 0.690795
# weather SimpleTM_Hybrid          dual     Hybrid_dual         weather_SimpleTM_Hybrid_dual_SimpleTM_Hybrid_dual_custom_96_96_32_32_4_db4_None_None_1_0.3_5e-05_0.01_TST_256_2025_1_0 0.162002 0.210868 0.402495 0.501913 0.348371 0.719269
# weather SimpleTM_Hybrid          dual     Hybrid_dual         weather_SimpleTM_Hybrid_dual_SimpleTM_Hybrid_dual_custom_96_96_32_32_4_db4_None_None_1_0.3_5e-05_0.01_TST_256_2025_1_1 0.162338 0.208539 0.402912 0.499519 0.344523 0.718687
# weather SimpleTM_Hybrid          dual     Hybrid_dual         weather_SimpleTM_Hybrid_dual_SimpleTM_Hybrid_dual_custom_96_96_32_32_4_db4_None_None_1_0.3_5e-05_0.01_TST_256_2025_1_2 0.162170 0.209541 0.402703 0.500731 0.346178 0.718978
# weather SimpleTM_Hybrid      original Hybrid_original weather_SimpleTM_Hybrid_original_SimpleTM_Hybrid_original_custom_96_96_32_32_4_db4_None_None_1_0.3_5e-05_0.01_TST_256_2025_1_0 0.158329 0.204436 0.397906 0.492532 0.337745 0.725634
# weather SimpleTM_Hybrid      original Hybrid_original weather_SimpleTM_Hybrid_original_SimpleTM_Hybrid_original_custom_96_96_32_32_4_db4_None_None_1_0.3_5e-05_0.01_TST_256_2025_1_1 0.156071 0.202181 0.395059 0.489192 0.334019 0.729546
# weather SimpleTM_Hybrid      original Hybrid_original weather_SimpleTM_Hybrid_original_SimpleTM_Hybrid_original_custom_96_96_32_32_4_db4_None_None_1_0.3_5e-05_0.01_TST_256_2025_1_2 0.159385 0.203701 0.399231 0.488139 0.336530 0.723804
# weather    SimpleTM_SWT          dual        SWT_dual               weather_SimpleTM_SWT_dual_SimpleTM_SWT_dual_custom_96_96_32_32_4_db4_None_None_1_0.3_5e-05_0.01_TST_256_2025_1_0 0.167525 0.211301 0.409298 0.502629 0.349087 0.709699
# weather    SimpleTM_SWT          dual        SWT_dual               weather_SimpleTM_SWT_dual_SimpleTM_SWT_dual_custom_96_96_32_32_4_db4_None_None_1_0.3_5e-05_0.01_TST_256_2025_1_1 0.159483 0.207886 0.399353 0.502039 0.343445 0.723635
# weather    SimpleTM_SWT          dual        SWT_dual               weather_SimpleTM_SWT_dual_SimpleTM_SWT_dual_custom_96_96_32_32_4_db4_None_None_1_0.3_5e-05_0.01_TST_256_2025_1_2 0.163040 0.211351 0.403782 0.504531 0.349169 0.717470
# weather    SimpleTM_SWT      original    SWT_original       weather_SimpleTM_SWT_original_SimpleTM_SWT_original_custom_96_96_32_32_4_db4_None_None_1_0.3_5e-05_0.01_TST_256_2025_1_0 0.159247 0.205118 0.399057 0.494950 0.338871 0.724044
# weather    SimpleTM_SWT      original    SWT_original       weather_SimpleTM_SWT_original_SimpleTM_SWT_original_custom_96_96_32_32_4_db4_None_None_1_0.3_5e-05_0.01_TST_256_2025_1_1 0.157492 0.202645 0.396853 0.490583 0.334785 0.727084
# weather    SimpleTM_SWT      original    SWT_original       weather_SimpleTM_SWT_original_SimpleTM_SWT_original_custom_96_96_32_32_4_db4_None_None_1_0.3_5e-05_0.01_TST_256_2025_1_2 0.156970 0.202480 0.396195 0.489597 0.334514 0.727988
#
# Averaged results across repeated itr runs:
# Dataset         Variant      MSE      MAE     RMSE     MAPE     WAPE       R2  NumRuns
#   ETTh1       Conv_dual 0.370249 0.395867 0.608477 0.663431 0.494784 0.664260        3
#   ETTh1   Conv_original 0.368425 0.394059 0.606980 0.661306 0.492525 0.665914        3
#   ETTh1        FFT_dual 0.367786 0.395348 0.606451 0.666276 0.494136 0.666494        3
#   ETTh1    FFT_original 0.370150 0.394432 0.608399 0.661961 0.492990 0.664350        3
#   ETTh1     Hybrid_dual 0.372710 0.398729 0.610499 0.670948 0.498362 0.662028        3
#   ETTh1 Hybrid_original 0.371096 0.396552 0.609175 0.666049 0.495641 0.663492        3
#   ETTh1        SWT_dual 0.367838 0.395085 0.606495 0.664647 0.493807 0.666447        3
#   ETTh1    SWT_original 0.367434 0.393959 0.606160 0.661264 0.492399 0.666813        3
#   ETTm1       Conv_dual 0.322776 0.362552 0.568133 0.654771 0.457248 0.708949        3
#   ETTm1   Conv_original 0.322154 0.360735 0.567586 0.649313 0.454957 0.709510        3
#   ETTm1        FFT_dual 0.330619 0.366923 0.574991 0.656998 0.462760 0.701877        3
#   ETTm1    FFT_original 0.326866 0.363184 0.571721 0.652217 0.458045 0.705261        3
#   ETTm1     Hybrid_dual 0.323819 0.362470 0.569040 0.654646 0.457145 0.708009        3
#   ETTm1 Hybrid_original 0.323131 0.360800 0.568437 0.650553 0.455039 0.708629        3
#   ETTm1        SWT_dual 0.324805 0.363564 0.569903 0.655552 0.458525 0.707120        3
#   ETTm1    SWT_original 0.321638 0.360919 0.567130 0.651103 0.455189 0.709975        3
# weather       Conv_dual 0.164239 0.211530 0.405254 0.505015 0.349465 0.715393        3
# weather   Conv_original 0.158594 0.204254 0.398238 0.492388 0.337444 0.725175        3
# weather        FFT_dual 0.165938 0.212918 0.407345 0.503042 0.351758 0.712448        3
# weather    FFT_original 0.178727 0.217056 0.422761 0.497239 0.358594 0.690286        3
# weather     Hybrid_dual 0.162170 0.209649 0.402703 0.500721 0.346357 0.718978        3
# weather Hybrid_original 0.157929 0.203439 0.397398 0.489954 0.336098 0.726328        3
# weather        SWT_dual 0.163349 0.210180 0.404144 0.503066 0.347234 0.716935        3
# weather    SWT_original 0.157903 0.203414 0.397368 0.491710 0.336057 0.726372        3
#
# Saved raw results to: /kaggle/working/SimpleTM_Paper96_AllVariants_Results/raw_metrics.csv
# Saved averaged results to: /kaggle/working/SimpleTM_Paper96_AllVariants_Results/averaged_metrics.csv
# Saved final table to: /kaggle/working/SimpleTM_Paper96_AllVariants_Results/final_metrics.csv

# %%
print("Packing logs, weights, plots, and results...")
archive_path = shutil.make_archive('/kaggle/working/SimpleTM_Paper96_AllVariants_Results', 'zip', OUTPUT_DIR)
print(f"\nDONE! Download {archive_path} from the Kaggle Output pane.")
# Out:
# Packing logs, weights, plots, and results...
#
# DONE! Download /kaggle/working/SimpleTM_Paper96_AllVariants_Results.zip from the Kaggle Output pane.
