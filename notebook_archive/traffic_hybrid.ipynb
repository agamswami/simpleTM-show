# %% [markdown]
# # SimpleTMG traffic Hybrid - Lightning AI

# %%
# !pip install PyWavelets gdown --quiet

import os
import sys
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"

import glob
import re
import shutil
import subprocess
import zipfile

import pandas as pd
import torch
from IPython.display import display

PYTHON_BIN = sys.executable
BASE_DIR = os.path.abspath("./lightning_runs")
os.makedirs(BASE_DIR, exist_ok=True)

print(f"Python executable: {PYTHON_BIN}")
print(f"Base directory: {BASE_DIR}")
print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
# Out:
# Python executable: /home/zeus/miniconda3/envs/cloudspace/bin/python
# Base directory: /teamspace/studios/this_studio/lightning_runs
# PyTorch version: 2.8.0+cu128
# CUDA available: True
# GPU: NVIDIA L4

# %%
REPO_URL = "https://github.com/agamswami/simpleTM-show"
REPO_DIR = os.path.join(BASE_DIR, "SimpleTM")

if os.path.exists(REPO_DIR):
    print("Repo already exists. Pulling latest changes...")
    subprocess.run(["git", "-C", REPO_DIR, "pull"], check=True)
else:
    subprocess.run(["git", "clone", REPO_URL, REPO_DIR], check=True)

os.chdir(REPO_DIR)
print(f"Working directory: {os.getcwd()}")

subprocess.run(["sed", "-i", r"s/np\.Inf/np.inf/g", "utils/tools.py"], check=True)

with open("run.py", "r", encoding="utf-8") as f:
    run_source = f.read()

required_flags = [
    "--hybrid_gate_mode",
    "--hybrid_branch_dropout",
    "--hybrid_gate_temperature",
    "--hybrid_residual_branch",
]
missing_flags = [flag for flag in required_flags if flag not in run_source]
if missing_flags:
    raise RuntimeError(f"This GitHub clone is missing Hybrid ablation flags: {missing_flags}. Push the local code changes before running this notebook.")

print("Hybrid ablation CLI flags found in run.py")
# Out:
# Cloning into '/teamspace/studios/this_studio/lightning_runs/SimpleTM'...
#
# Working directory: /teamspace/studios/this_studio/lightning_runs/SimpleTM
# Hybrid ablation CLI flags found in run.py

# %%
FILE_ID = "1JOgmL2ntyxKg6eB132ytCbVZumiHnDLR"
OUTPUT_PATH = os.path.join(BASE_DIR, "dataset.zip")
DATASET_DIR = os.path.join(REPO_DIR, "dataset")

if not os.path.exists(DATASET_DIR):
    download_url = f"https://drive.google.com/uc?id={FILE_ID}"
    subprocess.run(["gdown", download_url, "-O", OUTPUT_PATH], check=True)
    if not os.path.exists(OUTPUT_PATH):
        raise FileNotFoundError(f"Dataset download failed: {OUTPUT_PATH}")
    os.makedirs(DATASET_DIR, exist_ok=True)
    with zipfile.ZipFile(OUTPUT_PATH, "r") as zip_ref:
        zip_ref.extractall(DATASET_DIR)
    print("Dataset extracted successfully.")
else:
    print("Dataset already exists.")

for root, dirs, files in os.walk(DATASET_DIR):
    level = root.replace(DATASET_DIR, "").count(os.sep)
    indent = " " * 2 * level
    print(f"{indent}{os.path.basename(root)}/")
    subindent = " " * 2 * (level + 1)
    for file in files[:8]:
        print(f"{subindent}{file}")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1JOgmL2ntyxKg6eB132ytCbVZumiHnDLR
# From (redirected): https://drive.google.com/uc?id=1JOgmL2ntyxKg6eB132ytCbVZumiHnDLR&confirm=t&uuid=f6a7dd2f-1c12-423d-b8b3-7a2638f9247f
# To: /teamspace/studios/this_studio/lightning_runs/dataset.zip
# 100%|██████████| 172M/172M [00:01<00:00, 104MB/s]
# Dataset extracted successfully.
# dataset/
#   SimpleTM_datasets/
#     .DS_Store
#     smartbuilding/
#       smart.csv
#     traffic/
#       traffic.csv
#       .DS_Store
#     ETT-small/
#       ETTm2.csv
#       ETTh2.csv
#       ETTm1.csv
#       ETTh1.csv
#     Solar/
#       solar_AL.txt
#     PEMS/
#       PEMS07.npz
#       PEMS08.npz
#       PEMS04.npz
#       PEMS03.npz
#     electricity/
#       .DS_Store
#       electricity.csv
#     weather/
#       weather.csv
#   __MACOSX/
#     ._SimpleTM_datasets
#     SimpleTM_datasets/
#       ._weather
#       ._ETT-small
#       ._PEMS
#       ._electricity
#       ._traffic
#       ._Solar
#       ._.DS_Store
#       traffic/
#         ._traffic.csv
#         ._.DS_Store
#       ETT-small/
#         ._ETTh2.csv
#         ._ETTh1.csv
#         ._ETTm1.csv
#         ._ETTm2.csv
#       Solar/
#         ._solar_AL.txt
#       PEMS/
#         ._PEMS03.npz
#         ._PEMS04.npz
#         ._PEMS07.npz
#         ._PEMS08.npz
#       electricity/
#         ._electricity.csv
#         ._.DS_Store
#       weather/
#         ._weather.csv

# %%
# Set selectors to None for the full grid.
# For large datasets on Lightning, start with one attention mode and 1-2 configs, then expand.
SELECTED_DATASETS = ["traffic"]
SELECTED_ATTENTION_MODES = None
SELECTED_HYBRID_CONFIGS = None

# Residual fallback branch used by ResidualFallback and CombinedSparse configs.
# Change to "fft" or "conv" if previous results show those are stronger for the target dataset.
DEFAULT_RESIDUAL_BRANCH = "swt"

all_datasets = [
    {"name": "ETTh1", "data": "ETTh1", "root": "./dataset/SimpleTM_datasets/ETT-small", "path": "ETTh1.csv", "enc_in": 7, "d_model": 32, "d_ff": 32, "e_layers": 1, "wv": "db1", "m": 3, "alpha": 0.3, "learning_rate": 0.02, "batch_size": 256, "train_epochs": 10, "patience": 3, "use_norm": 1, "lradj": "TST", "freq": "h", "itr": 3, "l1_weight": 0.0005},
    {"name": "ETTm1", "data": "ETTm1", "root": "./dataset/SimpleTM_datasets/ETT-small", "path": "ETTm1.csv", "enc_in": 7, "d_model": 32, "d_ff": 32, "e_layers": 1, "wv": "db1", "m": 3, "alpha": 0.1, "learning_rate": 0.02, "batch_size": 256, "train_epochs": 10, "patience": 3, "use_norm": 1, "lradj": "TST", "freq": "t", "itr": 3, "l1_weight": 0.005},
    {"name": "weather", "data": "custom", "root": "./dataset/SimpleTM_datasets/weather", "path": "weather.csv", "enc_in": 21, "d_model": 32, "d_ff": 32, "e_layers": 4, "wv": "db4", "m": 3, "alpha": 0.3, "learning_rate": 0.01, "batch_size": 256, "train_epochs": 10, "patience": 3, "use_norm": 1, "lradj": "TST", "freq": "h", "itr": 3, "l1_weight": 5e-05},
    {"name": "electricity", "data": "custom", "root": "./dataset/SimpleTM_datasets/electricity", "path": "electricity.csv", "enc_in": 321, "d_model": 256, "d_ff": 1024, "e_layers": 1, "wv": "db1", "m": 3, "alpha": 0.0, "learning_rate": 0.01, "batch_size": 256, "train_epochs": 10, "patience": 3, "use_norm": 1, "lradj": "TST", "freq": "h", "itr": 1, "l1_weight": 0.0},
    {"name": "traffic", "data": "custom", "root": "./dataset/SimpleTM_datasets/traffic", "path": "traffic.csv", "enc_in": 862, "d_model": 512, "d_ff": 1024, "e_layers": 2, "wv": "db1", "m": 3, "alpha": 0.1, "learning_rate": 0.003, "batch_size": 24, "train_epochs": 10, "patience": 3, "use_norm": 1, "lradj": "TST", "freq": "h", "itr": 1, "l1_weight": 0.0},
    {"name": "Solar", "data": "Solar", "root": "./dataset/SimpleTM_datasets/Solar", "path": "solar_AL.txt", "enc_in": 137, "d_model": 128, "d_ff": 256, "e_layers": 1, "wv": "db8", "m": 3, "alpha": 0.0, "learning_rate": 0.01, "batch_size": 256, "train_epochs": 10, "patience": 3, "use_norm": 0, "lradj": "TST", "freq": "h", "itr": 3, "l1_weight": 0.005},
    {"name": "smartbuilding", "data": "custom", "root": "./dataset/SimpleTM_datasets/smartbuilding", "path": "smart.csv", "enc_in": 37, "d_model": 64, "d_ff": 128, "e_layers": 1, "wv": "db4", "m": 3, "alpha": 0.3, "learning_rate": 0.003, "batch_size": 64, "train_epochs": 20, "patience": 5, "use_norm": 1, "lradj": "TST", "freq": "h", "itr": 3, "l1_weight": 5e-05, "target": "Floor_Total(kW)"},
]

hybrid_configs = [
    # {"tag": "Baseline", "gate_mode": "soft", "branch_dropout": 0.0, "gate_temperature": 0.5, "residual_branch": "none"},
    # {"tag": "BranchDropout", "gate_mode": "soft", "branch_dropout": 0.15, "gate_temperature": 0.5, "residual_branch": "none"},
    # {"tag": "SparseGate", "gate_mode": "sparse", "branch_dropout": 0.0, "gate_temperature": 0.3, "residual_branch": "none"},
    # {"tag": "OneHotGate", "gate_mode": "one_hot", "branch_dropout": 0.0, "gate_temperature": 0.3, "residual_branch": "none"},
    # {"tag": "ResidualFallback", "gate_mode": "soft", "branch_dropout": 0.0, "gate_temperature": 0.5, "residual_branch": DEFAULT_RESIDUAL_BRANCH},
    {"tag": "CombinedSparse", "gate_mode": "sparse", "branch_dropout": 0.15, "gate_temperature": 0.3, "residual_branch": DEFAULT_RESIDUAL_BRANCH},
]

if SELECTED_DATASETS is None:
    datasets = list(all_datasets)
else:
    available_dataset_names = {ds["name"] for ds in all_datasets}
    missing_datasets = sorted(set(SELECTED_DATASETS) - available_dataset_names)
    if missing_datasets:
        raise ValueError(f"Unknown dataset(s): {missing_datasets}. Available: {sorted(available_dataset_names)}")
    datasets = [ds for ds in all_datasets if ds["name"] in SELECTED_DATASETS]
if not datasets:
    raise ValueError("No datasets selected. Check SELECTED_DATASETS.")

if SELECTED_ATTENTION_MODES is None:
    attention_modes = ["original", "dual"]
else:
    valid_attention_modes = {"original", "dual"}
    missing_attention_modes = sorted(set(SELECTED_ATTENTION_MODES) - valid_attention_modes)
    if missing_attention_modes:
        raise ValueError(f"Unknown attention mode(s): {missing_attention_modes}. Available: {sorted(valid_attention_modes)}")
    attention_modes = list(SELECTED_ATTENTION_MODES)
if not attention_modes:
    raise ValueError("No attention modes selected.")

if SELECTED_HYBRID_CONFIGS is None:
    configs = list(hybrid_configs)
else:
    available_config_tags = {cfg["tag"] for cfg in hybrid_configs}
    missing_configs = sorted(set(SELECTED_HYBRID_CONFIGS) - available_config_tags)
    if missing_configs:
        raise ValueError(f"Unknown Hybrid config(s): {missing_configs}. Available: {sorted(available_config_tags)}")
    configs = [cfg for cfg in hybrid_configs if cfg["tag"] in SELECTED_HYBRID_CONFIGS]
if not configs:
    raise ValueError("No Hybrid configs selected.")

# This setup cell resets previous outputs. Do not rerun it after training unless you want to start over.
OUTPUT_DIR = os.path.join(BASE_DIR, "SimpleTM_HybridFeatureAblation_Results")
if os.path.exists(OUTPUT_DIR):
    shutil.rmtree(OUTPUT_DIR)
os.makedirs(OUTPUT_DIR, exist_ok=True)

LOG_DIR = os.path.join(OUTPUT_DIR, "logs")
os.makedirs(LOG_DIR, exist_ok=True)

for path in ["./checkpoints", "result_long_term_forecast.txt"]:
    if os.path.isdir(path):
        shutil.rmtree(path)
    elif os.path.exists(path):
        os.remove(path)

print("Datasets selected:")
for ds in datasets:
    print(f"- {ds['name']}: epochs={ds['train_epochs']}, itr={ds['itr']}, d_model={ds['d_model']}, batch={ds['batch_size']}, alpha={ds['alpha']}")
print("\nAttention modes selected:")
for mode in attention_modes:
    print(f"- {mode}")
print("\nHybrid configs selected:")
for cfg in configs:
    print(f"- {cfg['tag']}: gate={cfg['gate_mode']}, dropout={cfg['branch_dropout']}, temp={cfg['gate_temperature']}, residual={cfg['residual_branch']}")
# Out:
# Datasets selected:
# - traffic: epochs=10, itr=1, d_model=512, batch=24, alpha=0.1
#
# Attention modes selected:
# - original
# - dual
#
# Hybrid configs selected:
# - CombinedSparse: gate=sparse, dropout=0.15, temp=0.3, residual=swt

# %%
for ds in datasets:
    print("\n" + "=" * 100)
    print(f"DATASET: {ds['name']} | variates={ds['enc_in']} | Hybrid feature ablation")
    print("=" * 100 + "\n")

    for attention_mode in attention_modes:
        for cfg in configs:
            run_tag = f"{attention_mode}_{cfg['tag']}"
            print(f">>> Training Hybrid {run_tag} on {ds['name']} <<<\n")
            unique_model_id = f"{ds['name']}_SimpleTM_Hybrid_{attention_mode}_{cfg['tag']}"

            cmd = [
                PYTHON_BIN, "-u", "run.py",
                "--is_training", "1",
                "--model", "SimpleTM_Hybrid",
                "--attention_mode", attention_mode,
                "--model_id", unique_model_id,
                "--data", ds["data"],
                "--root_path", ds["root"],
                "--data_path", ds["path"],
                "--features", "M",
                "--freq", ds["freq"],
                "--seq_len", "96",
                "--pred_len", "96",
                "--e_layers", str(ds["e_layers"]),
                "--d_model", str(ds["d_model"]),
                "--d_ff", str(ds["d_ff"]),
                "--enc_in", str(ds["enc_in"]),
                "--dec_in", str(ds["enc_in"]),
                "--c_out", str(ds["enc_in"]),
                "--wv", ds["wv"],
                "--m", str(ds["m"]),
                "--alpha", str(ds["alpha"]),
                "--l1_weight", str(ds["l1_weight"]),
                "--learning_rate", str(ds["learning_rate"]),
                "--batch_size", str(ds["batch_size"]),
                "--train_epochs", str(ds["train_epochs"]),
                "--patience", str(ds["patience"]),
                "--itr", str(ds["itr"]),
                "--num_workers", "2",
                "--lradj", ds["lradj"],
                "--use_norm", str(ds["use_norm"]),
                "--hybrid_gate_mode", cfg["gate_mode"],
                "--hybrid_branch_dropout", str(cfg["branch_dropout"]),
                "--hybrid_gate_temperature", str(cfg["gate_temperature"]),
                "--hybrid_residual_branch", cfg["residual_branch"],
                "--checkpoints", f"{OUTPUT_DIR}/checkpoints/",
                "--fix_seed", "2025",
                "--des", "HybridFeatureAblation",
            ]

            if "conv_kernel_sizes" in ds:
                cmd.extend(["--conv_kernel_sizes", ds["conv_kernel_sizes"]])
            if "target" in ds:
                cmd.extend(["--target", ds["target"]])

            log_file = os.path.join(LOG_DIR, f"{ds['name']}_{run_tag}.log")
            log_lines = []
            process = subprocess.Popen(cmd, stdout=subprocess.PIPE, stderr=subprocess.STDOUT, text=True)
            for line in process.stdout:
                print(line, end="")
                log_lines.append(line)
            process.wait()
            with open(log_file, "w", encoding="utf-8") as f:
                f.writelines(log_lines)
            print(f"Saved run log to: {log_file}")

            if process.returncode == 0:
                print(f"\nSUCCESS: Finished Hybrid {run_tag} on {ds['name']}\n")
            else:
                raise RuntimeError(f"Run failed for {ds['name']} | Hybrid {run_tag} with exit code {process.returncode}")

print("\nGathering generated plots and metric text...")
if os.path.exists("./checkpoints"):
    for root_dir, dirs, files in os.walk("./checkpoints"):
        for file in files:
            if file.endswith(".pdf") or file.endswith(".png"):
                folder_name = os.path.basename(root_dir)
                source_path = os.path.join(root_dir, file)
                target_plot_dir = os.path.join(OUTPUT_DIR, "plots", folder_name)
                os.makedirs(target_plot_dir, exist_ok=True)
                shutil.copy(source_path, os.path.join(target_plot_dir, file))

if os.path.exists("result_long_term_forecast.txt"):
    shutil.copy("result_long_term_forecast.txt", os.path.join(OUTPUT_DIR, "result_long_term_forecast.txt"))
    print("Copied metric text results to output directory.")
# Out:
# ====================================================================================================
# DATASET: traffic | variates=862 | Hybrid feature ablation
# ====================================================================================================
#
# >>> Training Hybrid original_CombinedSparse on traffic <<<
#
# Args in experiment:
# Namespace(is_training=1, model_id='traffic_SimpleTM_Hybrid_original_CombinedSparse', model='SimpleTM_Hybrid', data='custom', root_path='./dataset/SimpleTM_datasets/traffic', data_path='traffic.csv', features='M', target='OT', freq='h', checkpoints='/teamspace/studios/this_studio/lightning_runs/SimpleTM_HybridFeatureAblation_Results/checkpoints/', seq_len=96, label_len=0, pred_len=96, enc_in=862, dec_in=862, c_out=862, n_heads=8, d_layers=1, moving_avg=25, factor=1, distil=True, dropout=0.1, geomattn_dropout=0.5, embed='timeF', activation='gelu', do_predict=False, num_workers=2, itr=1, train_epochs=10, batch_size=24, patience=3, learning_rate=0.003, des='HybridFeatureAblation', loss='MSE', lradj='TST', pct_start=0.2, use_amp=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', exp_name='MTSF', channel_independence=False, inverse=False, class_strategy='projection', target_root_path='./data/electricity/', target_data_path='electricity.csv', efficient_training=False, use_norm=1, partial_start_index=0, requires_grad=True, wv='db1', m=3, kernel_size=None, conv_kernel_sizes=None, hybrid_gate_mode='sparse', hybrid_branch_dropout=0.15, hybrid_gate_temperature=0.3, hybrid_residual_branch='swt', alpha=0.1, learnable_alpha=False, l1_weight=0.0, d_model=512, d_ff=1024, e_layers=2, compile=False, output_attention=False, attention_mode='original', fix_seed=2025)
# Use GPU: cuda:0
# Total trainable parameters: 8032376.0
# Memory usage for trainable parameters: 30.64 MB
# Static memory footprint (allocated): 30.65 MB
# Static memory footprint (reserved): 50.00 MB
# >>>>>>>start training : traffic_SimpleTM_Hybrid_original_CombinedSparse_SimpleTM_Hybrid_original_custom_96_96_512_1024_2_db1_None_None_sparse_0.15_0.3_swt_3_0.1_False_0.0_0.003_TST_24_2025_1_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 12089
# val 1661
# test 3413
# 	iters: 30, epoch: 1 | loss: 0.5631110
# 	speed: 1.6484s/iter; left time: 8243.7758s
# 	iters: 60, epoch: 1 | loss: 0.4215070
# 	speed: 1.6649s/iter; left time: 8276.3142s
# 	iters: 90, epoch: 1 | loss: 0.3992740
# 	speed: 1.6849s/iter; left time: 8325.3088s
# 	iters: 120, epoch: 1 | loss: 0.3373207
# 	speed: 1.6864s/iter; left time: 8281.8422s
# 	iters: 150, epoch: 1 | loss: 0.3292960
# 	speed: 1.6959s/iter; left time: 8277.7314s
# 	iters: 180, epoch: 1 | loss: 0.3119361
# 	speed: 1.6976s/iter; left time: 8235.1058s
# 	iters: 210, epoch: 1 | loss: 0.3343020
# 	speed: 1.6960s/iter; left time: 8176.1768s
# 	iters: 240, epoch: 1 | loss: 0.3514275
# 	speed: 1.6951s/iter; left time: 8121.1553s
# 	iters: 270, epoch: 1 | loss: 0.3297947
# 	speed: 1.7007s/iter; left time: 8097.0085s
# 	iters: 300, epoch: 1 | loss: 0.3373672
# 	speed: 1.6958s/iter; left time: 8022.9678s
# 	iters: 330, epoch: 1 | loss: 0.3374390
# 	speed: 1.6963s/iter; left time: 7974.1375s
# 	iters: 360, epoch: 1 | loss: 0.3319116
# 	speed: 1.6962s/iter; left time: 7923.0890s
# 	iters: 390, epoch: 1 | loss: 0.3130442
# 	speed: 1.6973s/iter; left time: 7877.3233s
# 	iters: 420, epoch: 1 | loss: 0.2917755
# 	speed: 1.6995s/iter; left time: 7836.1663s
# 	iters: 450, epoch: 1 | loss: 0.3193007
# 	speed: 1.6955s/iter; left time: 7767.2152s
# 	iters: 480, epoch: 1 | loss: 0.3036765
# 	speed: 1.6961s/iter; left time: 7718.8008s
# Epoch: 1 cost time: 851.5782630443573
# Epoch: 1, Steps: 503 | Train Loss: 0.3733748 Vali Loss: 0.4604985 Test Loss: 0.5116329
# Validation loss decreased (inf --> 0.460499).  Saving model ...
# Updating learning rate to 0.001562250692327989
# 	iters: 30, epoch: 2 | loss: 0.3575432
# 	speed: 6.5354s/iter; left time: 29396.1048s
# 	iters: 60, epoch: 2 | loss: 0.3492225
# 	speed: 1.6973s/iter; left time: 7583.5779s
# 	iters: 90, epoch: 2 | loss: 0.3155887
# 	speed: 1.6944s/iter; left time: 7519.9512s
# 	iters: 120, epoch: 2 | loss: 0.3440939
# 	speed: 1.6965s/iter; left time: 7478.2590s
# 	iters: 150, epoch: 2 | loss: 0.3032941
# 	speed: 1.6982s/iter; left time: 7434.9125s
# 	iters: 180, epoch: 2 | loss: 0.3044394
# 	speed: 1.6966s/iter; left time: 7376.9536s
# 	iters: 210, epoch: 2 | loss: 0.2940011
# 	speed: 1.6930s/iter; left time: 7310.4289s
# 	iters: 240, epoch: 2 | loss: 0.2950731
# 	speed: 1.6979s/iter; left time: 7280.7790s
# 	iters: 270, epoch: 2 | loss: 0.2910431
# 	speed: 1.6929s/iter; left time: 7208.5223s
# 	iters: 300, epoch: 2 | loss: 0.3112221
# 	speed: 1.6948s/iter; left time: 7165.5685s
# 	iters: 330, epoch: 2 | loss: 0.3194598
# 	speed: 1.6954s/iter; left time: 7117.1432s
# 	iters: 360, epoch: 2 | loss: 0.2778476
# 	speed: 1.6969s/iter; left time: 7072.6443s
# 	iters: 390, epoch: 2 | loss: 0.3021365
# 	speed: 1.6942s/iter; left time: 7010.4035s
# 	iters: 420, epoch: 2 | loss: 0.2530825
# 	speed: 1.6954s/iter; left time: 6964.8032s
# 	iters: 450, epoch: 2 | loss: 0.3126195
# 	speed: 1.6927s/iter; left time: 6902.7503s
# 	iters: 480, epoch: 2 | loss: 0.3120693
# 	speed: 1.6931s/iter; left time: 6853.6458s
# Epoch: 2 cost time: 853.1427471637726
# Epoch: 2, Steps: 503 | Train Loss: 0.3113456 Vali Loss: 0.4255297 Test Loss: 0.4781070
# Validation loss decreased (0.460499 --> 0.425530).  Saving model ...
# Updating learning rate to 0.00299999954286623
# 	iters: 30, epoch: 3 | loss: 0.2769932
# 	speed: 6.5290s/iter; left time: 26083.3387s
# 	iters: 60, epoch: 3 | loss: 0.3102221
# 	speed: 1.6941s/iter; left time: 6717.0466s
# 	iters: 90, epoch: 3 | loss: 0.2645885
# 	speed: 1.6968s/iter; left time: 6676.9924s
# 	iters: 120, epoch: 3 | loss: 0.3107620
# 	speed: 1.6906s/iter; left time: 6601.9389s
# 	iters: 150, epoch: 3 | loss: 0.2911733
# 	speed: 1.6889s/iter; left time: 6544.6377s
# 	iters: 180, epoch: 3 | loss: 0.2709680
# 	speed: 1.6902s/iter; left time: 6498.8411s
# 	iters: 210, epoch: 3 | loss: 0.2449294
# 	speed: 1.6868s/iter; left time: 6434.9748s
# 	iters: 240, epoch: 3 | loss: 0.2471179
# 	speed: 1.6935s/iter; left time: 6410.0215s
# 	iters: 270, epoch: 3 | loss: 0.2698515
# 	speed: 1.6880s/iter; left time: 6338.4810s
# 	iters: 300, epoch: 3 | loss: 0.2604352
# 	speed: 1.6901s/iter; left time: 6295.7824s
# 	iters: 330, epoch: 3 | loss: 0.3248943
# 	speed: 1.6889s/iter; left time: 6240.5247s
# 	iters: 360, epoch: 3 | loss: 0.2676111
# 	speed: 1.6921s/iter; left time: 6201.3941s
# 	iters: 390, epoch: 3 | loss: 0.2953226
# 	speed: 1.6888s/iter; left time: 6138.7115s
# 	iters: 420, epoch: 3 | loss: 0.2989882
# 	speed: 1.6888s/iter; left time: 6088.1711s
# 	iters: 450, epoch: 3 | loss: 0.3102979
# 	speed: 1.6921s/iter; left time: 6049.2470s
# 	iters: 480, epoch: 3 | loss: 0.2834671
# 	speed: 1.6861s/iter; left time: 5977.3004s
# Epoch: 3 cost time: 850.4760601520538
# Epoch: 3, Steps: 503 | Train Loss: 0.2809703 Vali Loss: 0.4085387 Test Loss: 0.4563916
# Validation loss decreased (0.425530 --> 0.408539).  Saving model ...
# Updating learning rate to 0.0028853711855903173
# 	iters: 30, epoch: 4 | loss: 0.3048107
# 	speed: 6.5173s/iter; left time: 22758.3710s
# 	iters: 60, epoch: 4 | loss: 0.2366451
# 	speed: 1.6878s/iter; left time: 5843.0865s
# 	iters: 90, epoch: 4 | loss: 0.2882370
# 	speed: 1.6926s/iter; left time: 5808.9289s
# 	iters: 120, epoch: 4 | loss: 0.2665284
# 	speed: 1.6858s/iter; left time: 5735.0648s
# 	iters: 150, epoch: 4 | loss: 0.2578996
# 	speed: 1.6857s/iter; left time: 5684.2178s
# 	iters: 180, epoch: 4 | loss: 0.2495680
# 	speed: 1.6842s/iter; left time: 5628.5565s
# 	iters: 210, epoch: 4 | loss: 0.2810884
# 	speed: 1.6865s/iter; left time: 5585.8362s
# 	iters: 240, epoch: 4 | loss: 0.3076481
# 	speed: 1.6840s/iter; left time: 5526.8102s
# 	iters: 270, epoch: 4 | loss: 0.2303794
# 	speed: 1.6871s/iter; left time: 5486.4105s
# 	iters: 300, epoch: 4 | loss: 0.2537372
# 	speed: 1.6902s/iter; left time: 5445.9572s
# 	iters: 330, epoch: 4 | loss: 0.2791010
# 	speed: 1.6842s/iter; left time: 5375.8351s
# 	iters: 360, epoch: 4 | loss: 0.2960703
# 	speed: 1.6846s/iter; left time: 5326.7940s
# 	iters: 390, epoch: 4 | loss: 0.2450664
# 	speed: 1.6862s/iter; left time: 5281.1762s
# 	iters: 420, epoch: 4 | loss: 0.2971103
# 	speed: 1.6869s/iter; left time: 5232.7044s
# 	iters: 450, epoch: 4 | loss: 0.2684355
# 	speed: 1.6878s/iter; left time: 5184.7842s
# 	iters: 480, epoch: 4 | loss: 0.2473686
# 	speed: 1.6838s/iter; left time: 5122.0190s
# Epoch: 4 cost time: 848.4853491783142
# Epoch: 4, Steps: 503 | Train Loss: 0.2656633 Vali Loss: 0.4020043 Test Loss: 0.4509304
# Validation loss decreased (0.408539 --> 0.402004).  Saving model ...
# Updating learning rate to 0.0025598335371749582
# 	iters: 30, epoch: 5 | loss: 0.2388378
# 	speed: 6.5178s/iter; left time: 19481.5692s
# 	iters: 60, epoch: 5 | loss: 0.2485498
# 	speed: 1.6851s/iter; left time: 4986.2241s
# 	iters: 90, epoch: 5 | loss: 0.2529537
# 	speed: 1.6841s/iter; left time: 4932.7949s
# 	iters: 120, epoch: 5 | loss: 0.2601853
# 	speed: 1.6870s/iter; left time: 4890.5884s
# 	iters: 150, epoch: 5 | loss: 0.2414155
# 	speed: 1.6847s/iter; left time: 4833.4475s
# 	iters: 180, epoch: 5 | loss: 0.2453944
# 	speed: 1.6847s/iter; left time: 4782.8340s
# 	iters: 210, epoch: 5 | loss: 0.2460963
# 	speed: 1.6843s/iter; left time: 4731.2269s
# 	iters: 240, epoch: 5 | loss: 0.2338623
# 	speed: 1.6852s/iter; left time: 4683.0945s
# 	iters: 270, epoch: 5 | loss: 0.2793652
# 	speed: 1.6894s/iter; left time: 4644.0791s
# 	iters: 300, epoch: 5 | loss: 0.2732994
# 	speed: 1.6876s/iter; left time: 4588.4945s
# 	iters: 330, epoch: 5 | loss: 0.2442695
# 	speed: 1.6869s/iter; left time: 4536.1654s
# 	iters: 360, epoch: 5 | loss: 0.2351995
# 	speed: 1.6839s/iter; left time: 4477.5794s
# 	iters: 390, epoch: 5 | loss: 0.2296095
# 	speed: 1.6883s/iter; left time: 4438.5257s
# 	iters: 420, epoch: 5 | loss: 0.2684279
# 	speed: 1.6851s/iter; left time: 4379.5905s
# 	iters: 450, epoch: 5 | loss: 0.2404165
# 	speed: 1.6844s/iter; left time: 4327.3432s
# 	iters: 480, epoch: 5 | loss: 0.2527253
# 	speed: 1.6896s/iter; left time: 4289.9396s
# Epoch: 5 cost time: 848.4005665779114
# Epoch: 5, Steps: 503 | Train Loss: 0.2546485 Vali Loss: 0.3887153 Test Loss: 0.4389955
# Validation loss decreased (0.402004 --> 0.388715).  Saving model ...
# Updating learning rate to 0.0020729467535852606
# 	iters: 30, epoch: 6 | loss: 0.2560807
# 	speed: 6.5140s/iter; left time: 16193.8825s
# 	iters: 60, epoch: 6 | loss: 0.2240754
# 	speed: 1.6848s/iter; left time: 4137.8828s
# 	iters: 90, epoch: 6 | loss: 0.2592098
# 	speed: 1.6893s/iter; left time: 4098.1902s
# 	iters: 120, epoch: 6 | loss: 0.2507513
# 	speed: 1.6945s/iter; left time: 4059.9445s
# 	iters: 150, epoch: 6 | loss: 0.2441781
# 	speed: 1.6891s/iter; left time: 3996.3229s
# 	iters: 180, epoch: 6 | loss: 0.2621392
# 	speed: 1.6860s/iter; left time: 3938.4532s
# 	iters: 210, epoch: 6 | loss: 0.2693559
# 	speed: 1.6866s/iter; left time: 3889.2318s
# 	iters: 240, epoch: 6 | loss: 0.2745646
# 	speed: 1.6888s/iter; left time: 3843.7791s
# 	iters: 270, epoch: 6 | loss: 0.2190073
# 	speed: 1.6850s/iter; left time: 3784.6103s
# 	iters: 300, epoch: 6 | loss: 0.2213915
# 	speed: 1.6861s/iter; left time: 3736.3452s
# 	iters: 330, epoch: 6 | loss: 0.2353760
# 	speed: 1.6882s/iter; left time: 3690.3906s
# 	iters: 360, epoch: 6 | loss: 0.2364010
# 	speed: 1.6853s/iter; left time: 3633.4648s
# 	iters: 390, epoch: 6 | loss: 0.2529449
# 	speed: 1.6850s/iter; left time: 3582.3242s
# 	iters: 420, epoch: 6 | loss: 0.2548241
# 	speed: 1.6848s/iter; left time: 3531.3176s
# 	iters: 450, epoch: 6 | loss: 0.2570812
# 	speed: 1.6855s/iter; left time: 3482.2533s
# 	iters: 480, epoch: 6 | loss: 0.2421971
# 	speed: 1.6875s/iter; left time: 3435.6630s
# Epoch: 6 cost time: 848.6528997421265
# Epoch: 6, Steps: 503 | Train Loss: 0.2445215 Vali Loss: 0.3854638 Test Loss: 0.4315622
# Validation loss decreased (0.388715 --> 0.385464).  Saving model ...
# Updating learning rate to 0.0014988349339830718
# 	iters: 30, epoch: 7 | loss: 0.2229659
# 	speed: 6.5079s/iter; left time: 12905.2371s
# 	iters: 60, epoch: 7 | loss: 0.2233890
# 	speed: 1.6846s/iter; left time: 3289.9712s
# 	iters: 90, epoch: 7 | loss: 0.2256103
# 	speed: 1.6903s/iter; left time: 3250.4652s
# 	iters: 120, epoch: 7 | loss: 0.2477831
# 	speed: 1.6891s/iter; left time: 3197.4831s
# 	iters: 150, epoch: 7 | loss: 0.2442982
# 	speed: 1.6878s/iter; left time: 3144.4097s
# 	iters: 180, epoch: 7 | loss: 0.2104300
# 	speed: 1.6862s/iter; left time: 3090.7848s
# 	iters: 210, epoch: 7 | loss: 0.2528551
# 	speed: 1.6867s/iter; left time: 3041.1561s
# 	iters: 240, epoch: 7 | loss: 0.2429123
# 	speed: 1.6841s/iter; left time: 2985.9820s
# 	iters: 270, epoch: 7 | loss: 0.2137931
# 	speed: 1.6861s/iter; left time: 2938.9155s
# 	iters: 300, epoch: 7 | loss: 0.2409182
# 	speed: 1.6869s/iter; left time: 2889.6413s
# 	iters: 330, epoch: 7 | loss: 0.2330557
# 	speed: 1.6908s/iter; left time: 2845.5511s
# 	iters: 360, epoch: 7 | loss: 0.2300044
# 	speed: 1.6868s/iter; left time: 2788.2045s
# 	iters: 390, epoch: 7 | loss: 0.2499274
# 	speed: 1.6863s/iter; left time: 2736.8462s
# 	iters: 420, epoch: 7 | loss: 0.2641544
# 	speed: 1.6887s/iter; left time: 2690.0936s
# 	iters: 450, epoch: 7 | loss: 0.2262606
# 	speed: 1.6855s/iter; left time: 2634.5034s
# 	iters: 480, epoch: 7 | loss: 0.2246774
# 	speed: 1.6834s/iter; left time: 2580.6148s
# Epoch: 7 cost time: 848.6321275234222
# Epoch: 7, Steps: 503 | Train Loss: 0.2356663 Vali Loss: 0.3743465 Test Loss: 0.4201425
# Validation loss decreased (0.385464 --> 0.374347).  Saving model ...
# Updating learning rate to 0.0009249013985662202
# 	iters: 30, epoch: 8 | loss: 0.2550495
# 	speed: 6.5219s/iter; left time: 9652.3533s
# 	iters: 60, epoch: 8 | loss: 0.2306845
# 	speed: 1.6861s/iter; left time: 2444.8900s
# 	iters: 90, epoch: 8 | loss: 0.2594982
# 	speed: 1.6848s/iter; left time: 2392.3680s
# 	iters: 120, epoch: 8 | loss: 0.2148566
# 	speed: 1.6870s/iter; left time: 2344.8790s
# 	iters: 150, epoch: 8 | loss: 0.2292182
# 	speed: 1.6870s/iter; left time: 2294.2888s
# 	iters: 180, epoch: 8 | loss: 0.2269336
# 	speed: 1.6891s/iter; left time: 2246.5516s
# 	iters: 210, epoch: 8 | loss: 0.2173310
# 	speed: 1.6856s/iter; left time: 2191.2212s
# 	iters: 240, epoch: 8 | loss: 0.2295318
# 	speed: 1.6861s/iter; left time: 2141.3730s
# 	iters: 270, epoch: 8 | loss: 0.2363697
# 	speed: 1.6866s/iter; left time: 2091.4141s
# 	iters: 300, epoch: 8 | loss: 0.2530799
# 	speed: 1.6847s/iter; left time: 2038.4490s
# 	iters: 330, epoch: 8 | loss: 0.2149395
# 	speed: 1.6859s/iter; left time: 1989.3218s
# 	iters: 360, epoch: 8 | loss: 0.2578500
# 	speed: 1.6893s/iter; left time: 1942.6835s
# 	iters: 390, epoch: 8 | loss: 0.2325054
# 	speed: 1.6861s/iter; left time: 1888.4728s
# 	iters: 420, epoch: 8 | loss: 0.2641113
# 	speed: 1.6855s/iter; left time: 1837.1707s
# 	iters: 450, epoch: 8 | loss: 0.2234327
# 	speed: 1.6855s/iter; left time: 1786.6622s
# 	iters: 480, epoch: 8 | loss: 0.2055821
# 	speed: 1.6835s/iter; left time: 1733.9782s
# Epoch: 8 cost time: 848.6508963108063
# Epoch: 8, Steps: 503 | Train Loss: 0.2268949 Vali Loss: 0.3697376 Test Loss: 0.4144897
# Validation loss decreased (0.374347 --> 0.369738).  Saving model ...
# Updating learning rate to 0.0004385223253814674
# 	iters: 30, epoch: 9 | loss: 0.2081840
# 	speed: 6.5163s/iter; left time: 6366.4219s
# 	iters: 60, epoch: 9 | loss: 0.2175197
# 	speed: 1.6839s/iter; left time: 1594.6210s
# 	iters: 90, epoch: 9 | loss: 0.2153496
# 	speed: 1.6840s/iter; left time: 1544.2302s
# 	iters: 120, epoch: 9 | loss: 0.2156112
# 	speed: 1.6857s/iter; left time: 1495.2129s
# 	iters: 150, epoch: 9 | loss: 0.2262103
# 	speed: 1.6908s/iter; left time: 1449.0467s
# 	iters: 180, epoch: 9 | loss: 0.2458658
# 	speed: 1.6846s/iter; left time: 1393.1232s
# 	iters: 210, epoch: 9 | loss: 0.1997595
# 	speed: 1.6867s/iter; left time: 1344.3384s
# 	iters: 240, epoch: 9 | loss: 0.2260447
# 	speed: 1.6862s/iter; left time: 1293.3160s
# 	iters: 270, epoch: 9 | loss: 0.2415877
# 	speed: 1.6886s/iter; left time: 1244.4956s
# 	iters: 300, epoch: 9 | loss: 0.2090947
# 	speed: 1.6837s/iter; left time: 1190.3619s
# 	iters: 330, epoch: 9 | loss: 0.2338867
# 	speed: 1.6860s/iter; left time: 1141.3911s
# 	iters: 360, epoch: 9 | loss: 0.2160742
# 	speed: 1.6897s/iter; left time: 1093.2434s
# 	iters: 390, epoch: 9 | loss: 0.2138378
# 	speed: 1.6873s/iter; left time: 1041.0648s
# 	iters: 420, epoch: 9 | loss: 0.2162750
# 	speed: 1.6842s/iter; left time: 988.6099s
# 	iters: 450, epoch: 9 | loss: 0.2247589
# 	speed: 1.6855s/iter; left time: 938.8153s
# 	iters: 480, epoch: 9 | loss: 0.2179892
# 	speed: 1.6831s/iter; left time: 886.9799s
# Epoch: 9 cost time: 848.4161460399628
# Epoch: 9, Steps: 503 | Train Loss: 0.2203313 Vali Loss: 0.3621202 Test Loss: 0.4112332
# Validation loss decreased (0.369738 --> 0.362120).  Saving model ...
# Updating learning rate to 0.00011374451928391443
# 	iters: 30, epoch: 10 | loss: 0.2143164
# 	speed: 6.5249s/iter; left time: 3092.8220s
# 	iters: 60, epoch: 10 | loss: 0.2049954
# 	speed: 1.6854s/iter; left time: 748.3169s
# 	iters: 90, epoch: 10 | loss: 0.2329360
# 	speed: 1.6869s/iter; left time: 698.3852s
# 	iters: 120, epoch: 10 | loss: 0.2336738
# 	speed: 1.6912s/iter; left time: 649.4252s
# 	iters: 150, epoch: 10 | loss: 0.2230401
# 	speed: 1.6863s/iter; left time: 596.9457s
# 	iters: 180, epoch: 10 | loss: 0.2020417
# 	speed: 1.6863s/iter; left time: 546.3757s
# 	iters: 210, epoch: 10 | loss: 0.2038302
# 	speed: 1.6894s/iter; left time: 496.6981s
# 	iters: 240, epoch: 10 | loss: 0.2081528
# 	speed: 1.6854s/iter; left time: 444.9509s
# 	iters: 270, epoch: 10 | loss: 0.2085931
# 	speed: 1.6847s/iter; left time: 394.2113s
# 	iters: 300, epoch: 10 | loss: 0.2303034
# 	speed: 1.6856s/iter; left time: 343.8710s
# 	iters: 330, epoch: 10 | loss: 0.2117614
# 	speed: 1.6839s/iter; left time: 293.0024s
# 	iters: 360, epoch: 10 | loss: 0.2102707
# 	speed: 1.6876s/iter; left time: 243.0121s
# 	iters: 390, epoch: 10 | loss: 0.2188068
# 	speed: 1.6845s/iter; left time: 192.0274s
# 	iters: 420, epoch: 10 | loss: 0.1997631
# 	speed: 1.6851s/iter; left time: 141.5488s
# 	iters: 450, epoch: 10 | loss: 0.2114605
# 	speed: 1.6876s/iter; left time: 91.1278s
# 	iters: 480, epoch: 10 | loss: 0.2112688
# 	speed: 1.6857s/iter; left time: 40.4573s
# Epoch: 10 cost time: 848.5067234039307
# Epoch: 10, Steps: 503 | Train Loss: 0.2166957 Vali Loss: 0.3614703 Test Loss: 0.4097684
# Validation loss decreased (0.362120 --> 0.361470).  Saving model ...
# Updating learning rate to 1.2457133770165797e-08
# >>>>>>>testing : traffic_SimpleTM_Hybrid_original_CombinedSparse_SimpleTM_Hybrid_original_custom_96_96_512_1024_2_db1_None_None_sparse_0.15_0.3_swt_3_0.1_False_0.0_0.003_TST_24_2025_1_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 3413
# test shape: (142, 24, 96, 862) (142, 24, 96, 862)
# test shape: (3408, 96, 862) (3408, 96, 862)
# Collected 16 examples for combined_prediction_examples.png
# mse:0.40976905822753906, mae:0.26284554600715637
# rmse:0.6401320695877075, mape:0.45895254611968994, mspe:121342.359375
# rse:0.5298895020972976, corr:29.331804275512695, smape:0.47416770458221436, wape:0.3288000474077775, r2:0.7192171276016006
# Saved run log to: /teamspace/studios/this_studio/lightning_runs/SimpleTM_HybridFeatureAblation_Results/logs/traffic_original_CombinedSparse.log
#
# SUCCESS: Finished Hybrid original_CombinedSparse on traffic
#
# >>> Training Hybrid dual_CombinedSparse on traffic <<<
#
# Args in experiment:
# Namespace(is_training=1, model_id='traffic_SimpleTM_Hybrid_dual_CombinedSparse', model='SimpleTM_Hybrid', data='custom', root_path='./dataset/SimpleTM_datasets/traffic', data_path='traffic.csv', features='M', target='OT', freq='h', checkpoints='/teamspace/studios/this_studio/lightning_runs/SimpleTM_HybridFeatureAblation_Results/checkpoints/', seq_len=96, label_len=0, pred_len=96, enc_in=862, dec_in=862, c_out=862, n_heads=8, d_layers=1, moving_avg=25, factor=1, distil=True, dropout=0.1, geomattn_dropout=0.5, embed='timeF', activation='gelu', do_predict=False, num_workers=2, itr=1, train_epochs=10, batch_size=24, patience=3, learning_rate=0.003, des='HybridFeatureAblation', loss='MSE', lradj='TST', pct_start=0.2, use_amp=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', exp_name='MTSF', channel_independence=False, inverse=False, class_strategy='projection', target_root_path='./data/electricity/', target_data_path='electricity.csv', efficient_training=False, use_norm=1, partial_start_index=0, requires_grad=True, wv='db1', m=3, kernel_size=None, conv_kernel_sizes=None, hybrid_gate_mode='sparse', hybrid_branch_dropout=0.15, hybrid_gate_temperature=0.3, hybrid_residual_branch='swt', alpha=0.1, learnable_alpha=False, l1_weight=0.0, d_model=512, d_ff=1024, e_layers=2, compile=False, output_attention=False, attention_mode='dual', fix_seed=2025)
# Use GPU: cuda:0
# Total trainable parameters: 15034250.0
# Memory usage for trainable parameters: 57.35 MB
# Static memory footprint (allocated): 57.36 MB
# Static memory footprint (reserved): 70.00 MB
# >>>>>>>start training : traffic_SimpleTM_Hybrid_dual_CombinedSparse_SimpleTM_Hybrid_dual_custom_96_96_512_1024_2_db1_None_None_sparse_0.15_0.3_swt_3_0.1_False_0.0_0.003_TST_24_2025_1_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 12089
# val 1661
# test 3413
# 	iters: 30, epoch: 1 | loss: 0.5574022
# 	speed: 1.7819s/iter; left time: 8911.0499s
# 	iters: 60, epoch: 1 | loss: 0.4460456
# 	speed: 1.8061s/iter; left time: 8978.2617s
# 	iters: 90, epoch: 1 | loss: 0.3896335
# 	speed: 1.8060s/iter; left time: 8923.5329s
# 	iters: 120, epoch: 1 | loss: 0.3284233
# 	speed: 1.8001s/iter; left time: 8840.3261s
# 	iters: 150, epoch: 1 | loss: 0.3313300
# 	speed: 1.8088s/iter; left time: 8828.9776s
# 	iters: 180, epoch: 1 | loss: 0.3208797
# 	speed: 1.8014s/iter; left time: 8738.6093s
# 	iters: 210, epoch: 1 | loss: 0.3234870
# 	speed: 1.8034s/iter; left time: 8694.0603s
# 	iters: 240, epoch: 1 | loss: 0.3340864
# 	speed: 1.8036s/iter; left time: 8640.8693s
# 	iters: 270, epoch: 1 | loss: 0.3207077
# 	speed: 1.8053s/iter; left time: 8595.1217s
# 	iters: 300, epoch: 1 | loss: 0.3293876
# 	speed: 1.8042s/iter; left time: 8535.5891s
# 	iters: 330, epoch: 1 | loss: 0.3152505
# 	speed: 1.8052s/iter; left time: 8486.2267s
# 	iters: 360, epoch: 1 | loss: 0.2964507
# 	speed: 1.8002s/iter; left time: 8408.7354s
# 	iters: 390, epoch: 1 | loss: 0.3547170
# 	speed: 1.8034s/iter; left time: 8369.5241s
# 	iters: 420, epoch: 1 | loss: 0.4117568
# 	speed: 1.7980s/iter; left time: 8290.7218s
# 	iters: 450, epoch: 1 | loss: 0.4775888
# 	speed: 1.7949s/iter; left time: 8222.2893s
# 	iters: 480, epoch: 1 | loss: 0.3587516
# 	speed: 1.7994s/iter; left time: 8189.2702s
# Epoch: 1 cost time: 907.1578869819641
# Epoch: 1, Steps: 503 | Train Loss: 0.3805304 Vali Loss: 0.4722934 Test Loss: 0.5284969
# Validation loss decreased (inf --> 0.472293).  Saving model ...
# Updating learning rate to 0.001562250692327989
# 	iters: 30, epoch: 2 | loss: 0.3374425
# 	speed: 6.9458s/iter; left time: 31242.2673s
# 	iters: 60, epoch: 2 | loss: 0.3349673
# 	speed: 1.8025s/iter; left time: 8053.3558s
# 	iters: 90, epoch: 2 | loss: 0.3167009
# 	speed: 1.7977s/iter; left time: 7978.1308s
# 	iters: 120, epoch: 2 | loss: 0.3527081
# 	speed: 1.7934s/iter; left time: 7905.4540s
# 	iters: 150, epoch: 2 | loss: 0.3276633
# 	speed: 1.7929s/iter; left time: 7849.3981s
# 	iters: 180, epoch: 2 | loss: 0.3322532
# 	speed: 1.7959s/iter; left time: 7808.7821s
# 	iters: 210, epoch: 2 | loss: 0.3263242
# 	speed: 1.7968s/iter; left time: 7758.7926s
# 	iters: 240, epoch: 2 | loss: 0.3144932
# 	speed: 1.7940s/iter; left time: 7692.7115s
# 	iters: 270, epoch: 2 | loss: 0.3275551
# 	speed: 1.7915s/iter; left time: 7628.0763s
# 	iters: 300, epoch: 2 | loss: 0.3241754
# 	speed: 1.7971s/iter; left time: 7598.1345s
# 	iters: 330, epoch: 2 | loss: 0.2954281
# 	speed: 1.7896s/iter; left time: 7512.5704s
# 	iters: 360, epoch: 2 | loss: 0.3521941
# 	speed: 1.7951s/iter; left time: 7482.0303s
# 	iters: 390, epoch: 2 | loss: 0.2686732
# 	speed: 1.7945s/iter; left time: 7425.8412s
# 	iters: 420, epoch: 2 | loss: 0.2856556
# 	speed: 1.7915s/iter; left time: 7359.4255s
# 	iters: 450, epoch: 2 | loss: 0.2803608
# 	speed: 1.7909s/iter; left time: 7303.2433s
# 	iters: 480, epoch: 2 | loss: 0.2851502
# 	speed: 1.7906s/iter; left time: 7248.2843s
# Epoch: 2 cost time: 902.6931481361389
# Epoch: 2, Steps: 503 | Train Loss: 0.3152563 Vali Loss: 0.4203226 Test Loss: 0.4710442
# Validation loss decreased (0.472293 --> 0.420323).  Saving model ...
# Updating learning rate to 0.00299999954286623
# 	iters: 30, epoch: 3 | loss: 0.2773736
# 	speed: 6.9202s/iter; left time: 27646.2142s
# 	iters: 60, epoch: 3 | loss: 0.2669856
# 	speed: 1.7864s/iter; left time: 7083.1409s
# 	iters: 90, epoch: 3 | loss: 0.3213839
# 	speed: 1.7914s/iter; left time: 7049.2352s
# 	iters: 120, epoch: 3 | loss: 0.2682276
# 	speed: 1.7872s/iter; left time: 6978.9965s
# 	iters: 150, epoch: 3 | loss: 0.2744870
# 	speed: 1.7891s/iter; left time: 6932.7003s
# 	iters: 180, epoch: 3 | loss: 0.2922334
# 	speed: 1.7900s/iter; left time: 6882.4941s
# 	iters: 210, epoch: 3 | loss: 0.2863740
# 	speed: 1.7906s/iter; left time: 6831.2242s
# 	iters: 240, epoch: 3 | loss: 0.2910358
# 	speed: 1.7877s/iter; left time: 6766.5107s
# 	iters: 270, epoch: 3 | loss: 0.2508253
# 	speed: 1.7907s/iter; left time: 6723.9059s
# 	iters: 300, epoch: 3 | loss: 0.3017665
# 	speed: 1.7876s/iter; left time: 6658.6567s
# 	iters: 330, epoch: 3 | loss: 0.2593889
# 	speed: 1.7854s/iter; left time: 6597.0802s
# 	iters: 360, epoch: 3 | loss: 0.2471717
# 	speed: 1.7893s/iter; left time: 6557.8607s
# 	iters: 390, epoch: 3 | loss: 0.2594857
# 	speed: 1.7850s/iter; left time: 6488.3266s
# 	iters: 420, epoch: 3 | loss: 0.2768915
# 	speed: 1.7832s/iter; left time: 6428.5508s
# 	iters: 450, epoch: 3 | loss: 0.2642884
# 	speed: 1.7848s/iter; left time: 6380.6368s
# 	iters: 480, epoch: 3 | loss: 0.3165055
# 	speed: 1.7871s/iter; left time: 6335.3487s
# Epoch: 3 cost time: 899.7166926860809
# Epoch: 3, Steps: 503 | Train Loss: 0.2828268 Vali Loss: 0.4085345 Test Loss: 0.4582914
# Validation loss decreased (0.420323 --> 0.408535).  Saving model ...
# Updating learning rate to 0.0028853711855903173
# 	iters: 30, epoch: 4 | loss: 0.2623925
# 	speed: 6.9235s/iter; left time: 24176.8147s
# 	iters: 60, epoch: 4 | loss: 0.2767962
# 	speed: 1.7848s/iter; left time: 6178.9801s
# 	iters: 90, epoch: 4 | loss: 0.2867248
# 	speed: 1.7893s/iter; left time: 6140.9782s
# 	iters: 120, epoch: 4 | loss: 0.2555971
# 	speed: 1.7843s/iter; left time: 6070.0239s
# 	iters: 150, epoch: 4 | loss: 0.2548800
# 	speed: 1.7851s/iter; left time: 6019.4722s
# 	iters: 180, epoch: 4 | loss: 0.2545969
# 	speed: 1.7850s/iter; left time: 5965.5617s
# 	iters: 210, epoch: 4 | loss: 0.2710769
# 	speed: 1.7894s/iter; left time: 5926.5105s
# 	iters: 240, epoch: 4 | loss: 0.2620130
# 	speed: 1.7860s/iter; left time: 5861.6035s
# 	iters: 270, epoch: 4 | loss: 0.2661155
# 	speed: 1.7855s/iter; left time: 5806.3513s
# 	iters: 300, epoch: 4 | loss: 0.2775087
# 	speed: 1.7891s/iter; left time: 5764.6187s
# 	iters: 330, epoch: 4 | loss: 0.2697120
# 	speed: 1.7857s/iter; left time: 5699.9845s
# 	iters: 360, epoch: 4 | loss: 0.2315526
# 	speed: 1.7855s/iter; left time: 5645.6169s
# 	iters: 390, epoch: 4 | loss: 0.2839409
# 	speed: 1.7855s/iter; left time: 5592.2068s
# 	iters: 420, epoch: 4 | loss: 0.2793169
# 	speed: 1.7873s/iter; left time: 5544.3234s
# 	iters: 450, epoch: 4 | loss: 0.2808831
# 	speed: 1.7828s/iter; left time: 5476.7674s
# 	iters: 480, epoch: 4 | loss: 0.2393349
# 	speed: 1.7827s/iter; left time: 5423.0859s
# Epoch: 4 cost time: 898.4557704925537
# Epoch: 4, Steps: 503 | Train Loss: 0.2657845 Vali Loss: 0.4038759 Test Loss: 0.4563487
# Validation loss decreased (0.408535 --> 0.403876).  Saving model ...
# Updating learning rate to 0.0025598335371749582
# 	iters: 30, epoch: 5 | loss: 0.2458846
# 	speed: 6.9266s/iter; left time: 20703.4685s
# 	iters: 60, epoch: 5 | loss: 0.2442692
# 	speed: 1.7868s/iter; left time: 5287.0993s
# 	iters: 90, epoch: 5 | loss: 0.2360000
# 	speed: 1.7853s/iter; left time: 5229.2280s
# 	iters: 120, epoch: 5 | loss: 0.2840139
# 	speed: 1.7861s/iter; left time: 5177.9494s
# 	iters: 150, epoch: 5 | loss: 0.2378900
# 	speed: 1.7881s/iter; left time: 5130.0871s
# 	iters: 180, epoch: 5 | loss: 0.2358584
# 	speed: 1.7850s/iter; left time: 5067.5173s
# 	iters: 210, epoch: 5 | loss: 0.2550161
# 	speed: 1.7847s/iter; left time: 5013.0868s
# 	iters: 240, epoch: 5 | loss: 0.2677484
# 	speed: 1.7891s/iter; left time: 4971.9514s
# 	iters: 270, epoch: 5 | loss: 0.2534384
# 	speed: 1.7836s/iter; left time: 4903.2056s
# 	iters: 300, epoch: 5 | loss: 0.2613186
# 	speed: 1.7841s/iter; left time: 4850.9349s
# 	iters: 330, epoch: 5 | loss: 0.2855102
# 	speed: 1.7861s/iter; left time: 4802.9102s
# 	iters: 360, epoch: 5 | loss: 0.2650878
# 	speed: 1.7862s/iter; left time: 4749.4706s
# 	iters: 390, epoch: 5 | loss: 0.2404424
# 	speed: 1.7854s/iter; left time: 4693.6967s
# 	iters: 420, epoch: 5 | loss: 0.2367263
# 	speed: 1.7854s/iter; left time: 4640.2842s
# 	iters: 450, epoch: 5 | loss: 0.2345050
# 	speed: 1.7877s/iter; left time: 4592.6430s
# 	iters: 480, epoch: 5 | loss: 0.2403764
# 	speed: 1.7859s/iter; left time: 4534.4951s
# Epoch: 5 cost time: 898.6970195770264
# Epoch: 5, Steps: 503 | Train Loss: 0.2550276 Vali Loss: 0.3917287 Test Loss: 0.4373398
# Validation loss decreased (0.403876 --> 0.391729).  Saving model ...
# Updating learning rate to 0.0020729467535852606
# 	iters: 30, epoch: 6 | loss: 0.2292291
# 	speed: 6.9290s/iter; left time: 17225.5566s
# 	iters: 60, epoch: 6 | loss: 0.2226847
# 	speed: 1.7897s/iter; left time: 4395.5009s
# 	iters: 90, epoch: 6 | loss: 0.2190149
# 	speed: 1.7838s/iter; left time: 4327.5361s
# 	iters: 120, epoch: 6 | loss: 0.2586479
# 	speed: 1.7835s/iter; left time: 4273.2176s
# 	iters: 150, epoch: 6 | loss: 0.2643556
# 	speed: 1.7883s/iter; left time: 4231.1665s
# 	iters: 180, epoch: 6 | loss: 0.2474970
# 	speed: 1.7845s/iter; left time: 4168.6420s
# 	iters: 210, epoch: 6 | loss: 0.2251978
# 	speed: 1.7854s/iter; left time: 4117.1825s
# 	iters: 240, epoch: 6 | loss: 0.2531258
# 	speed: 1.7874s/iter; left time: 4068.1580s
# 	iters: 270, epoch: 6 | loss: 0.2255118
# 	speed: 1.7882s/iter; left time: 4016.2748s
# 	iters: 300, epoch: 6 | loss: 0.2330469
# 	speed: 1.7848s/iter; left time: 3955.0484s
# 	iters: 330, epoch: 6 | loss: 0.2292186
# 	speed: 1.7840s/iter; left time: 3899.8770s
# 	iters: 360, epoch: 6 | loss: 0.2414929
# 	speed: 1.7841s/iter; left time: 3846.5162s
# 	iters: 390, epoch: 6 | loss: 0.2220912
# 	speed: 1.7874s/iter; left time: 3800.0680s
# 	iters: 420, epoch: 6 | loss: 0.2464704
# 	speed: 1.7821s/iter; left time: 3735.2435s
# 	iters: 450, epoch: 6 | loss: 0.2693341
# 	speed: 1.7849s/iter; left time: 3687.6217s
# 	iters: 480, epoch: 6 | loss: 0.2381295
# 	speed: 1.7892s/iter; left time: 3642.8871s
# Epoch: 6 cost time: 898.606761932373
# Epoch: 6, Steps: 503 | Train Loss: 0.2461707 Vali Loss: 0.3833500 Test Loss: 0.4337938
# Validation loss decreased (0.391729 --> 0.383350).  Saving model ...
# Updating learning rate to 0.0014988349339830718
# 	iters: 30, epoch: 7 | loss: 0.2219372
# 	speed: 6.9220s/iter; left time: 13726.3097s
# 	iters: 60, epoch: 7 | loss: 0.2437486
# 	speed: 1.7913s/iter; left time: 3498.4989s
# 	iters: 90, epoch: 7 | loss: 0.2498091
# 	speed: 1.7847s/iter; left time: 3432.0375s
# 	iters: 120, epoch: 7 | loss: 0.2257906
# 	speed: 1.7861s/iter; left time: 3381.0820s
# 	iters: 150, epoch: 7 | loss: 0.2135463
# 	speed: 1.7855s/iter; left time: 3326.4527s
# 	iters: 180, epoch: 7 | loss: 0.2376235
# 	speed: 1.7847s/iter; left time: 3271.2938s
# 	iters: 210, epoch: 7 | loss: 0.2428837
# 	speed: 1.7854s/iter; left time: 3219.1214s
# 	iters: 240, epoch: 7 | loss: 0.2453804
# 	speed: 1.7849s/iter; left time: 3164.6329s
# 	iters: 270, epoch: 7 | loss: 0.2578852
# 	speed: 1.7840s/iter; left time: 3109.4456s
# 	iters: 300, epoch: 7 | loss: 0.2290975
# 	speed: 1.7869s/iter; left time: 3060.9897s
# 	iters: 330, epoch: 7 | loss: 0.2359356
# 	speed: 1.7840s/iter; left time: 3002.5513s
# 	iters: 360, epoch: 7 | loss: 0.2595098
# 	speed: 1.7814s/iter; left time: 2944.5834s
# 	iters: 390, epoch: 7 | loss: 0.2143182
# 	speed: 1.7869s/iter; left time: 2900.0617s
# 	iters: 420, epoch: 7 | loss: 0.2369153
# 	speed: 1.7821s/iter; left time: 2838.8260s
# 	iters: 450, epoch: 7 | loss: 0.2368336
# 	speed: 1.7820s/iter; left time: 2785.3324s
# 	iters: 480, epoch: 7 | loss: 0.2526959
# 	speed: 1.7828s/iter; left time: 2733.0070s
# Epoch: 7 cost time: 897.8681490421295
# Epoch: 7, Steps: 503 | Train Loss: 0.2361705 Vali Loss: 0.3758945 Test Loss: 0.4232044
# Validation loss decreased (0.383350 --> 0.375894).  Saving model ...
# Updating learning rate to 0.0009249013985662202
# 	iters: 30, epoch: 8 | loss: 0.2389865
# 	speed: 6.9385s/iter; left time: 10268.9077s
# 	iters: 60, epoch: 8 | loss: 0.2266484
# 	speed: 1.7842s/iter; left time: 2587.0363s
# 	iters: 90, epoch: 8 | loss: 0.2292103
# 	speed: 1.7817s/iter; left time: 2529.9764s
# 	iters: 120, epoch: 8 | loss: 0.2294363
# 	speed: 1.7839s/iter; left time: 2479.6086s
# 	iters: 150, epoch: 8 | loss: 0.2052076
# 	speed: 1.7854s/iter; left time: 2428.1143s
# 	iters: 180, epoch: 8 | loss: 0.2135293
# 	speed: 1.7821s/iter; left time: 2370.1349s
# 	iters: 210, epoch: 8 | loss: 0.2067656
# 	speed: 1.7848s/iter; left time: 2320.1762s
# 	iters: 240, epoch: 8 | loss: 0.2536618
# 	speed: 1.7845s/iter; left time: 2266.3290s
# 	iters: 270, epoch: 8 | loss: 0.2462711
# 	speed: 1.7892s/iter; left time: 2218.5731s
# 	iters: 300, epoch: 8 | loss: 0.2486039
# 	speed: 1.7843s/iter; left time: 2158.9970s
# 	iters: 330, epoch: 8 | loss: 0.2327566
# 	speed: 1.7868s/iter; left time: 2108.4446s
# 	iters: 360, epoch: 8 | loss: 0.2231598
# 	speed: 1.7849s/iter; left time: 2052.6113s
# 	iters: 390, epoch: 8 | loss: 0.2305641
# 	speed: 1.7864s/iter; left time: 2000.7201s
# 	iters: 420, epoch: 8 | loss: 0.2413591
# 	speed: 1.7840s/iter; left time: 1944.5634s
# 	iters: 450, epoch: 8 | loss: 0.2262822
# 	speed: 1.7848s/iter; left time: 1891.8877s
# 	iters: 480, epoch: 8 | loss: 0.2164383
# 	speed: 1.7854s/iter; left time: 1838.9710s
# Epoch: 8 cost time: 898.2324273586273
# Epoch: 8, Steps: 503 | Train Loss: 0.2265683 Vali Loss: 0.3675501 Test Loss: 0.4156315
# Validation loss decreased (0.375894 --> 0.367550).  Saving model ...
# Updating learning rate to 0.0004385223253814674
# 	iters: 30, epoch: 9 | loss: 0.2143815
# 	speed: 6.9153s/iter; left time: 6756.2019s
# 	iters: 60, epoch: 9 | loss: 0.2138983
# 	speed: 1.7841s/iter; left time: 1689.5377s
# 	iters: 90, epoch: 9 | loss: 0.2260093
# 	speed: 1.7900s/iter; left time: 1641.4640s
# 	iters: 120, epoch: 9 | loss: 0.2123865
# 	speed: 1.7854s/iter; left time: 1583.6330s
# 	iters: 150, epoch: 9 | loss: 0.2232259
# 	speed: 1.7874s/iter; left time: 1531.7904s
# 	iters: 180, epoch: 9 | loss: 0.2161490
# 	speed: 1.7863s/iter; left time: 1477.3095s
# 	iters: 210, epoch: 9 | loss: 0.2144759
# 	speed: 1.7886s/iter; left time: 1425.5511s
# 	iters: 240, epoch: 9 | loss: 0.2156077
# 	speed: 1.7880s/iter; left time: 1371.3840s
# 	iters: 270, epoch: 9 | loss: 0.2440760
# 	speed: 1.7842s/iter; left time: 1314.9776s
# 	iters: 300, epoch: 9 | loss: 0.2121230
# 	speed: 1.7862s/iter; left time: 1262.8087s
# 	iters: 330, epoch: 9 | loss: 0.2375745
# 	speed: 1.7839s/iter; left time: 1207.7111s
# 	iters: 360, epoch: 9 | loss: 0.2384799
# 	speed: 1.7835s/iter; left time: 1153.9045s
# 	iters: 390, epoch: 9 | loss: 0.2259113
# 	speed: 1.7856s/iter; left time: 1101.7259s
# 	iters: 420, epoch: 9 | loss: 0.1984241
# 	speed: 1.7860s/iter; left time: 1048.3565s
# 	iters: 450, epoch: 9 | loss: 0.1907332
# 	speed: 1.7858s/iter; left time: 994.7006s
# 	iters: 480, epoch: 9 | loss: 0.2070761
# 	speed: 1.7834s/iter; left time: 939.8429s
# Epoch: 9 cost time: 898.3583052158356
# Epoch: 9, Steps: 503 | Train Loss: 0.2197617 Vali Loss: 0.3609395 Test Loss: 0.4125845
# Validation loss decreased (0.367550 --> 0.360940).  Saving model ...
# Updating learning rate to 0.00011374451928391443
# 	iters: 30, epoch: 10 | loss: 0.2078556
# 	speed: 6.9294s/iter; left time: 3284.5488s
# 	iters: 60, epoch: 10 | loss: 0.2220534
# 	speed: 1.7841s/iter; left time: 792.1312s
# 	iters: 90, epoch: 10 | loss: 0.1961927
# 	speed: 1.7814s/iter; left time: 737.5126s
# 	iters: 120, epoch: 10 | loss: 0.2250456
# 	speed: 1.7868s/iter; left time: 686.1185s
# 	iters: 150, epoch: 10 | loss: 0.2136715
# 	speed: 1.7835s/iter; left time: 631.3715s
# 	iters: 180, epoch: 10 | loss: 0.1979302
# 	speed: 1.7838s/iter; left time: 577.9490s
# 	iters: 210, epoch: 10 | loss: 0.2137565
# 	speed: 1.7885s/iter; left time: 525.8275s
# 	iters: 240, epoch: 10 | loss: 0.2061038
# 	speed: 1.7879s/iter; left time: 472.0009s
# 	iters: 270, epoch: 10 | loss: 0.1938687
# 	speed: 1.7894s/iter; left time: 418.7239s
# 	iters: 300, epoch: 10 | loss: 0.2041270
# 	speed: 1.7841s/iter; left time: 363.9645s
# 	iters: 330, epoch: 10 | loss: 0.2099234
# 	speed: 1.7848s/iter; left time: 310.5510s
# 	iters: 360, epoch: 10 | loss: 0.2046988
# 	speed: 1.7879s/iter; left time: 257.4629s
# 	iters: 390, epoch: 10 | loss: 0.1951580
# 	speed: 1.7876s/iter; left time: 203.7815s
# 	iters: 420, epoch: 10 | loss: 0.2166636
# 	speed: 1.7843s/iter; left time: 149.8841s
# 	iters: 450, epoch: 10 | loss: 0.2357479
# 	speed: 1.7885s/iter; left time: 96.5811s
# 	iters: 480, epoch: 10 | loss: 0.2120177
# 	speed: 1.7838s/iter; left time: 42.8114s
# Epoch: 10 cost time: 898.5818283557892
# Epoch: 10, Steps: 503 | Train Loss: 0.2159749 Vali Loss: 0.3600903 Test Loss: 0.4106843
# Validation loss decreased (0.360940 --> 0.360090).  Saving model ...
# Updating learning rate to 1.2457133770165797e-08
# >>>>>>>testing : traffic_SimpleTM_Hybrid_dual_CombinedSparse_SimpleTM_Hybrid_dual_custom_96_96_512_1024_2_db1_None_None_sparse_0.15_0.3_swt_3_0.1_False_0.0_0.003_TST_24_2025_1_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 3413
# test shape: (142, 24, 96, 862) (142, 24, 96, 862)
# test shape: (3408, 96, 862) (3408, 96, 862)
# Collected 16 examples for combined_prediction_examples.png
# mse:0.41068387031555176, mae:0.26739510893821716
# rmse:0.6408461928367615, mape:0.46713292598724365, mspe:119250.1484375
# rse:0.530480669485614, corr:29.266504287719727, smape:0.48162442445755005, wape:0.3344911807694751, r2:0.7185902834076718
# Saved run log to: /teamspace/studios/this_studio/lightning_runs/SimpleTM_HybridFeatureAblation_Results/logs/traffic_dual_CombinedSparse.log
#
# SUCCESS: Finished Hybrid dual_CombinedSparse on traffic
#
#
# Gathering generated plots and metric text...
# Copied metric text results to output directory.

# %%
results_file = os.path.join(OUTPUT_DIR, "result_long_term_forecast.txt")
root_results_file = "result_long_term_forecast.txt"
metric_order = ["MSE", "MAE", "RMSE", "MAPE", "WAPE", "R2"]
setting_pattern = re.compile(r"^(?P<dataset>[^_]+)_SimpleTM_Hybrid_(?P<attention>original|dual)_(?P<config>[^_]+)_SimpleTM_Hybrid_")
metric_pattern = re.compile(r"([a-zA-Z0-9_]+):([^,]+)")

if not os.path.exists(results_file):
    if os.path.exists(root_results_file):
        print(f"Result file was not copied to OUTPUT_DIR. Copying from repo root: {root_results_file}")
        os.makedirs(OUTPUT_DIR, exist_ok=True)
        shutil.copy(root_results_file, results_file)
    else:
        log_dir = os.path.join(OUTPUT_DIR, "logs")
        log_files = glob.glob(os.path.join(log_dir, "*.log")) if os.path.exists(log_dir) else []
        raise FileNotFoundError(
            f"{results_file} was not found. Run the training cell before this parsing cell. "
            "If you reran the configuration cell after training, it deleted OUTPUT_DIR and the result file. "
            f"Found {len(log_files)} log files in {log_dir}. If this is 0, training did not run or failed before testing."
        )

with open(results_file, "r", encoding="utf-8") as f:
    content = f.read().strip()

rows = []
for entry in content.split("\n\n") if content else []:
    lines = [line.strip() for line in entry.splitlines() if line.strip()]
    if len(lines) < 2:
        continue
    setting = lines[0]
    metrics_line = lines[-1]
    match = setting_pattern.search(setting)
    if not match:
        continue

    row = {
        "Dataset": match.group("dataset"),
        "Model": "SimpleTM_Hybrid",
        "AttentionMode": match.group("attention"),
        "HybridConfig": match.group("config"),
        "Variant": f"Hybrid_{match.group('attention')}_{match.group('config')}",
        "Setting": setting,
    }
    for metric_name, value in metric_pattern.findall(metrics_line):
        try:
            row[metric_name.upper()] = float(value.strip())
        except ValueError:
            pass
    rows.append(row)

if not rows:
    raise RuntimeError("No valid metrics found in result file.")

raw_df = pd.DataFrame(rows).sort_values(["Dataset", "AttentionMode", "HybridConfig", "Setting"]).reset_index(drop=True)
value_columns = [col for col in metric_order if col in raw_df.columns]

raw_path = os.path.join(OUTPUT_DIR, "raw_metrics.csv")
raw_df.to_csv(raw_path, index=False)

agg_df = raw_df.groupby(["Dataset", "AttentionMode", "HybridConfig", "Variant"], as_index=False)[value_columns].mean(numeric_only=True)
count_df = raw_df.groupby(["Dataset", "AttentionMode", "HybridConfig", "Variant"], as_index=False).size().rename(columns={"size": "NumRuns"})
agg_df = agg_df.merge(count_df, on=["Dataset", "AttentionMode", "HybridConfig", "Variant"], how="left")
averaged_path = os.path.join(OUTPUT_DIR, "averaged_metrics.csv")
agg_df.to_csv(averaged_path, index=False)

comparison = agg_df.pivot_table(index=["Dataset", "AttentionMode"], columns="HybridConfig", values=value_columns, aggfunc="mean")
comparison_path = os.path.join(OUTPUT_DIR, "hybrid_feature_comparison.csv")
comparison.to_csv(comparison_path)

print("Raw runs:")
display(raw_df)
print("Averaged Hybrid feature ablation results:")
display(agg_df.sort_values(["Dataset", "AttentionMode", "HybridConfig"]))
print(f"Saved raw results to: {raw_path}")
print(f"Saved averaged results to: {averaged_path}")
print(f"Saved comparison table to: {comparison_path}")
# Out:
# Raw runs:
#    Dataset            Model AttentionMode    HybridConfig  \
# 0  traffic  SimpleTM_Hybrid          dual  CombinedSparse
# 1  traffic  SimpleTM_Hybrid      original  CombinedSparse
#
#                           Variant  \
# 0      Hybrid_dual_CombinedSparse
# 1  Hybrid_original_CombinedSparse
#
#                                              Setting       MAE       MSE  \
# 0  traffic_SimpleTM_Hybrid_dual_CombinedSparse_Si...  0.267395  0.410684
# 1  traffic_SimpleTM_Hybrid_original_CombinedSpars...  0.262846  0.409769
#
#        RMSE      MAPE           MSPE       RSE       CORR     SMAPE      WAPE  \
# 0  0.640846  0.467133  119250.148438  0.530481  29.266504  0.481624  0.334491
# 1  0.640132  0.458953  121342.359375  0.529890  29.331804  0.474168  0.328800
#
#          R2
# 0  0.718590
# 1  0.719217
# Averaged Hybrid feature ablation results:
#    Dataset AttentionMode    HybridConfig                         Variant  \
# 0  traffic          dual  CombinedSparse      Hybrid_dual_CombinedSparse
# 1  traffic      original  CombinedSparse  Hybrid_original_CombinedSparse
#
#         MSE       MAE      RMSE      MAPE      WAPE        R2  NumRuns
# 0  0.410684  0.267395  0.640846  0.467133  0.334491  0.718590        1
# 1  0.409769  0.262846  0.640132  0.458953  0.328800  0.719217        1
# Saved raw results to: /teamspace/studios/this_studio/lightning_runs/SimpleTM_HybridFeatureAblation_Results/raw_metrics.csv
# Saved averaged results to: /teamspace/studios/this_studio/lightning_runs/SimpleTM_HybridFeatureAblation_Results/averaged_metrics.csv
# Saved comparison table to: /teamspace/studios/this_studio/lightning_runs/SimpleTM_HybridFeatureAblation_Results/hybrid_feature_comparison.csv

# %%
import matplotlib.pyplot as plt

MAX_LEARNING_CURVES_TO_SHOW = 12
LEARNING_CURVE_DIR = os.path.join(OUTPUT_DIR, "learning_curves")
os.makedirs(LEARNING_CURVE_DIR, exist_ok=True)

epoch_pattern = re.compile(
    r"Epoch:\s*(?P<epoch>\d+),\s*Steps:\s*\d+\s*\|\s*"
    r"Train Loss:\s*(?P<train>[0-9.eE+-]+)\s*"
    r"Vali Loss:\s*(?P<vali>[0-9.eE+-]+)\s*"
    r"Test Loss:\s*(?P<test>[0-9.eE+-]+)"
)

learning_rows = []
for log_path in sorted(glob.glob(os.path.join(OUTPUT_DIR, "logs", "*.log"))):
    stem = os.path.splitext(os.path.basename(log_path))[0]
    dataset_name, attention_mode, config_tag = stem.split("_", 2)
    repeat = 0
    previous_epoch = 0
    with open(log_path, "r", encoding="utf-8") as f:
        for line in f:
            match = epoch_pattern.search(line)
            if not match:
                continue
            epoch = int(match.group("epoch"))
            if previous_epoch and epoch <= previous_epoch:
                repeat += 1
            previous_epoch = epoch
            learning_rows.append({
                "Dataset": dataset_name,
                "AttentionMode": attention_mode,
                "HybridConfig": config_tag,
                "Repeat": repeat,
                "Epoch": epoch,
                "TrainLoss": float(match.group("train")),
                "ValiLoss": float(match.group("vali")),
                "TestLoss": float(match.group("test")),
                "LogFile": log_path,
            })

learning_df = pd.DataFrame(learning_rows)
if learning_df.empty:
    print("No epoch-wise learning curves found. Run the training cell first.")
else:
    learning_csv = os.path.join(OUTPUT_DIR, "learning_curves.csv")
    learning_df.to_csv(learning_csv, index=False)
    print(f"Saved learning-curve data to: {learning_csv}")
    display(learning_df.head(20))

    shown = 0
    for (dataset_name, attention_mode), curve_df in learning_df.groupby(["Dataset", "AttentionMode"]):
        fig, ax = plt.subplots(figsize=(12, 6))
        for config_tag, mode_df in curve_df.groupby("HybridConfig"):
            mode_df = mode_df.groupby("Epoch", as_index=False)[["TrainLoss", "ValiLoss", "TestLoss"]].mean().sort_values("Epoch")
            ax.plot(mode_df["Epoch"], mode_df["ValiLoss"], marker="o", linewidth=2.0, label=f"{config_tag} val")

        ax.set_title(f"{dataset_name} | Hybrid {attention_mode}: validation learning curves")
        ax.set_xlabel("Epoch")
        ax.set_ylabel("Validation Loss")
        ax.grid(alpha=0.3)
        ax.legend(fontsize=9)
        plt.tight_layout()
        curve_path = os.path.join(LEARNING_CURVE_DIR, f"{dataset_name}_{attention_mode}_validation_learning_curve.png")
        plt.savefig(curve_path, dpi=180, bbox_inches="tight")
        if shown < MAX_LEARNING_CURVES_TO_SHOW:
            plt.show()
            shown += 1
        else:
            plt.close(fig)

    print(f"Saved learning-curve plots to: {LEARNING_CURVE_DIR}")
# Out:
# Saved learning-curve data to: /teamspace/studios/this_studio/lightning_runs/SimpleTM_HybridFeatureAblation_Results/learning_curves.csv
#     Dataset AttentionMode    HybridConfig  Repeat  Epoch  TrainLoss  ValiLoss  \
# 0   traffic          dual  CombinedSparse       0      1   0.380530  0.472293
# 1   traffic          dual  CombinedSparse       0      2   0.315256  0.420323
# 2   traffic          dual  CombinedSparse       0      3   0.282827  0.408535
# 3   traffic          dual  CombinedSparse       0      4   0.265784  0.403876
# 4   traffic          dual  CombinedSparse       0      5   0.255028  0.391729
# 5   traffic          dual  CombinedSparse       0      6   0.246171  0.383350
# 6   traffic          dual  CombinedSparse       0      7   0.236171  0.375895
# 7   traffic          dual  CombinedSparse       0      8   0.226568  0.367550
# 8   traffic          dual  CombinedSparse       0      9   0.219762  0.360940
# 9   traffic          dual  CombinedSparse       0     10   0.215975  0.360090
# 10  traffic      original  CombinedSparse       0      1   0.373375  0.460498
# 11  traffic      original  CombinedSparse       0      2   0.311346  0.425530
# 12  traffic      original  CombinedSparse       0      3   0.280970  0.408539
# 13  traffic      original  CombinedSparse       0      4   0.265663  0.402004
# 14  traffic      original  CombinedSparse       0      5   0.254648  0.388715
# 15  traffic      original  CombinedSparse       0      6   0.244522  0.385464
# 16  traffic      original  CombinedSparse       0      7   0.235666  0.374347
# 17  traffic      original  CombinedSparse       0      8   0.226895  0.369738
# 18  traffic      original  CombinedSparse       0      9   0.220331  0.362120
# 19  traffic      original  CombinedSparse       0     10   0.216696  0.361470
#
#     TestLoss                                            LogFile
# 0   0.528497  /teamspace/studios/this_studio/lightning_runs/...
# 1   0.471044  /teamspace/studios/this_studio/lightning_runs/...
# 2   0.458291  /teamspace/studios/this_studio/lightning_runs/...
# 3   0.456349  /teamspace/studios/this_studio/lightning_runs/...
# 4   0.437340  /teamspace/studios/this_studio/lightning_runs/...
# 5   0.433794  /teamspace/studios/this_studio/lightning_runs/...
# 6   0.423204  /teamspace/studios/this_studio/lightning_runs/...
# 7   0.415631  /teamspace/studios/this_studio/lightning_runs/...
# 8   0.412585  /teamspace/studios/this_studio/lightning_runs/...
# 9   0.410684  /teamspace/studios/this_studio/lightning_runs/...
# 10  0.511633  /teamspace/studios/this_studio/lightning_runs/...
# 11  0.478107  /teamspace/studios/this_studio/lightning_runs/...
# 12  0.456392  /teamspace/studios/this_studio/lightning_runs/...
# 13  0.450930  /teamspace/studios/this_studio/lightning_runs/...
# 14  0.438995  /teamspace/studios/this_studio/lightning_runs/...
# 15  0.431562  /teamspace/studios/this_studio/lightning_runs/...
# 16  0.420142  /teamspace/studios/this_studio/lightning_runs/...
# 17  0.414490  /teamspace/studios/this_studio/lightning_runs/...
# 18  0.411233  /teamspace/studios/this_studio/lightning_runs/...
# 19  0.409768  /teamspace/studios/this_studio/lightning_runs/...
# Saved learning-curve plots to: /teamspace/studios/this_studio/lightning_runs/SimpleTM_HybridFeatureAblation_Results/learning_curves

# %%
if "agg_df" in globals() and not agg_df.empty:
    metric = "MSE" if "MSE" in agg_df.columns else value_columns[0]
    for dataset_name, ds_df in agg_df.groupby("Dataset"):
        for attention_mode, mode_df in ds_df.groupby("AttentionMode"):
            plot_df = mode_df.set_index("HybridConfig")[[metric]].sort_values(metric)
            ax = plot_df.plot(kind="bar", figsize=(12, 5), legend=False, color="#4C78A8")
            ax.set_title(f"{dataset_name}: Hybrid {attention_mode} feature ablation ({metric}, lower is better)")
            ax.set_xlabel("Hybrid Config")
            ax.set_ylabel(metric)
            ax.grid(axis="y", alpha=0.3)
            plt.xticks(rotation=30, ha="right")
            plt.tight_layout()
            plot_path = os.path.join(OUTPUT_DIR, f"{dataset_name}_{attention_mode}_hybrid_feature_{metric}.png")
            plt.savefig(plot_path, dpi=180, bbox_inches="tight")
            plt.show()

    best_rows = agg_df.sort_values(["Dataset", "AttentionMode", metric]).groupby(["Dataset", "AttentionMode"], as_index=False).first()
    print(f"Best config by {metric}:")
    display(best_rows[["Dataset", "AttentionMode", "HybridConfig", metric, "MAE"] if "MAE" in best_rows.columns else ["Dataset", "AttentionMode", "HybridConfig", metric]])
# Out:
# Best config by MSE:
#    Dataset AttentionMode    HybridConfig       MSE       MAE
# 0  traffic          dual  CombinedSparse  0.410684  0.267395
# 1  traffic      original  CombinedSparse  0.409769  0.262846

# %%
print("Packing logs, checkpoints, plots, and CSV results...")
archive_path = shutil.make_archive(os.path.join(BASE_DIR, "SimpleTM_HybridFeatureAblation_Results"), "zip", OUTPUT_DIR)
print(f"DONE. Archive saved to: {archive_path}")
print("Download it from the Lightning file browser or copy it from the studio workspace.")
# Out:
# Packing logs, checkpoints, plots, and CSV results...
# DONE. Archive saved to: /teamspace/studios/this_studio/lightning_runs/SimpleTM_HybridFeatureAblation_Results.zip
# Download it from the Lightning file browser or copy it from the studio workspace.
