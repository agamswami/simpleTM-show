# %% [markdown]
# # SimpleTMG smartbuilding Hybrid - kaggle

# %%
# !pip install PyWavelets gdown --quiet

import os
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"

import glob
import re
import shutil
import subprocess
import zipfile

import pandas as pd
import torch
from IPython.display import display

print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
# Out:
# PyTorch version: 2.10.0+cu128
# CUDA available: True
# GPU: Tesla T4

# %%
REPO_URL = "https://github.com/agamswami/simpleTM-show"
REPO_DIR = "/kaggle/working/SimpleTM"

if os.path.exists(REPO_DIR):
    print("Repo already exists. Pulling latest changes...")
    subprocess.run(["git", "-C", REPO_DIR, "pull"], check=True)
else:
    subprocess.run(["git", "clone", REPO_URL, REPO_DIR], check=True)

os.chdir(REPO_DIR)
print(f"Working directory: {os.getcwd()}")

subprocess.run(["sed", "-i", r"s/np\.Inf/np.inf/g", "utils/tools.py"], check=True)

with open("run.py", "r", encoding="utf-8") as f:
    run_source = f.read()

required_flags = [
    "--hybrid_gate_mode",
    "--hybrid_branch_dropout",
    "--hybrid_gate_temperature",
    "--hybrid_residual_branch",
]
missing_flags = [flag for flag in required_flags if flag not in run_source]
if missing_flags:
    raise RuntimeError(f"This GitHub clone is missing Hybrid ablation flags: {missing_flags}. Push the local code changes before running this notebook.")

print("Hybrid ablation CLI flags found in run.py")
# Out:
# Cloning into '/kaggle/working/SimpleTM'...
# Working directory: /kaggle/working/SimpleTM
# Hybrid ablation CLI flags found in run.py

# %%
FILE_ID = "1JOgmL2ntyxKg6eB132ytCbVZumiHnDLR"
OUTPUT_PATH = "/kaggle/working/dataset.zip"
DATASET_DIR = "./dataset"

if not os.path.exists(DATASET_DIR):
    download_url = f"https://drive.google.com/uc?id={FILE_ID}"
    subprocess.run(["gdown", download_url, "-O", OUTPUT_PATH], check=True)
    if not os.path.exists(OUTPUT_PATH):
        raise FileNotFoundError(f"Dataset download failed: {OUTPUT_PATH}")
    os.makedirs(DATASET_DIR, exist_ok=True)
    with zipfile.ZipFile(OUTPUT_PATH, "r") as zip_ref:
        zip_ref.extractall(DATASET_DIR)
    print("Dataset extracted successfully.")
else:
    print("Dataset already exists.")

for root, dirs, files in os.walk(DATASET_DIR):
    level = root.replace(DATASET_DIR, "").count(os.sep)
    indent = " " * 2 * level
    print(f"{indent}{os.path.basename(root)}/")
    subindent = " " * 2 * (level + 1)
    for file in files[:8]:
        print(f"{subindent}{file}")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1JOgmL2ntyxKg6eB132ytCbVZumiHnDLR
# From (redirected): https://drive.google.com/uc?id=1JOgmL2ntyxKg6eB132ytCbVZumiHnDLR&confirm=t&uuid=03f660a5-f367-4815-8db2-26978d2769e5
# To: /kaggle/working/dataset.zip
# 100%|██████████| 172M/172M [00:00<00:00, 189MB/s]
# Dataset extracted successfully.
# dataset/
#   SimpleTM_datasets/
#     .DS_Store
#     ETT-small/
#       ETTh2.csv
#       ETTm1.csv
#       ETTm2.csv
#       ETTh1.csv
#     electricity/
#       electricity.csv
#       .DS_Store
#     traffic/
#       traffic.csv
#       .DS_Store
#     weather/
#       weather.csv
#     PEMS/
#       PEMS08.npz
#       PEMS07.npz
#       PEMS04.npz
#       PEMS03.npz
#     smartbuilding/
#       smart.csv
#     Solar/
#       solar_AL.txt
#   __MACOSX/
#     ._SimpleTM_datasets
#     SimpleTM_datasets/
#       ._traffic
#       ._ETT-small
#       ._weather
#       ._PEMS
#       ._electricity
#       ._.DS_Store
#       ._Solar
#       ETT-small/
#         ._ETTh1.csv
#         ._ETTm1.csv
#         ._ETTm2.csv
#         ._ETTh2.csv
#       electricity/
#         ._.DS_Store
#         ._electricity.csv
#       traffic/
#         ._traffic.csv
#         ._.DS_Store
#       weather/
#         ._weather.csv
#       PEMS/
#         ._PEMS08.npz
#         ._PEMS07.npz
#         ._PEMS03.npz
#         ._PEMS04.npz
#       Solar/
#         ._solar_AL.txt

# %%
# Set selectors to None for the full grid.
SELECTED_DATASETS = ["smartbuilding"]
SELECTED_ATTENTION_MODES = None
SELECTED_HYBRID_CONFIGS = None

# Residual fallback branch used by ResidualFallback and CombinedSparse configs.
# Change to "fft" or "conv" if your previous results show those are stronger for the target dataset.
DEFAULT_RESIDUAL_BRANCH = "swt"

all_datasets = [
    {"name": "ETTh1", "data": "ETTh1", "root": "./dataset/SimpleTM_datasets/ETT-small", "path": "ETTh1.csv", "enc_in": 7, "d_model": 32, "d_ff": 32, "e_layers": 1, "wv": "db1", "m": 3, "alpha": 0.3, "learning_rate": 0.02, "batch_size": 256, "train_epochs": 10, "patience": 3, "use_norm": 1, "lradj": "TST", "freq": "h", "itr": 3, "l1_weight": 0.0005},
    {"name": "ETTm1", "data": "ETTm1", "root": "./dataset/SimpleTM_datasets/ETT-small", "path": "ETTm1.csv", "enc_in": 7, "d_model": 32, "d_ff": 32, "e_layers": 1, "wv": "db1", "m": 3, "alpha": 0.1, "learning_rate": 0.02, "batch_size": 256, "train_epochs": 10, "patience": 3, "use_norm": 1, "lradj": "TST", "freq": "t", "itr": 3, "l1_weight": 0.005},
    {"name": "weather", "data": "custom", "root": "./dataset/SimpleTM_datasets/weather", "path": "weather.csv", "enc_in": 21, "d_model": 32, "d_ff": 32, "e_layers": 4, "wv": "db4", "m": 3, "alpha": 0.3, "learning_rate": 0.01, "batch_size": 256, "train_epochs": 10, "patience": 3, "use_norm": 1, "lradj": "TST", "freq": "h", "itr": 3, "l1_weight": 5e-05},
    {"name": "electricity", "data": "custom", "root": "./dataset/SimpleTM_datasets/electricity", "path": "electricity.csv", "enc_in": 321, "d_model": 256, "d_ff": 1024, "e_layers": 1, "wv": "db1", "m": 3, "alpha": 0.0, "learning_rate": 0.01, "batch_size": 256, "train_epochs": 10, "patience": 3, "use_norm": 1, "lradj": "TST", "freq": "h", "itr": 1, "l1_weight": 0.0},
    {"name": "traffic", "data": "custom", "root": "./dataset/SimpleTM_datasets/traffic", "path": "traffic.csv", "enc_in": 862, "d_model": 512, "d_ff": 1024, "e_layers": 2, "wv": "db1", "m": 3, "alpha": 0.1, "learning_rate": 0.003, "batch_size": 24, "train_epochs": 10, "patience": 3, "use_norm": 1, "lradj": "TST", "freq": "h", "itr": 1, "l1_weight": 0.0},
    {"name": "Solar", "data": "Solar", "root": "./dataset/SimpleTM_datasets/Solar", "path": "solar_AL.txt", "enc_in": 137, "d_model": 128, "d_ff": 256, "e_layers": 1, "wv": "db8", "m": 3, "alpha": 0.0, "learning_rate": 0.01, "batch_size": 256, "train_epochs": 10, "patience": 3, "use_norm": 0, "lradj": "TST", "freq": "h", "itr": 3, "l1_weight": 0.005},
    {"name": "smartbuilding", "data": "custom", "root": "./dataset/SimpleTM_datasets/smartbuilding", "path": "smart.csv", "enc_in": 37, "d_model": 64, "d_ff": 128, "e_layers": 1, "wv": "db4", "m": 3, "alpha": 0.3, "learning_rate": 0.003, "batch_size": 64, "train_epochs": 20, "patience": 5, "use_norm": 1, "lradj": "TST", "freq": "h", "itr": 3, "l1_weight": 5e-05, "target": "Floor_Total(kW)"},
]

hybrid_configs = [
    {"tag": "Baseline", "gate_mode": "soft", "branch_dropout": 0.0, "gate_temperature": 0.5, "residual_branch": "none"},
    {"tag": "BranchDropout", "gate_mode": "soft", "branch_dropout": 0.15, "gate_temperature": 0.5, "residual_branch": "none"},
    {"tag": "SparseGate", "gate_mode": "sparse", "branch_dropout": 0.0, "gate_temperature": 0.3, "residual_branch": "none"},
    {"tag": "OneHotGate", "gate_mode": "one_hot", "branch_dropout": 0.0, "gate_temperature": 0.3, "residual_branch": "none"},
    {"tag": "ResidualFallback", "gate_mode": "soft", "branch_dropout": 0.0, "gate_temperature": 0.5, "residual_branch": DEFAULT_RESIDUAL_BRANCH},
    {"tag": "CombinedSparse", "gate_mode": "sparse", "branch_dropout": 0.15, "gate_temperature": 0.3, "residual_branch": DEFAULT_RESIDUAL_BRANCH},
]

if SELECTED_DATASETS is None:
    datasets = list(all_datasets)
else:
    datasets = [ds for ds in all_datasets if ds["name"] in SELECTED_DATASETS]

if SELECTED_ATTENTION_MODES is None:
    attention_modes = ["original", "dual"]
else:
    attention_modes = list(SELECTED_ATTENTION_MODES)

if SELECTED_HYBRID_CONFIGS is None:
    configs = list(hybrid_configs)
else:
    configs = [cfg for cfg in hybrid_configs if cfg["tag"] in SELECTED_HYBRID_CONFIGS]

# This setup cell resets previous outputs. Do not rerun it after training unless you want to start over.
OUTPUT_DIR = "/kaggle/working/SimpleTM_HybridFeatureAblation_Results"
if os.path.exists(OUTPUT_DIR):
    shutil.rmtree(OUTPUT_DIR)
os.makedirs(OUTPUT_DIR, exist_ok=True)

LOG_DIR = os.path.join(OUTPUT_DIR, "logs")
os.makedirs(LOG_DIR, exist_ok=True)

for path in ["./checkpoints", "result_long_term_forecast.txt"]:
    if os.path.isdir(path):
        shutil.rmtree(path)
    elif os.path.exists(path):
        os.remove(path)

print("Datasets selected:")
for ds in datasets:
    print(f"- {ds['name']}: epochs={ds['train_epochs']}, itr={ds['itr']}, d_model={ds['d_model']}, batch={ds['batch_size']}, alpha={ds['alpha']}")
print("\nAttention modes selected:")
for mode in attention_modes:
    print(f"- {mode}")
print("\nHybrid configs selected:")
for cfg in configs:
    print(f"- {cfg['tag']}: gate={cfg['gate_mode']}, dropout={cfg['branch_dropout']}, temp={cfg['gate_temperature']}, residual={cfg['residual_branch']}")
# Out:
# Datasets selected:
# - smartbuilding: epochs=20, itr=3, d_model=64, batch=64, alpha=0.3
#
# Attention modes selected:
# - original
# - dual
#
# Hybrid configs selected:
# - Baseline: gate=soft, dropout=0.0, temp=0.5, residual=none
# - BranchDropout: gate=soft, dropout=0.15, temp=0.5, residual=none
# - SparseGate: gate=sparse, dropout=0.0, temp=0.3, residual=none
# - OneHotGate: gate=one_hot, dropout=0.0, temp=0.3, residual=none
# - ResidualFallback: gate=soft, dropout=0.0, temp=0.5, residual=swt
# - CombinedSparse: gate=sparse, dropout=0.15, temp=0.3, residual=swt

# %%
for ds in datasets:
    print("\n" + "=" * 100)
    print(f"DATASET: {ds['name']} | variates={ds['enc_in']} | Hybrid feature ablation")
    print("=" * 100 + "\n")

    for attention_mode in attention_modes:
        for cfg in configs:
            run_tag = f"{attention_mode}_{cfg['tag']}"
            print(f">>> Training Hybrid {run_tag} on {ds['name']} <<<\n")
            unique_model_id = f"{ds['name']}_SimpleTM_Hybrid_{attention_mode}_{cfg['tag']}"

            cmd = [
                "python", "-u", "run.py",
                "--is_training", "1",
                "--model", "SimpleTM_Hybrid",
                "--attention_mode", attention_mode,
                "--model_id", unique_model_id,
                "--data", ds["data"],
                "--root_path", ds["root"],
                "--data_path", ds["path"],
                "--features", "M",
                "--freq", ds["freq"],
                "--seq_len", "96",
                "--pred_len", "96",
                "--e_layers", str(ds["e_layers"]),
                "--d_model", str(ds["d_model"]),
                "--d_ff", str(ds["d_ff"]),
                "--enc_in", str(ds["enc_in"]),
                "--dec_in", str(ds["enc_in"]),
                "--c_out", str(ds["enc_in"]),
                "--wv", ds["wv"],
                "--m", str(ds["m"]),
                "--alpha", str(ds["alpha"]),
                "--l1_weight", str(ds["l1_weight"]),
                "--learning_rate", str(ds["learning_rate"]),
                "--batch_size", str(ds["batch_size"]),
                "--train_epochs", str(ds["train_epochs"]),
                "--patience", str(ds["patience"]),
                "--itr", str(ds["itr"]),
                "--num_workers", "2",
                "--lradj", ds["lradj"],
                "--use_norm", str(ds["use_norm"]),
                "--hybrid_gate_mode", cfg["gate_mode"],
                "--hybrid_branch_dropout", str(cfg["branch_dropout"]),
                "--hybrid_gate_temperature", str(cfg["gate_temperature"]),
                "--hybrid_residual_branch", cfg["residual_branch"],
                "--checkpoints", f"{OUTPUT_DIR}/checkpoints/",
                "--fix_seed", "2025",
                "--des", "HybridFeatureAblation",
            ]

            if "conv_kernel_sizes" in ds:
                cmd.extend(["--conv_kernel_sizes", ds["conv_kernel_sizes"]])
            if "target" in ds:
                cmd.extend(["--target", ds["target"]])

            log_file = os.path.join(LOG_DIR, f"{ds['name']}_{run_tag}.log")
            log_lines = []
            process = subprocess.Popen(cmd, stdout=subprocess.PIPE, stderr=subprocess.STDOUT, text=True)
            for line in process.stdout:
                print(line, end="")
                log_lines.append(line)
            process.wait()
            with open(log_file, "w", encoding="utf-8") as f:
                f.writelines(log_lines)
            print(f"Saved run log to: {log_file}")

            if process.returncode == 0:
                print(f"\nSUCCESS: Finished Hybrid {run_tag} on {ds['name']}\n")
            else:
                raise RuntimeError(f"Run failed for {ds['name']} | Hybrid {run_tag} with exit code {process.returncode}")

print("\nGathering generated plots and metric text...")
if os.path.exists("./checkpoints"):
    for root_dir, dirs, files in os.walk("./checkpoints"):
        for file in files:
            if file.endswith(".pdf") or file.endswith(".png"):
                folder_name = os.path.basename(root_dir)
                source_path = os.path.join(root_dir, file)
                target_plot_dir = os.path.join(OUTPUT_DIR, "plots", folder_name)
                os.makedirs(target_plot_dir, exist_ok=True)
                shutil.copy(source_path, os.path.join(target_plot_dir, file))

if os.path.exists("result_long_term_forecast.txt"):
    shutil.copy("result_long_term_forecast.txt", os.path.join(OUTPUT_DIR, "result_long_term_forecast.txt"))
    print("Copied metric text results to output directory.")
# Out:
# ====================================================================================================
# DATASET: smartbuilding | variates=37 | Hybrid feature ablation
# ====================================================================================================
#
# >>> Training Hybrid original_Baseline on smartbuilding <<<
#
# Args in experiment:
# Namespace(is_training=1, model_id='smartbuilding_SimpleTM_Hybrid_original_Baseline', model='SimpleTM_Hybrid', data='custom', root_path='./dataset/SimpleTM_datasets/smartbuilding', data_path='smart.csv', features='M', target='Floor_Total(kW)', freq='h', checkpoints='/kaggle/working/SimpleTM_HybridFeatureAblation_Results/checkpoints/', seq_len=96, label_len=0, pred_len=96, enc_in=37, dec_in=37, c_out=37, n_heads=8, d_layers=1, moving_avg=25, factor=1, distil=True, dropout=0.1, geomattn_dropout=0.5, embed='timeF', activation='gelu', do_predict=False, num_workers=2, itr=3, train_epochs=20, batch_size=64, patience=5, learning_rate=0.003, des='HybridFeatureAblation', loss='MSE', lradj='TST', pct_start=0.2, use_amp=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', exp_name='MTSF', channel_independence=False, inverse=False, class_strategy='projection', target_root_path='./data/electricity/', target_data_path='electricity.csv', efficient_training=False, use_norm=1, partial_start_index=0, requires_grad=True, wv='db4', m=3, kernel_size=None, conv_kernel_sizes=None, hybrid_gate_mode='soft', hybrid_branch_dropout=0.0, hybrid_gate_temperature=0.5, hybrid_residual_branch='none', alpha=0.3, learnable_alpha=False, l1_weight=5e-05, d_model=64, d_ff=128, e_layers=1, compile=False, output_attention=False, attention_mode='original', fix_seed=2025)
# Use GPU: cuda:0
# Total trainable parameters: 76601
# Memory usage for trainable parameters: 0.29 MB
# Static memory footprint (allocated): 0.30 MB
# Static memory footprint (reserved): 2.00 MB
# >>>>>>>start training : smartbuilding_SimpleTM_Hybrid_original_Baseline_SimpleTM_Hybrid_original_custom_96_96_64_128_1_db4_None_None_soft_0.0_0.5_none_3_0.3_False_5e-05_0.003_TST_64_2025_1_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 4758
# val 612
# test 1319
# 	iters: 30, epoch: 1 | loss: 1.0866238
# 	speed: 0.2184s/iter; left time: 316.9672s
# 	iters: 60, epoch: 1 | loss: 0.7854362
# 	speed: 0.1488s/iter; left time: 211.3905s
# Epoch: 1 cost time: 13.188903093338013
# Epoch: 1, Steps: 74 | Train Loss: 1.0020958 Vali Loss: 0.6510199 Test Loss: 0.6393596
# Validation loss decreased (inf --> 0.651020).  Saving model ...
# Updating learning rate to 0.000544480752230301
# 	iters: 30, epoch: 2 | loss: 0
# EarlyStopping counter: 1 out of 5
# Updating learning rate to 0.00011267402836130357
# 	iters: 30, epoch: 19 | loss: 0.4696089
# 	speed: 0.2375s/iter; left time: 28.2607s
# 	iters: 60, epoch: 19 | loss: 0.4283024
# 	speed: 0.1469s/iter; left time: 13.0709s
# Epoch: 19 cost time: 10.909721612930298
# Epoch: 19, Steps: 74 | Train Loss: 0.3946179 Vali Loss: 0.3074988 Test Loss: 0.2816938
# EarlyStopping counter: 2 out of 5
# Updating learning rate to 2.806267608106234e-05
# 	iters: 30, epoch: 20 | loss: 0.4015246
# 	speed: 0.2419s/iter; left time: 10.8844s
# 	iters: 60, epoch: 20 | loss: 0.4713487
# 	speed: 0.1467s/iter; left time: 2.2001s
# Epoch: 20 cost time: 10.96481728553772
# Epoch: 20, Steps: 74 | Train Loss: 0.3935650 Vali Loss: 0.3085141 Test Loss: 0.2818474
# EarlyStopping counter: 3 out of 5
# Updating learning rate to 1.728026369974621e-08
# >>>>>>>testing : smartbuilding_SimpleTM_Hybrid_original_Baseline_SimpleTM_Hybrid_original_custom_96_96_64_128_1_db4_None_None_soft_0.0_0.5_none_3_0.3_False_5e-05_0.003_TST_64_2025_1_2<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 1319
# test shape: (20, 64, 96, 37) (20, 64, 96, 37)
# test shape: (1280, 96, 37) (1280, 96, 37)
# Collected 16 examples for combined_prediction_examples.png
# mse:0.28316980600357056, mae:0.2904026210308075
# rmse:0.5321370363235474, mape:0.45168372988700867, mspe:1462.2655029296875
# rse:0.46871915459632874, corr:21.177734375, smape:0.5279555320739746, wape:0.3656032681465149, r2:0.7803023457527161
# Saved run log to: /kaggle/working/SimpleTM_HybridFeatureAblation_Results/logs/smartbuilding_original_Baseline.log
#
# SUCCESS: Finished Hybrid original_Baseline on smartbuilding
#
# >>> Training Hybrid original_BranchDropout on smartbuilding <<<
#
# Args in experiment:
# Namespace(is_training=1, model_id='smartbuilding_SimpleTM_Hybrid_original_BranchDropout', model='SimpleTM_Hybrid', data='custom', root_path='./dataset/SimpleTM_datasets/smartbuilding', data_path='smart.csv', features='M', target='Floor_Total(kW)', freq='h', checkpoints='/kaggle/working/SimpleTM_HybridFeatureAblation_Results/checkpoints/', seq_len=96, label_len=0, pred_len=96, enc_in=37, dec_in=37, c_out=37, n_heads=8, d_layers=1, moving_avg=25, factor=1, distil=True, dropout=0.1, geomattn_dropout=0.5, embed='timeF', activation='gelu', do_predict=False, num_workers=2, itr=3, train_epochs=20, batch_size=64, patience=5, learning_rate=0.003, des='HybridFeatureAblation', loss='MSE', lradj='TST', pct_start=0.2, use_amp=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', exp_name='MTSF', channel_independence=False, inverse=False, class_strategy='projection', target_root_path='./data/electricity/', target_data_path='electricity.csv', efficient_training=False, use_norm=1, partial_start_index=0, requires_grad=True, wv='db4', m=3, kernel_size=None, conv_kernel_sizes=None, hybrid_gate_mode='soft', hybrid_branch_dropout=0.15, hybrid_gate_temperature=0.5, hybrid_residual_branch='none', alpha=0.3, learnable_alpha=False, l1_weight=5e-05, d_model=64, d_ff=128, e_layers=1, compile=False, output_attention=False, attention_mode='original', fix_seed=2025)
# Use GPU: cuda:0
# Total trainable parameters: 76601
# Memory usage for trainable parameters: 0.29 MB
# Static memory footprint (allocated): 0.30 MB
# Static memory footprint (reserved): 2.00 MB
# >>>>>>>start training : smartbuilding_SimpleTM_Hybrid_original_BranchDropout_SimpleTM_Hybrid_original_custom_96_96_64_128_1_db4_None_None_soft_0.15_0.5_none_3_0.3_False_5e-05_0.003_TST_64_2025_1_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 4758
# val 612
# test 1319
# 	iters: 30, epoch: 1 | loss: 1.0876791
# 	speed: 0.1810s/iter; left time: 262.6462s
# 	iters: 60, epoch: 1 | loss: 0.7837602
# 	speed: 0.1521s/iter; left time: 216.1268s
# Epoch: 1 cost time: 12.16123914718628
# Epoch: 1, Steps: 74 | Train Loss: 1.0024086 Vali Loss: 0.6515555 Test Loss: 0.6396392
# Validation loss decreased (inf --> 0.651555).  Saving model ...
# Updating learning rate to 0.000544480752230301
# 	iters: 30, epoch: 2 | loss: 0.6837555
# 	speed: 0.2421s/iter; left time: 333.3677s
# 	iters: 60, epoch: 2 | loss: 0.6635287
# 	speed: 0.1515s/iter; left time: 204.0197s
# Epoch: 2 cost time: 11.186838388442993
# Epoch: 2, Steps: 74 | Train Loss: 0.6853685 Vali Loss: 0.5044422 Test Loss: 0.5084899
# Validation loss decreased (0.651555 --> 0.504442).  Saving model ...
# Updating learning rate to 0.0015676675797350902
# 	iters: 30, epoch: 3 | loss: 0.5957083
# 	speed: 0.2446s/iter; left time: 318.7593s
# 	iters: 60, epoch: 3 | loss: 0.5600880
# 	speed: 0.1497s/iter; left time: 190.5794s
# Epoch: 3 cost time: 11.213045835494995
# Epoch: 3, Steps: 74 | Train Loss: 0.5885647 Vali Loss: 0.3932469 Test Loss: 0.4041929
# Validation loss decreased (0.504442 --> 0.393247).  Saving model ...
# Updating learning rate to 0.0025863339349985787
# 	iters: 30, epoch: 4 | loss: 0.5379657
# 	speed: 0.2437s/iter; left time: 299.4505s
# 	iters: 60, epoch: 4 | loss: 0.5301259
# 	speed: 0.1485s/iter; left time: 178.0474s
# Epoch: 4 cost time: 11.141025066375732
# Epoch: 4, Steps: 74 | Train Loss: 0.5282810 Vali Loss: 0.3578743 Test Loss: 0.3567843
# Validation loss decreased (0.393247 --> 0.357874).  Saving model ...
# Updating learning rate to 0.0029999947197363007
# 	iters: 30, epoch: 5 | loss: 0.
# EarlyStopping counter: 1 out of 5
# Updating learning rate to 0.0004365394929452589
# 	iters: 30, epoch: 17 | loss: 0.4685735
# 	speed: 0.2897s/iter; left time: 77.3397s
# 	iters: 60, epoch: 17 | loss: 0.4119771
# 	speed: 0.1887s/iter; left time: 44.7160s
# Epoch: 17 cost time: 13.546715021133423
# Epoch: 17, Steps: 74 | Train Loss: 0.3878616 Vali Loss: 0.3084195 Test Loss: 0.2843235
# EarlyStopping counter: 2 out of 5
# Updating learning rate to 0.0002505997702868865
# 	iters: 30, epoch: 18 | loss: 0.3889385
# 	speed: 0.2918s/iter; left time: 56.3198s
# 	iters: 60, epoch: 18 | loss: 0.3114915
# 	speed: 0.1788s/iter; left time: 29.1489s
# Epoch: 18 cost time: 13.38088607788086
# Epoch: 18, Steps: 74 | Train Loss: 0.3873100 Vali Loss: 0.3063740 Test Loss: 0.2859485
# EarlyStopping counter: 3 out of 5
# Updating learning rate to 0.00011267402836130357
# 	iters: 30, epoch: 19 | loss: 0.4109373
# 	speed: 0.2909s/iter; left time: 34.6122s
# 	iters: 60, epoch: 19 | loss: 0.3476197
# 	speed: 0.1778s/iter; left time: 15.8279s
# Epoch: 19 cost time: 13.34386944770813
# Epoch: 19, Steps: 74 | Train Loss: 0.3857952 Vali Loss: 0.3042527 Test Loss: 0.2840880
# Validation loss decreased (0.304655 --> 0.304253).  Saving model ...
# Updating learning rate to 2.806267608106234e-05
# 	iters: 30, epoch: 20 | loss: 0.5127816
# 	speed: 0.2911s/iter; left time: 13.0975s
# 	iters: 60, epoch: 20 | loss: 0.3942090
# 	speed: 0.1791s/iter; left time: 2.6869s
# Epoch: 20 cost time: 13.338500738143921
# Epoch: 20, Steps: 74 | Train Loss: 0.3846466 Vali Loss: 0.3063208 Test Loss: 0.2842384
# EarlyStopping counter: 1 out of 5
# Updating learning rate to 1.728026369974621e-08
# >>>>>>>testing : smartbuilding_SimpleTM_Hybrid_dual_CombinedSparse_SimpleTM_Hybrid_dual_custom_96_96_64_128_1_db4_None_None_sparse_0.15_0.3_swt_3_0.3_False_5e-05_0.003_TST_64_2025_1_2<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 1319
# test shape: (20, 64, 96, 37) (20, 64, 96, 37)
# test shape: (1280, 96, 37) (1280, 96, 37)
# Collected 16 examples for combined_prediction_examples.png
# mse:0.2840879559516907, mae:0.3003326952457428
# rmse:0.5329990386962891, mape:0.4596404731273651, mspe:1351.36279296875
# rse:0.46947842836380005, corr:21.17540740966797, smape:0.5386694669723511, wape:0.3781047463417053, r2:0.7795900106430054
# Saved run log to: /kaggle/working/SimpleTM_HybridFeatureAblation_Results/logs/smartbuilding_dual_CombinedSparse.log
#
# SUCCESS: Finished Hybrid dual_CombinedSparse on smartbuilding
#
#
# Gathering generated plots and metric text...
# Copied metric text results to output directory.

# %%
results_file = os.path.join(OUTPUT_DIR, "result_long_term_forecast.txt")
root_results_file = "result_long_term_forecast.txt"
metric_order = ["MSE", "MAE", "RMSE", "MAPE", "WAPE", "R2"]
setting_pattern = re.compile(r"^(?P<dataset>[^_]+)_SimpleTM_Hybrid_(?P<attention>original|dual)_(?P<config>[^_]+)_SimpleTM_Hybrid_")
metric_pattern = re.compile(r"([a-zA-Z0-9_]+):([^,]+)")

if not os.path.exists(results_file):
    if os.path.exists(root_results_file):
        print(f"Result file was not copied to OUTPUT_DIR. Copying from repo root: {root_results_file}")
        os.makedirs(OUTPUT_DIR, exist_ok=True)
        shutil.copy(root_results_file, results_file)
    else:
        log_dir = os.path.join(OUTPUT_DIR, "logs")
        log_files = glob.glob(os.path.join(log_dir, "*.log")) if os.path.exists(log_dir) else []
        raise FileNotFoundError(
            f"{results_file} was not found. Run the training cell before this parsing cell. "
            "If you reran the configuration cell after training, it deleted OUTPUT_DIR and the result file. "
            f"Found {len(log_files)} log files in {log_dir}. If this is 0, training did not run or failed before testing."
        )

with open(results_file, "r", encoding="utf-8") as f:
    content = f.read().strip()

rows = []
for entry in content.split("\n\n") if content else []:
    lines = [line.strip() for line in entry.splitlines() if line.strip()]
    if len(lines) < 2:
        continue
    setting = lines[0]
    metrics_line = lines[-1]
    match = setting_pattern.search(setting)
    if not match:
        continue

    row = {
        "Dataset": match.group("dataset"),
        "Model": "SimpleTM_Hybrid",
        "AttentionMode": match.group("attention"),
        "HybridConfig": match.group("config"),
        "Variant": f"Hybrid_{match.group('attention')}_{match.group('config')}",
        "Setting": setting,
    }
    for metric_name, value in metric_pattern.findall(metrics_line):
        try:
            row[metric_name.upper()] = float(value.strip())
        except ValueError:
            pass
    rows.append(row)

if not rows:
    raise RuntimeError("No valid metrics found in result file.")

raw_df = pd.DataFrame(rows).sort_values(["Dataset", "AttentionMode", "HybridConfig", "Setting"]).reset_index(drop=True)
value_columns = [col for col in metric_order if col in raw_df.columns]

raw_path = os.path.join(OUTPUT_DIR, "raw_metrics.csv")
raw_df.to_csv(raw_path, index=False)

agg_df = raw_df.groupby(["Dataset", "AttentionMode", "HybridConfig", "Variant"], as_index=False)[value_columns].mean(numeric_only=True)
count_df = raw_df.groupby(["Dataset", "AttentionMode", "HybridConfig", "Variant"], as_index=False).size().rename(columns={"size": "NumRuns"})
agg_df = agg_df.merge(count_df, on=["Dataset", "AttentionMode", "HybridConfig", "Variant"], how="left")
averaged_path = os.path.join(OUTPUT_DIR, "averaged_metrics.csv")
agg_df.to_csv(averaged_path, index=False)

comparison = agg_df.pivot_table(index=["Dataset", "AttentionMode"], columns="HybridConfig", values=value_columns, aggfunc="mean")
comparison_path = os.path.join(OUTPUT_DIR, "hybrid_feature_comparison.csv")
comparison.to_csv(comparison_path)

print("Raw runs:")
display(raw_df)
print("Averaged Hybrid feature ablation results:")
display(agg_df.sort_values(["Dataset", "AttentionMode", "HybridConfig"]))
print(f"Saved raw results to: {raw_path}")
print(f"Saved averaged results to: {averaged_path}")
print(f"Saved comparison table to: {comparison_path}")
# Out:
# Raw runs:
#           Dataset            Model AttentionMode      HybridConfig  \
# 0   smartbuilding  SimpleTM_Hybrid          dual          Baseline
# 1   smartbuilding  SimpleTM_Hybrid          dual          Baseline
# 2   smartbuilding  SimpleTM_Hybrid          dual          Baseline
# 3   smartbuilding  SimpleTM_Hybrid          dual     BranchDropout
# 4   smartbuilding  SimpleTM_Hybrid          dual     BranchDropout
# 5   smartbuilding  SimpleTM_Hybrid          dual     BranchDropout
# 6   smartbuilding  SimpleTM_Hybrid          dual    CombinedSparse
# 7   smartbuilding  SimpleTM_Hybrid          dual    CombinedSparse
# 8   smartbuilding  SimpleTM_Hybrid          dual    CombinedSparse
# 9   smartbuilding  SimpleTM_Hybrid          dual        OneHotGate
# 10  smartbuilding  SimpleTM_Hybrid          dual        OneHotGate
# 11  smartbuilding  SimpleTM_Hybrid          dual        OneHotGate
# 12  smartbuilding  SimpleTM_Hybrid          dual  ResidualFallback
# 13  smartbuilding  SimpleTM_Hybrid          dual  ResidualFallback
# 14  smartbuilding  SimpleTM_Hybrid          dual  ResidualFallback
# 15  smartbuilding  SimpleTM_Hybrid          dual        SparseGate
# 16  smartbuilding  SimpleTM_Hybrid          dual        SparseGate
# 17  smartbuilding  SimpleTM_Hybrid          dual        SparseGate
# 18  smartbuilding  SimpleTM_Hybrid      original          Baseline
# 19  smartbuilding  SimpleTM_Hybrid      original          Baseline
# 20  smartbuilding  SimpleTM_Hybrid      original          Baseline
# 21  smartbuilding  SimpleTM_Hybrid      original     BranchDropout
# 22  smartbuilding  SimpleTM_Hybrid      original     BranchDropout
# 23  smartbuilding  SimpleTM_Hybrid      original     BranchDropout
# 24  smartbuilding  SimpleTM_Hybrid      original    CombinedSparse
# 25  smartbuilding  SimpleTM_Hybrid      original    CombinedSparse
# 26  smartbuilding  SimpleTM_Hybrid      original    CombinedSparse
# 27  smartbuilding  SimpleTM_Hybrid      original        OneHotGate
# 28  smartbuilding  SimpleTM_Hybrid      original        OneHotGate
# 29  smartbuilding  SimpleTM_Hybrid      original        OneHotGate
# 30  smartbuilding  SimpleTM_Hybrid      original  ResidualFallback
# 31  smartbuilding  SimpleTM_Hybrid      original  ResidualFallback
# 32  smartbuilding  SimpleTM_Hybrid      original  ResidualFallback
# 33  smartbuilding  SimpleTM_Hybrid      original        SparseGate
# 34  smartbuilding  SimpleTM_Hybrid      original        SparseGate
# 35  smartbuilding  SimpleTM_Hybrid      original        SparseGate
#
#                              Variant  \
# 0               Hybrid_dual_Baseline
# 1               Hybrid_dual_Baseline
# 2               Hybrid_dual_Baseline
# 3          Hybrid_dual_BranchDropout
# 4          Hybrid_dual_BranchDropout
# 5          Hybrid_dual_BranchDropout
# 6         Hybrid_dual_CombinedSparse
# 7         Hybrid_dual_CombinedSparse
# 8         Hybrid_dual_CombinedSparse
# 9             Hybrid_dual_OneHotGate
# 10            Hybrid_dual_OneHotGate
# 11            Hybrid_dual_OneHotGate
# 12      Hybrid_dual_ResidualFallback
# 13      Hybrid_dual_ResidualFallback
# 14      Hybrid_dual_ResidualFallback
# 15            Hybrid_dual_SparseGate
# 16            Hybrid_dual_SparseGate
# 17            Hybrid_dual_SparseGate
# 18          Hybrid_original_Baseline
# 19          Hybrid_original_Baseline
# 20          Hybrid_original_Baseline
# 21     Hybrid_original_BranchDropout
# 22     Hybrid_original_BranchDropout
# 23     Hybrid_original_BranchDropout
# 24    Hybrid_original_CombinedSparse
# 25    Hybrid_original_CombinedSparse
# 26    Hybrid_original_CombinedSparse
# 27        Hybrid_original_OneHotGate
# 28        Hybrid_original_OneHotGate
# 29        Hybrid_original_OneHotGate
# 30  Hybrid_original_ResidualFallback
# 31  Hybrid_original_ResidualFallback
# 32  Hybrid_original_ResidualFallback
# 33        Hybrid_original_SparseGate
# 34        Hybrid_original_SparseGate
# 35        Hybrid_original_SparseGate
#
#                                               Setting       MAE       MSE  \
# 0   smartbuilding_SimpleTM_Hybrid_dual_Baseline_Si...  0.308142  0.295351
# 1   smartbuilding_SimpleTM_Hybrid_dual_Baseline_Si...  0.317135  0.311681
# 2   smartbuilding_SimpleTM_Hybrid_dual_Baseline_Si...  0.300301  0.290250
# 3   smartbuilding_SimpleTM_Hybrid_dual_BranchDropo...  0.300692  0.294493
# 4   smartbuilding_SimpleTM_Hybrid_dual_BranchDropo...  0.307265  0.298121
# 5   smartbuilding_SimpleTM_Hybrid_dual_BranchDropo...  0.307218  0.296024
# 6   smartbuilding_SimpleTM_Hybrid_dual_CombinedSpa...  0.305198  0.293241
# 7   smartbuilding_SimpleTM_Hybrid_dual_CombinedSpa...  0.301585  0.285942
# 8   smartbuilding_SimpleTM_Hybrid_dual_CombinedSpa...  0.300333  0.284088
# 9   smartbuilding_SimpleTM_Hybrid_dual_OneHotGate_...  0.305152  0.296925
# 10  smartbuilding_SimpleTM_Hybrid_dual_OneHotGate_...  0.303946  0.294119
# 11  smartbuilding_SimpleTM_Hybrid_dual_OneHotGate_...  0.297344  0.286435
# 12  smartbuilding_SimpleTM_Hybrid_dual_ResidualFal...  0.301604  0.288930
# 13  smartbuilding_SimpleTM_Hybrid_dual_ResidualFal...  0.304057  0.288428
# 14  smartbuilding_SimpleTM_Hybrid_dual_ResidualFal...  0.299163  0.283991
# 15  smartbuilding_SimpleTM_Hybrid_dual_SparseGate_...  0.310201  0.306414
# 16  smartbuilding_SimpleTM_Hybrid_dual_SparseGate_...  0.297333  0.286657
# 17  smartbuilding_SimpleTM_Hybrid_dual_SparseGate_...  0.300635  0.294298
# 18  smartbuilding_SimpleTM_Hybrid_original_Baselin...  0.292601  0.280612
# 19  smartbuilding_SimpleTM_Hybrid_original_Baselin...  0.288269  0.281569
# 20  smartbuilding_SimpleTM_Hybrid_original_Baselin...  0.290403  0.283170
# 21  smartbuilding_SimpleTM_Hybrid_original_BranchD...  0.292796  0.277419
# 22  smartbuilding_SimpleTM_Hybrid_original_BranchD...  0.290629  0.276510
# 23  smartbuilding_SimpleTM_Hybrid_original_BranchD...  0.292918  0.282363
# 24  smartbuilding_SimpleTM_Hybrid_original_Combine...  0.290160  0.274700
# 25  smartbuilding_SimpleTM_Hybrid_original_Combine...  0.287909  0.273606
# 26  smartbuilding_SimpleTM_Hybrid_original_Combine...  0.289846  0.273557
# 27  smartbuilding_SimpleTM_Hybrid_original_OneHotG...  0.293331  0.281180
# 28  smartbuilding_SimpleTM_Hybrid_original_OneHotG...  0.289410  0.279553
# 29  smartbuilding_SimpleTM_Hybrid_original_OneHotG...  0.293828  0.284409
# 30  smartbuilding_SimpleTM_Hybrid_original_Residua...  0.289644  0.274642
# 31  smartbuilding_SimpleTM_Hybrid_original_Residua...  0.290687  0.276124
# 32  smartbuilding_SimpleTM_Hybrid_original_Residua...  0.289092  0.272420
# 33  smartbuilding_SimpleTM_Hybrid_original_SparseG...  0.292337  0.279684
# 34  smartbuilding_SimpleTM_Hybrid_original_SparseG...  0.289087  0.278340
# 2   0.774809
# 3   0.771517
# 4   0.768702
# 5   0.770329
# 6   0.772488
# 7   0.778152
# 8   0.779590
# 9   0.769631
# 10  0.771807
# 11  0.777769
# 12  0.775833
# 13  0.776223
# 14  0.779665
# 15  0.762268
# 16  0.777597
# 17  0.771668
# 18  0.782287
# 19  0.781544
# 20  0.780302
# 21  0.784764
# 22  0.785469
# 23  0.780929
# 24  0.786874
# 25  0.787723
# 26  0.787760
# 27  0.781846
# 28  0.783109
# 29  0.779341
# 30  0.786919
# 31  0.785769
# 32  0.788643
# 33  0.783007
# 34  0.784050
# 35  0.780276
# Averaged Hybrid feature ablation results:
#           Dataset AttentionMode      HybridConfig  \
# 0   smartbuilding          dual          Baseline
# 1   smartbuilding          dual     BranchDropout
# 2   smartbuilding          dual    CombinedSparse
# 3   smartbuilding          dual        OneHotGate
# 4   smartbuilding          dual  ResidualFallback
# 5   smartbuilding          dual        SparseGate
# 6   smartbuilding      original          Baseline
# 7   smartbuilding      original     BranchDropout
# 8   smartbuilding      original    CombinedSparse
# 9   smartbuilding      original        OneHotGate
# 10  smartbuilding      original  ResidualFallback
# 11  smartbuilding      original        SparseGate
#
#                              Variant       MSE       MAE      RMSE      MAPE  \
# 0               Hybrid_dual_Baseline  0.299094  0.308526  0.546831  0.472904
# 1          Hybrid_dual_BranchDropout  0.296213  0.305058  0.544252  0.469734
# 2         Hybrid_dual_CombinedSparse  0.287757  0.302372  0.536417  0.464273
# 3             Hybrid_dual_OneHotGate  0.292493  0.302147  0.540811  0.462241
# 4       Hybrid_dual_ResidualFallback  0.287116  0.301608  0.535828  0.464399
# 5             Hybrid_dual_SparseGate  0.295790  0.302723  0.543814  0.465078
# 6           Hybrid_original_Baseline  0.281784  0.290424  0.530832  0.449631
# 7      Hybrid_original_BranchDropout  0.278764  0.292114  0.527975  0.452370
# 8     Hybrid_original_CombinedSparse  0.273954  0.289305  0.523406  0.447991
# 9         Hybrid_original_OneHotGate  0.281714  0.292190  0.530764  0.451715
# 10  Hybrid_original_ResidualFallback  0.274395  0.289807  0.523826  0.449352
# 11        Hybrid_original_SparseGate  0.280409  0.290811  0.529533  0.448873
#
#         WAPE        R2  NumRuns
# 0   0.388420  0.767948        3
# 1   0.384054  0.770183        3
# 2   0.380672  0.776743        3
# 3   0.380389  0.773069        3
# 4   0.379710  0.777240        3
# 5   0.381114  0.770511        3
# 6   0.365630  0.781378        3
# 7   0.367758  0.783721        3
# 8   0.364221  0.787452        3
# 9   0.367853  0.781432        3
# 10  0.364854  0.787110        3
# 11  0.366117  0.782444        3
# Saved raw results to: /kaggle/working/SimpleTM_HybridFeatureAblation_Results/raw_metrics.csv
# Saved averaged results to: /kaggle/working/SimpleTM_HybridFeatureAblation_Results/averaged_metrics.csv
# Saved comparison table to: /kaggle/working/SimpleTM_HybridFeatureAblation_Results/hybrid_feature_comparison.csv

# %%
import matplotlib.pyplot as plt

MAX_LEARNING_CURVES_TO_SHOW = 12
LEARNING_CURVE_DIR = os.path.join(OUTPUT_DIR, "learning_curves")
os.makedirs(LEARNING_CURVE_DIR, exist_ok=True)

epoch_pattern = re.compile(
    r"Epoch:\s*(?P<epoch>\d+),\s*Steps:\s*\d+\s*\|\s*"
    r"Train Loss:\s*(?P<train>[0-9.eE+-]+)\s*"
    r"Vali Loss:\s*(?P<vali>[0-9.eE+-]+)\s*"
    r"Test Loss:\s*(?P<test>[0-9.eE+-]+)"
)

learning_rows = []
for log_path in sorted(glob.glob(os.path.join(OUTPUT_DIR, "logs", "*.log"))):
    stem = os.path.splitext(os.path.basename(log_path))[0]
    dataset_name, attention_mode, config_tag = stem.split("_", 2)
    repeat = 0
    previous_epoch = 0
    with open(log_path, "r", encoding="utf-8") as f:
        for line in f:
            match = epoch_pattern.search(line)
            if not match:
                continue
            epoch = int(match.group("epoch"))
            if previous_epoch and epoch <= previous_epoch:
                repeat += 1
            previous_epoch = epoch
            learning_rows.append({
                "Dataset": dataset_name,
                "AttentionMode": attention_mode,
                "HybridConfig": config_tag,
                "Repeat": repeat,
                "Epoch": epoch,
                "TrainLoss": float(match.group("train")),
                "ValiLoss": float(match.group("vali")),
                "TestLoss": float(match.group("test")),
                "LogFile": log_path,
            })

learning_df = pd.DataFrame(learning_rows)
if learning_df.empty:
    print("No epoch-wise learning curves found. Run the training cell first.")
else:
    learning_csv = os.path.join(OUTPUT_DIR, "learning_curves.csv")
    learning_df.to_csv(learning_csv, index=False)
    print(f"Saved learning-curve data to: {learning_csv}")
    display(learning_df.head(20))

    shown = 0
    for (dataset_name, attention_mode), curve_df in learning_df.groupby(["Dataset", "AttentionMode"]):
        fig, ax = plt.subplots(figsize=(12, 6))
        for config_tag, mode_df in curve_df.groupby("HybridConfig"):
            mode_df = mode_df.groupby("Epoch", as_index=False)[["TrainLoss", "ValiLoss", "TestLoss"]].mean().sort_values("Epoch")
            ax.plot(mode_df["Epoch"], mode_df["ValiLoss"], marker="o", linewidth=2.0, label=f"{config_tag} val")

        ax.set_title(f"{dataset_name} | Hybrid {attention_mode}: validation learning curves")
        ax.set_xlabel("Epoch")
        ax.set_ylabel("Validation Loss")
        ax.grid(alpha=0.3)
        ax.legend(fontsize=9)
        plt.tight_layout()
        curve_path = os.path.join(LEARNING_CURVE_DIR, f"{dataset_name}_{attention_mode}_validation_learning_curve.png")
        plt.savefig(curve_path, dpi=180, bbox_inches="tight")
        if shown < MAX_LEARNING_CURVES_TO_SHOW:
            plt.show()
            shown += 1
        else:
            plt.close(fig)

    print(f"Saved learning-curve plots to: {LEARNING_CURVE_DIR}")
# Out:
# Saved learning-curve data to: /kaggle/working/SimpleTM_HybridFeatureAblation_Results/learning_curves.csv
#           Dataset AttentionMode HybridConfig  Repeat  Epoch  TrainLoss  \
# 0   smartbuilding          dual     Baseline       0      1   0.952367
# 1   smartbuilding          dual     Baseline       0      2   0.666388
# 2   smartbuilding          dual     Baseline       0      3   0.561413
# 3   smartbuilding          dual     Baseline       0      4   0.500209
# 4   smartbuilding          dual     Baseline       0      5   0.471181
# 5   smartbuilding          dual     Baseline       0      6   0.453352
# 6   smartbuilding          dual     Baseline       0      7   0.442912
# 7   smartbuilding          dual     Baseline       0      8   0.431801
# 8   smartbuilding          dual     Baseline       0      9   0.421361
# 9   smartbuilding          dual     Baseline       0     10   0.415143
# 10  smartbuilding          dual     Baseline       0     11   0.406758
# 11  smartbuilding          dual     Baseline       0     12   0.401000
# 12  smartbuilding          dual     Baseline       0     13   0.396386
# 13  smartbuilding          dual     Baseline       0     14   0.390139
# 14  smartbuilding          dual     Baseline       0     15   0.386959
# 15  smartbuilding          dual     Baseline       0     16   0.383981
# 16  smartbuilding          dual     Baseline       0     17   0.381440
# 17  smartbuilding          dual     Baseline       1      1   1.006236
# 18  smartbuilding          dual     Baseline       1      2   0.668868
# 19  smartbuilding          dual     Baseline       1      3   0.549373
#
#     ValiLoss  TestLoss                                            LogFile
# 0   0.632496  0.624536  /kaggle/working/SimpleTM_HybridFeatureAblation...
# 1   0.471949  0.483574  /kaggle/working/SimpleTM_HybridFeatureAblation...
# 2   0.388220  0.390262  /kaggle/working/SimpleTM_HybridFeatureAblation...
# 3   0.345268  0.345058  /kaggle/working/SimpleTM_HybridFeatureAblation...
# 4   0.335289  0.327531  /kaggle/working/SimpleTM_HybridFeatureAblation...
# 5   0.333531  0.310745  /kaggle/working/SimpleTM_HybridFeatureAblation...
# 6   0.341056  0.320448  /kaggle/working/SimpleTM_HybridFeatureAblation...
# 7   0.321712  0.305065  /kaggle/working/SimpleTM_HybridFeatureAblation...
# 8   0.321845  0.300283  /kaggle/working/SimpleTM_HybridFeatureAblation...
# 9   0.321149  0.299789  /kaggle/working/SimpleTM_HybridFeatureAblation...
# 10  0.315963  0.293876  /kaggle/working/SimpleTM_HybridFeatureAblation...
# 11  0.313974  0.295351  /kaggle/working/SimpleTM_HybridFeatureAblation...
# 12  0.318630  0.287502  /kaggle/working/SimpleTM_HybridFeatureAblation...
# 13  0.318433  0.287309  /kaggle/working/SimpleTM_HybridFeatureAblation...
# 14  0.317759  0.284774  /kaggle/working/SimpleTM_HybridFeatureAblation...
# 15  0.319822  0.284531  /kaggle/working/SimpleTM_HybridFeatureAblation...
# 16  0.314243  0.285414  /kaggle/working/SimpleTM_HybridFeatureAblation...
# 17  0.643660  0.640605  /kaggle/working/SimpleTM_HybridFeatureAblation...
# 18  0.454747  0.472980  /kaggle/working/SimpleTM_HybridFeatureAblation...
# 19  0.397901  0.403845  /kaggle/working/SimpleTM_HybridFeatureAblation...
# Saved learning-curve plots to: /kaggle/working/SimpleTM_HybridFeatureAblation_Results/learning_curves

# %%
if "agg_df" in globals() and not agg_df.empty:
    metric = "MSE" if "MSE" in agg_df.columns else value_columns[0]
    for dataset_name, ds_df in agg_df.groupby("Dataset"):
        for attention_mode, mode_df in ds_df.groupby("AttentionMode"):
            plot_df = mode_df.set_index("HybridConfig")[[metric]].sort_values(metric)
            ax = plot_df.plot(kind="bar", figsize=(12, 5), legend=False, color="#4C78A8")
            ax.set_title(f"{dataset_name}: Hybrid {attention_mode} feature ablation ({metric}, lower is better)")
            ax.set_xlabel("Hybrid Config")
            ax.set_ylabel(metric)
            ax.grid(axis="y", alpha=0.3)
            plt.xticks(rotation=30, ha="right")
            plt.tight_layout()
            plot_path = os.path.join(OUTPUT_DIR, f"{dataset_name}_{attention_mode}_hybrid_feature_{metric}.png")
            plt.savefig(plot_path, dpi=180, bbox_inches="tight")
            plt.show()

    best_rows = agg_df.sort_values(["Dataset", "AttentionMode", metric]).groupby(["Dataset", "AttentionMode"], as_index=False).first()
    print(f"Best config by {metric}:")
    display(best_rows[["Dataset", "AttentionMode", "HybridConfig", metric, "MAE"] if "MAE" in best_rows.columns else ["Dataset", "AttentionMode", "HybridConfig", metric]])
# Out:
# Best config by MSE:
#          Dataset AttentionMode      HybridConfig       MSE       MAE
# 0  smartbuilding          dual  ResidualFallback  0.287116  0.301608
# 1  smartbuilding      original    CombinedSparse  0.273954  0.289305

# %%
print("Packing logs, checkpoints, plots, and CSV results...")
archive_path = shutil.make_archive("/kaggle/working/SimpleTM_HybridFeatureAblation_Results", "zip", OUTPUT_DIR)
print(f"DONE. Download this archive from the Kaggle Output pane: {archive_path}")
# Out:
# Packing logs, checkpoints, plots, and CSV results...
# DONE. Download this archive from the Kaggle Output pane: /kaggle/working/SimpleTM_HybridFeatureAblation_Results.zip
