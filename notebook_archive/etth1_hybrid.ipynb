# %% [markdown]
# # SimpleTMG etth1 Hybrid- Kaggle

# %%
# !pip install PyWavelets gdown --quiet

import os
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"

import glob
import re
import shutil
import subprocess
import zipfile

import pandas as pd
import torch
from IPython.display import display

print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
# Out:
# PyTorch version: 2.10.0+cu128
# CUDA available: True
# GPU: Tesla T4

# %%
REPO_URL = "https://github.com/agamswami/simpleTM-show"
REPO_DIR = "/kaggle/working/SimpleTM"

if os.path.exists(REPO_DIR):
    print("Repo already exists. Pulling latest changes...")
    subprocess.run(["git", "-C", REPO_DIR, "pull"], check=True)
else:
    subprocess.run(["git", "clone", REPO_URL, REPO_DIR], check=True)

os.chdir(REPO_DIR)
print(f"Working directory: {os.getcwd()}")

subprocess.run(["sed", "-i", r"s/np\.Inf/np.inf/g", "utils/tools.py"], check=True)

with open("run.py", "r", encoding="utf-8") as f:
    run_source = f.read()

required_flags = [
    "--hybrid_gate_mode",
    "--hybrid_branch_dropout",
    "--hybrid_gate_temperature",
    "--hybrid_residual_branch",
]
missing_flags = [flag for flag in required_flags if flag not in run_source]
if missing_flags:
    raise RuntimeError(f"This GitHub clone is missing Hybrid ablation flags: {missing_flags}. Push the local code changes before running this notebook.")

print("Hybrid ablation CLI flags found in run.py")
# Out:
# Cloning into '/kaggle/working/SimpleTM'...
# Working directory: /kaggle/working/SimpleTM
# Hybrid ablation CLI flags found in run.py

# %%
FILE_ID = "1JOgmL2ntyxKg6eB132ytCbVZumiHnDLR"
OUTPUT_PATH = "/kaggle/working/dataset.zip"
DATASET_DIR = "./dataset"

if not os.path.exists(DATASET_DIR):
    download_url = f"https://drive.google.com/uc?id={FILE_ID}"
    subprocess.run(["gdown", download_url, "-O", OUTPUT_PATH], check=True)
    if not os.path.exists(OUTPUT_PATH):
        raise FileNotFoundError(f"Dataset download failed: {OUTPUT_PATH}")
    os.makedirs(DATASET_DIR, exist_ok=True)
    with zipfile.ZipFile(OUTPUT_PATH, "r") as zip_ref:
        zip_ref.extractall(DATASET_DIR)
    print("Dataset extracted successfully.")
else:
    print("Dataset already exists.")

for root, dirs, files in os.walk(DATASET_DIR):
    level = root.replace(DATASET_DIR, "").count(os.sep)
    indent = " " * 2 * level
    print(f"{indent}{os.path.basename(root)}/")
    subindent = " " * 2 * (level + 1)
    for file in files[:8]:
        print(f"{subindent}{file}")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1JOgmL2ntyxKg6eB132ytCbVZumiHnDLR
# From (redirected): https://drive.google.com/uc?id=1JOgmL2ntyxKg6eB132ytCbVZumiHnDLR&confirm=t&uuid=38fac7be-320a-4a03-8350-361f15bff2fe
# To: /kaggle/working/dataset.zip
# 100%|██████████| 172M/172M [00:01<00:00, 141MB/s]
# Dataset extracted successfully.
# dataset/
#   __MACOSX/
#     ._SimpleTM_datasets
#     SimpleTM_datasets/
#       ._.DS_Store
#       ._PEMS
#       ._ETT-small
#       ._weather
#       ._traffic
#       ._electricity
#       ._Solar
#       traffic/
#         ._.DS_Store
#         ._traffic.csv
#       electricity/
#         ._.DS_Store
#         ._electricity.csv
#       ETT-small/
#         ._ETTh1.csv
#         ._ETTm2.csv
#         ._ETTh2.csv
#         ._ETTm1.csv
#       Solar/
#         ._solar_AL.txt
#       PEMS/
#         ._PEMS03.npz
#         ._PEMS08.npz
#         ._PEMS04.npz
#         ._PEMS07.npz
#       weather/
#         ._weather.csv
#   SimpleTM_datasets/
#     .DS_Store
#     traffic/
#       .DS_Store
#       traffic.csv
#     electricity/
#       .DS_Store
#       electricity.csv
#     ETT-small/
#       ETTm2.csv
#       ETTh1.csv
#       ETTh2.csv
#       ETTm1.csv
#     Solar/
#       solar_AL.txt
#     PEMS/
#       PEMS07.npz
#       PEMS03.npz
#       PEMS08.npz
#       PEMS04.npz
#     weather/
#       weather.csv
#     smartbuilding/
#       smart.csv

# %%
# Set selectors to None for the full grid.
SELECTED_DATASETS = ["ETTh1"]
SELECTED_ATTENTION_MODES = None
SELECTED_HYBRID_CONFIGS = None

# Residual fallback branch used by ResidualFallback and CombinedSparse configs.
# Change to "fft" or "conv" if your previous results show those are stronger for the target dataset.
DEFAULT_RESIDUAL_BRANCH = "swt"

all_datasets = [
    {"name": "ETTh1", "data": "ETTh1", "root": "./dataset/SimpleTM_datasets/ETT-small", "path": "ETTh1.csv", "enc_in": 7, "d_model": 32, "d_ff": 32, "e_layers": 1, "wv": "db1", "m": 3, "alpha": 0.3, "learning_rate": 0.02, "batch_size": 256, "train_epochs": 10, "patience": 3, "use_norm": 1, "lradj": "TST", "freq": "h", "itr": 3, "l1_weight": 0.0005},
    # {"name": "ETTm1", "data": "ETTm1", "root": "./dataset/SimpleTM_datasets/ETT-small", "path": "ETTm1.csv", "enc_in": 7, "d_model": 32, "d_ff": 32, "e_layers": 1, "wv": "db1", "m": 3, "alpha": 0.1, "learning_rate": 0.02, "batch_size": 256, "train_epochs": 10, "patience": 3, "use_norm": 1, "lradj": "TST", "freq": "t", "itr": 3, "l1_weight": 0.005},
    # {"name": "weather", "data": "custom", "root": "./dataset/SimpleTM_datasets/weather", "path": "weather.csv", "enc_in": 21, "d_model": 32, "d_ff": 32, "e_layers": 4, "wv": "db4", "m": 3, "alpha": 0.3, "learning_rate": 0.01, "batch_size": 256, "train_epochs": 10, "patience": 3, "use_norm": 1, "lradj": "TST", "freq": "h", "itr": 3, "l1_weight": 5e-05},
    # {"name": "electricity", "data": "custom", "root": "./dataset/SimpleTM_datasets/electricity", "path": "electricity.csv", "enc_in": 321, "d_model": 256, "d_ff": 1024, "e_layers": 1, "wv": "db1", "m": 3, "alpha": 0.0, "learning_rate": 0.01, "batch_size": 256, "train_epochs": 10, "patience": 3, "use_norm": 1, "lradj": "TST", "freq": "h", "itr": 1, "l1_weight": 0.0},
    # {"name": "traffic", "data": "custom", "root": "./dataset/SimpleTM_datasets/traffic", "path": "traffic.csv", "enc_in": 862, "d_model": 512, "d_ff": 1024, "e_layers": 2, "wv": "db1", "m": 3, "alpha": 0.1, "learning_rate": 0.003, "batch_size": 24, "train_epochs": 10, "patience": 3, "use_norm": 1, "lradj": "TST", "freq": "h", "itr": 1, "l1_weight": 0.0},
    # {"name": "Solar", "data": "Solar", "root": "./dataset/SimpleTM_datasets/Solar", "path": "solar_AL.txt", "enc_in": 137, "d_model": 128, "d_ff": 256, "e_layers": 1, "wv": "db8", "m": 3, "alpha": 0.0, "learning_rate": 0.01, "batch_size": 256, "train_epochs": 10, "patience": 3, "use_norm": 0, "lradj": "TST", "freq": "h", "itr": 3, "l1_weight": 0.005},
    # {"name": "smartbuilding", "data": "custom", "root": "./dataset/SimpleTM_datasets/smartbuilding", "path": "smart.csv", "enc_in": 37, "d_model": 64, "d_ff": 128, "e_layers": 1, "wv": "db4", "m": 3, "alpha": 0.3, "learning_rate": 0.003, "batch_size": 64, "train_epochs": 20, "patience": 5, "use_norm": 1, "lradj": "TST", "freq": "h", "itr": 3, "l1_weight": 5e-05, "target": "Floor_Total(kW)"},
]

hybrid_configs = [
    {"tag": "Baseline", "gate_mode": "soft", "branch_dropout": 0.0, "gate_temperature": 0.5, "residual_branch": "none"},
    {"tag": "BranchDropout", "gate_mode": "soft", "branch_dropout": 0.15, "gate_temperature": 0.5, "residual_branch": "none"},
    {"tag": "SparseGate", "gate_mode": "sparse", "branch_dropout": 0.0, "gate_temperature": 0.3, "residual_branch": "none"},
    {"tag": "OneHotGate", "gate_mode": "one_hot", "branch_dropout": 0.0, "gate_temperature": 0.3, "residual_branch": "none"},
    {"tag": "ResidualFallback", "gate_mode": "soft", "branch_dropout": 0.0, "gate_temperature": 0.5, "residual_branch": DEFAULT_RESIDUAL_BRANCH},
    {"tag": "CombinedSparse", "gate_mode": "sparse", "branch_dropout": 0.15, "gate_temperature": 0.3, "residual_branch": DEFAULT_RESIDUAL_BRANCH},
]

if SELECTED_DATASETS is None:
    datasets = list(all_datasets)
else:
    datasets = [ds for ds in all_datasets if ds["name"] in SELECTED_DATASETS]

if SELECTED_ATTENTION_MODES is None:
    attention_modes = ["original", "dual"]
else:
    attention_modes = list(SELECTED_ATTENTION_MODES)

if SELECTED_HYBRID_CONFIGS is None:
    configs = list(hybrid_configs)
else:
    configs = [cfg for cfg in hybrid_configs if cfg["tag"] in SELECTED_HYBRID_CONFIGS]

OUTPUT_DIR = "/kaggle/working/SimpleTM_HybridFeatureAblation_Results"
if os.path.exists(OUTPUT_DIR):
    shutil.rmtree(OUTPUT_DIR)
os.makedirs(OUTPUT_DIR, exist_ok=True)

LOG_DIR = os.path.join(OUTPUT_DIR, "logs")
os.makedirs(LOG_DIR, exist_ok=True)

for path in ["./checkpoints", "result_long_term_forecast.txt"]:
    if os.path.isdir(path):
        shutil.rmtree(path)
    elif os.path.exists(path):
        os.remove(path)

print("Datasets selected:")
for ds in datasets:
    print(f"- {ds['name']}: epochs={ds['train_epochs']}, itr={ds['itr']}, d_model={ds['d_model']}, batch={ds['batch_size']}, alpha={ds['alpha']}")
print("\nAttention modes selected:")
for mode in attention_modes:
    print(f"- {mode}")
print("\nHybrid configs selected:")
for cfg in configs:
    print(f"- {cfg['tag']}: gate={cfg['gate_mode']}, dropout={cfg['branch_dropout']}, temp={cfg['gate_temperature']}, residual={cfg['residual_branch']}")
# Out:
# Datasets selected:
# - ETTh1: epochs=10, itr=3, d_model=32, batch=256, alpha=0.3
#
# Attention modes selected:
# - original
# - dual
#
# Hybrid configs selected:
# - Baseline: gate=soft, dropout=0.0, temp=0.5, residual=none
# - BranchDropout: gate=soft, dropout=0.15, temp=0.5, residual=none
# - SparseGate: gate=sparse, dropout=0.0, temp=0.3, residual=none
# - OneHotGate: gate=one_hot, dropout=0.0, temp=0.3, residual=none
# - ResidualFallback: gate=soft, dropout=0.0, temp=0.5, residual=swt
# - CombinedSparse: gate=sparse, dropout=0.15, temp=0.3, residual=swt

# %%
for ds in datasets:
    print("\n" + "=" * 100)
    print(f"DATASET: {ds['name']} | variates={ds['enc_in']} | Hybrid feature ablation")
    print("=" * 100 + "\n")

    for attention_mode in attention_modes:
        for cfg in configs:
            run_tag = f"{attention_mode}_{cfg['tag']}"
            print(f">>> Training Hybrid {run_tag} on {ds['name']} <<<\n")
            unique_model_id = f"{ds['name']}_SimpleTM_Hybrid_{attention_mode}_{cfg['tag']}"

            cmd = [
                "python", "-u", "run.py",
                "--is_training", "1",
                "--model", "SimpleTM_Hybrid",
                "--attention_mode", attention_mode,
                "--model_id", unique_model_id,
                "--data", ds["data"],
                "--root_path", ds["root"],
                "--data_path", ds["path"],
                "--features", "M",
                "--freq", ds["freq"],
                "--seq_len", "96",
                "--pred_len", "96",
                "--e_layers", str(ds["e_layers"]),
                "--d_model", str(ds["d_model"]),
                "--d_ff", str(ds["d_ff"]),
                "--enc_in", str(ds["enc_in"]),
                "--dec_in", str(ds["enc_in"]),
                "--c_out", str(ds["enc_in"]),
                "--wv", ds["wv"],
                "--m", str(ds["m"]),
                "--alpha", str(ds["alpha"]),
                "--l1_weight", str(ds["l1_weight"]),
                "--learning_rate", str(ds["learning_rate"]),
                "--batch_size", str(ds["batch_size"]),
                "--train_epochs", str(ds["train_epochs"]),
                "--patience", str(ds["patience"]),
                "--itr", str(ds["itr"]),
                "--num_workers", "2",
                "--lradj", ds["lradj"],
                "--use_norm", str(ds["use_norm"]),
                "--hybrid_gate_mode", cfg["gate_mode"],
                "--hybrid_branch_dropout", str(cfg["branch_dropout"]),
                "--hybrid_gate_temperature", str(cfg["gate_temperature"]),
                "--hybrid_residual_branch", cfg["residual_branch"],
                "--checkpoints", f"{OUTPUT_DIR}/checkpoints/",
                "--fix_seed", "2025",
                "--des", "HybridFeatureAblation",
            ]

            if "conv_kernel_sizes" in ds:
                cmd.extend(["--conv_kernel_sizes", ds["conv_kernel_sizes"]])
            if "target" in ds:
                cmd.extend(["--target", ds["target"]])

            log_file = os.path.join(LOG_DIR, f"{ds['name']}_{run_tag}.log")
            log_lines = []
            process = subprocess.Popen(cmd, stdout=subprocess.PIPE, stderr=subprocess.STDOUT, text=True)
            for line in process.stdout:
                print(line, end="")
                log_lines.append(line)
            process.wait()
            with open(log_file, "w", encoding="utf-8") as f:
                f.writelines(log_lines)
            print(f"Saved run log to: {log_file}")

            if process.returncode == 0:
                print(f"\nSUCCESS: Finished Hybrid {run_tag} on {ds['name']}\n")
            else:
                raise RuntimeError(f"Run failed for {ds['name']} | Hybrid {run_tag} with exit code {process.returncode}")

print("\nGathering generated plots and metric text...")
if os.path.exists("./checkpoints"):
    for root_dir, dirs, files in os.walk("./checkpoints"):
        for file in files:
            if file.endswith(".pdf") or file.endswith(".png"):
                folder_name = os.path.basename(root_dir)
                source_path = os.path.join(root_dir, file)
                target_plot_dir = os.path.join(OUTPUT_DIR, "plots", folder_name)
                os.makedirs(target_plot_dir, exist_ok=True)
                shutil.copy(source_path, os.path.join(target_plot_dir, file))

if os.path.exists("result_long_term_forecast.txt"):
    shutil.copy("result_long_term_forecast.txt", os.path.join(OUTPUT_DIR, "result_long_term_forecast.txt"))
    print("Copied metric text results to output directory.")
# Out:
# ====================================================================================================
# DATASET: ETTh1 | variates=7 | Hybrid feature ablation
# ====================================================================================================
#
# >>> Training Hybrid original_Baseline on ETTh1 <<<
#
# Args in experiment:
# Namespace(is_training=1, model_id='ETTh1_SimpleTM_Hybrid_original_Baseline', model='SimpleTM_Hybrid', data='ETTh1', root_path='./dataset/SimpleTM_datasets/ETT-small', data_path='ETTh1.csv', features='M', target='OT', freq='h', checkpoints='/kaggle/working/SimpleTM_HybridFeatureAblation_Results/checkpoints/', seq_len=96, label_len=0, pred_len=96, enc_in=7, dec_in=7, c_out=7, n_heads=8, d_layers=1, moving_avg=25, factor=1, distil=True, dropout=0.1, geomattn_dropout=0.5, embed='timeF', activation='gelu', do_predict=False, num_workers=2, itr=3, train_epochs=10, batch_size=256, patience=3, learning_rate=0.02, des='HybridFeatureAblation', loss='MSE', lradj='TST', pct_start=0.2, use_amp=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', exp_name='MTSF', channel_independence=False, inverse=False, class_strategy='projection', target_root_path='./data/electricity/', target_data_path='electricity.csv', efficient_training=False, use_norm=1, partial_start_index=0, requires_grad=True, wv='db1', m=3, kernel_size=None, conv_kernel_sizes=None, hybrid_gate_mode='soft', hybrid_branch_dropout=0.0, hybrid_gate_temperature=0.5, hybrid_residual_branch='none', alpha=0.3, learnable_alpha=False, l1_weight=0.0005, d_model=32, d_ff=32, e_layers=1, compile=False, output_attention=False, attention_mode='original', fix_seed=2025)
# Use GPU: cuda:0
# Total trainable parameters: 20345
# Memory usage for trainable parameters: 0.08 MB
# Static memory footprint (allocated): 0.09 MB
# Static memory footprint (reserved): 2.00 MB
# >>>>>>>start training : ETTh1_SimpleTM_Hybrid_original_Baseline_SimpleTM_Hybrid_original_ETTh1_96_96_32_32_1_db1_None_None_soft_0.0_0.5_none_3_0.3_False_0.0005_0.02_TST_256_2025_1_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8449
# val 2785
# test 2785
# 	iters: 30, epoch: 1 | loss: 0.4328235
# 	speed: 0.2102s/iter; left time: 63.2834s
# Epoch: 1 cost time: 6.7915661334991455
# Epoch: 1, Steps: 33 | Train Loss: 0.5086328 Vali Loss: 0.7585818 Test Loss: 0.4283887
# Validation loss decreased (inf --> 0.758582).  Saving model ...
# Updating learning rate to 0.010631971954266867
# 	iters: 30, epoch: 2 | loss: 0.4134178
# 	speed: 0.1728s/iter; left time: 46.3193s
# Epoch: 2 cost time: 4.6871607303619385
# Epoch: 2, Steps: 33 | Train Loss: 0.3798419 Vali Loss: 0.7135498 Test Loss: 0.3865715
# Validation loss decreased (0.758582 --> 0.713550).  Saving model ...
# Updating learning rate to 0.019999291964499063
# 	iters: 30, epoch: 3 | loss: 0.3600992
# 	speed: 0.1716s/iter; left time: 40.3345s
# Epoch: 3 cost time: 4.68060827255249
# Epoch: 3, Steps: 33 | Train Loss: 0.3635684 Vali Loss: 0.6996156 Test Loss: 0.3766808
# Validation loss decreased (0.713550 --> 0.699616).  Saving model ...
# Updating learning rate to 0.019192606265404512
# 	iters: 30, epoch: 4 | loss: 0.
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 0.006063553564389314
# 	iters: 30, epoch: 8 | loss: 0.3130095
# 	speed: 0.2241s/iter; left time: 15.6839s
# Epoch: 8 cost time: 5.482092618942261
# Epoch: 8, Steps: 33 | Train Loss: 0.3439176 Vali Loss: 0.6916100 Test Loss: 0.3725951
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 0.002845357941442444
# 	iters: 30, epoch: 9 | loss: 0.3190371
# 	speed: 0.1829s/iter; left time: 6.7682s
# ...
# Collected 16 examples for combined_prediction_examples.png
# mse:0.3702624440193176, mae:0.39562156796455383
# rmse:0.6084919571876526, mape:0.663671612739563, mspe:48212.26171875
# rse:0.5794411301612854, corr:24.242904663085938, smape:0.7241770625114441, wape:0.4944777190685272, r2:0.664247989654541
# Use GPU: cuda:0
# Total trainable parameters: 22683.0
# Memory usage for trainable parameters: 0.09 MB
# Static memory footprint (allocated): 17.55 MB
# Static memory footprint (reserved): 54.00 MB
# >>>>>>>start training : ETTh1_SimpleTM_Hybrid_dual_ResidualFallback_SimpleTM_Hybrid_dual_ETTh1_96_96_32_32_1_db1_None_None_soft_0.0_0.5_swt_3_0.3_False_0.0005_0.02_TST_256_2025_1_2>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8449
# val 2785
# test 2785
# 	iters: 30, epoch: 1 | loss: 0.4042002
# 	speed: 0.1665s/iter; left time: 50.1051s
# Epoch: 1 cost time: 5.587270021438599
# Epoch: 1, Steps: 33 | Train Loss: 0.5123634 Vali Loss: 0.7572429 Test Loss: 0.4274227
# Validation loss decreased (inf --> 0.757243).  Saving model ...
# Updating learning rate to 0.010631971954266867
# 	iters: 30, epoch: 2 | loss: 0.3406605
# 	speed: 0.2051s/iter; left time: 54.9665s
# Epoch: 2 cost time: 5.563549280166626
# Epoch: 2, Steps: 33 | Train Loss: 0.3818165 Vali Loss: 0.7001786 Test Loss: 0.3828286
# Validation loss decreased (0.757243 --> 0.700179).  Saving model ...
# Updating learning rate to 0.019999291964499063
# 	iters: 30, epoch: 3 | loss: 0.3661871
# 	speed: 0.2060s/iter; left time: 48.4068s
# Epoch: 3 cost time: 5.629706621170044
# Epoch: 3, Steps: 33 | Train Loss: 0.3627599 Vali Loss: 0.6900510 Test Loss: 0.3755072
# Validation loss decreased (0.700179 --> 0.690051).  Saving model ...
# Updating learning rate to 0.019192606265404512
# 	iters: 30, epoch: 4 | loss: 0.3838654
# 	speed: 0.2055s/iter; left time: 41.5030s
# Epoch: 4 cost time: 5.574330806732178
# Epoch: 4, Steps: 33 | Train Loss: 0.3555554 Vali Loss: 0.6811619 Test Loss: 0.3736977
# Validation loss decreased (0.690051 --> 0.681162).  Saving model ...
# Updating learning rate to 0.01698643568322283
# 	iters: 30, epoch: 5 | loss: 0.3457196
# 	speed: 0.2052s/iter; left time: 34.6741s
# Epoch: 5 cost time: 5.562572717666626
# Epoch: 5, Steps: 33 | Train Loss: 0.3518679 Vali Loss: 0.6748875 Test Loss: 0.3726768
# Validation loss decreased (0.681162 --> 0.674887).  Saving model ...
# Updating learning rate to 0.013716649690105047
# 	iters: 30, epoch: 6 | loss: 0.3628717
# 	speed: 0.2060s/iter; left time: 28.0175s
# Epoch: 6 cost time: 5.598403692245483
# Epoch: 6, Steps: 33 | Train Loss: 0.3468611 Vali Loss: 0.6840966 Test Loss: 0.3719107
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 0.00988104356281951
# 	iters: 30, epoch: 7 | loss: 0.3650844
# 	speed: 0.2045s/iter; left time: 21.0646s
# Epoch: 7 cost time: 5.567730665206909
# Epoch: 7, Steps: 33 | Train Loss: 0.3424072 Vali Loss: 0.6779965 Test Loss: 0.3695389
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 0.006063553564389314
# 	iters: 30, epoch: 8 | loss: 0.3044759
# 	speed: 0.2076s/iter; left time: 14.5291s
# Epoch: 8 cost time: 5.607644319534302
# Epoch: 8, Steps: 33 | Train Loss: 0.3403687 Vali Loss: 0.6869171 Test Loss: 0.3692889
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : ETTh1_SimpleTM_Hybrid_dual_ResidualFallback_SimpleTM_Hybrid_dual_ETTh1_96_96_32_32_1_db1_None_None_soft_0.0_0.5_swt_3_0.3_False_0.0005_0.02_TST_256_2025_1_2<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2785
# test shape: (10, 256, 96, 7) (10, 256, 96, 7)
# test shape: (2560, 96, 7) (2560, 96, 7)
# Collected 16 examples for combined_prediction_examples.png
# mse:0.3726768493652344, mae:0.3990918695926666
# rmse:0.6104726195335388, mape:0.6706101298332214, mspe:53020.9765625
# rse:0.5813273191452026, corr:24.04693031311035, smape:0.7243343591690063, wape:0.4988152086734772, r2:0.6620585918426514
# Saved run log to: /kaggle/working/SimpleTM_HybridFeatureAblation_Results/logs/ETTh1_dual_ResidualFallback.log
#
# SUCCESS: Finished Hybrid dual_ResidualFallback on ETTh1
#
# >>> Training Hybrid dual_CombinedSparse on ETTh1 <<<
#
# Args in experiment:
# Namespace(is_training=1, model_id='ETTh1_SimpleTM_Hybrid_dual_CombinedSparse', model='SimpleTM_Hybrid', data='ETTh1', root_path='./dataset/SimpleTM_datasets/ETT-small', data_path='ETTh1.csv', features='M', target='OT', freq='h', checkpoints='/kaggle/working/SimpleTM_HybridFeatureAblation_Results/checkpoints/', seq_len=96, label_len=0, pred_len=96, enc_in=7, dec_in=7, c_out=7, n_heads=8, d_layers=1, moving_avg=25, factor=1, distil=True, dropout=0.1, geomattn_dropout=0.5, embed='timeF', activation='gelu', do_predict=False, num_workers=2, itr=3, train_epochs=10, batch_size=256, patience=3, learning_rate=0.02, des='HybridFeatureAblation', loss='MSE', lradj='TST', pct_start=0.2, use_amp=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', exp_name='MTSF', channel_independence=False, inverse=False, class_strategy='projection', target_root_path='./data/electricity/', target_data_path='electricity.csv', efficient_training=False, use_norm=1, partial_start_index=0, requires_grad=True, wv='db1', m=3, kernel_size=None, conv_kernel_sizes=None, hybrid_gate_mode='sparse', hybrid_branch_dropout=0.15, hybrid_gate_temperature=0.3, hybrid_residual_branch='swt', alpha=0.3, learnable_alpha=False, l1_weight=0.0005, d_model=32, d_ff=32, e_layers=1, compile=False, output_attention=False, attention_mode='dual', fix_seed=2025)
# Use GPU: cuda:0
# Total trainable parameters: 22683.0
# Memory usage for trainable parameters: 0.09 MB
# Static memory footprint (allocated): 0.10 MB
# Static memory footprint (reserved): 2.00 MB
# >>>>>>>start training : ETTh1_SimpleTM_Hybrid_dual_CombinedSparse_SimpleTM_Hybrid_dual_ETTh1_96_96_32_32_1_db1_None_None_sparse_0.15_0.3_swt_3_0.3_False_0.0005_0.02_TST_256_2025_1_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8449
# val 2785
# test 2785
# 	iters: 30, epoch: 1 | loss: 0.4178386
# 	speed: 0.2029s/iter; left time: 61.0722s
# Epoch: 1 cost time: 6.700499057769775
# Epoch: 1, Steps: 33 | Train Loss: 0.5183977 Vali Loss: 0.7694753 Test Loss: 0.4350569
# Validation loss decreased (inf --> 0.769475).  Saving model ...
# Updating learning rate to 0.010631971954266867
# 	iters: 30, epoch: 2 | loss: 0.3747409
# 	speed: 0.2093s/iter; left time: 56.0850s
# Epoch: 2 cost time: 5.7483179569244385
# Epoch: 2, Steps: 33 | Train Loss: 0.3834708 Vali Loss: 0.7091201 Test Loss: 0.3854853
# Validation loss decreased (0.769475 --> 0.709120).  Saving model ...
# Updating learning rate to 0.019999291964499063
# 	iters: 30, epoch: 3 | loss: 0.3742235
# 	speed: 0.2113s/iter; left time: 49.6575s
# Epoch: 3 cost time: 5.796544551849365
# Epoch: 3, Steps: 33 | Train Loss: 0.3638205 Vali Loss: 0.6942548 Test Loss: 0.3767290
# Validation loss decreased (0.709120 --> 0.694255).  Saving model ...
# Updating learning rate to 0.019192606265404512
# 	iters: 30, epoch: 4 | loss: 0.3511944
# 	speed: 0.2128s/iter; left time: 42.9916s
# Epoch: 4 cost time: 5.847691059112549
# Epoch: 4, Steps: 33 | Train Loss: 0.3575809 Vali Loss: 0.6746039 Test Loss: 0.3726712
# Validation loss decreased (0.694255 --> 0.674604).  Saving model ...
# Updating learning rate to 0.01698643568322283
# 	iters: 30, epoch: 5 | loss: 0.3575434
# 	speed: 0.2095s/iter; left time: 35.4021s
# Epoch: 5 cost time: 5.7718260288238525
# Epoch: 5, Steps: 33 | Train Loss: 0.3533201 Vali Loss: 0.6816806 Test Loss: 0.3755881
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 0.013716649690105047
# 	iters: 30, epoch: 6 | loss: 0.3456477
# 	speed: 0.2084s/iter; left time: 28.3362s
# Epoch: 6 cost time: 5.743211269378662
# Epoch: 6, Steps: 33 | Train Loss: 0.3496687 Vali Loss: 0.6821733 Test Loss: 0.3689134
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 0.00988104356281951
# 	iters: 30, epoch: 7 | loss: 0.3585663
# 	speed: 0.2084s/iter; left time: 21.4676s
# Epoch: 7 cost time: 5.770361661911011
# Epoch: 7, Steps: 33 | Train Loss: 0.3459366 Vali Loss: 0.6763951 Test Loss: 0.3681921
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : ETTh1_SimpleTM_Hybrid_dual_CombinedSparse_SimpleTM_Hybrid_dual_ETTh1_96_96_32_32_1_db1_None_None_sparse_0.15_0.3_swt_3_0.3_False_0.0005_0.02_TST_256_2025_1_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2785
# test shape: (10, 256, 96, 7) (10, 256, 96, 7)
# test shape: (2560, 96, 7) (2560, 96, 7)
# Collected 16 examples for combined_prediction_examples.png
# mse:0.3726710379123688, mae:0.39677244424819946
# rmse:0.6104679107666016, mape:0.665644109249115, mspe:47914.453125
# rse:0.5813227891921997, corr:24.25124168395996, smape:0.7266486883163452, wape:0.4959161877632141, r2:0.6620638370513916
# Use GPU: cuda:0
# Total trainable parameters: 22683.0
# Memory usage for trainable parameters: 0.09 MB
# Static memory footprint (allocated): 17.55 MB
# Static memory footprint (reserved): 54.00 MB
# >>>>>>>start training : ETTh1_SimpleTM_Hybrid_dual_CombinedSparse_SimpleTM_Hybrid_dual_ETTh1_96_96_32_32_1_db1_None_None_sparse_0.15_0.3_swt_3_0.3_False_0.0005_0.02_TST_256_2025_1_1>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8449
# val 2785
# test 2785
# 	iters: 30, epoch: 1 | loss: 0.4272689
# 	speed: 0.1775s/iter; left time: 53.4306s
# Epoch: 1 cost time: 5.924081563949585
# Epoch: 1, Steps: 33 | Train Loss: 0.5098822 Vali Loss: 0.7453669 Test Loss: 0.4243852
# Validation loss decreased (inf --> 0.745367).  Saving model ...
# Updating learning rate to 0.010631971954266867
# 	iters: 30, epoch: 2 | loss: 0.3644822
# 	speed: 0.2121s/iter; left time: 56.8366s
# Epoch: 2 cost time: 5.773202419281006
# Epoch: 2, Steps: 33 | Train Loss: 0.3816352 Vali Loss: 0.7043585 Test Loss: 0.3838738
# Validation loss decreased (0.745367 --> 0.704358).  Saving model ...
# Updating learning rate to 0.019999291964499063
# 	iters: 30, epoch: 3 | loss: 0.3424616
# 	speed: 0.2124s/iter; left time: 49.9138s
# Epoch: 3 cost time: 5.807651042938232
# Epoch: 3, Steps: 33 | Train Loss: 0.3634193 Vali Loss: 0.6935852 Test Loss: 0.3765642
# Validation loss decreased (0.704358 --> 0.693585).  Saving model ...
# Updating learning rate to 0.019192606265404512
# 	iters: 30, epoch: 4 | loss: 0.4032461
# 	speed: 0.2134s/iter; left time: 43.1089s
# Epoch: 4 cost time: 5.8538689613342285
# Epoch: 4, Steps: 33 | Train Loss: 0.3569081 Vali Loss: 0.7089907 Test Loss: 0.3749389
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 0.01698643568322283
# 	iters: 30, epoch: 5 | loss: 0.3543624
# 	speed: 0.2089s/iter; left time: 35.3124s
# Epoch: 5 cost time: 5.727551698684692
# Epoch: 5, Steps: 33 | Train Loss: 0.3517066 Vali Loss: 0.6924313 Test Loss: 0.3714641
# Validation loss decreased (0.693585 --> 0.692431).  Saving model ...
# Updating learning rate to 0.013716649690105047
# 	iters: 30, epoch: 6 | loss: 0.3437852
# 	speed: 0.2153s/iter; left time: 29.2844s
# Epoch: 6 cost time: 5.857870101928711
# Epoch: 6, Steps: 33 | Train Loss: 0.3470081 Vali Loss: 0.6883460 Test Loss: 0.3703454
# Validation loss decreased (0.692431 --> 0.688346).  Saving model ...
# Updating learning rate to 0.00988104356281951
# 	iters: 30, epoch: 7 | loss: 0.3534371
# 	speed: 0.2110s/iter; left time: 21.7319s
# Epoch: 7 cost time: 5.81568169593811
# Epoch: 7, Steps: 33 | Train Loss: 0.3450059 Vali Loss: 0.6795069 Test Loss: 0.3672612
# Validation loss decreased (0.688346 --> 0.679507).  Saving model ...
# Updating learning rate to 0.006063553564389314
# 	iters: 30, epoch: 8 | loss: 0.3243535
# 	speed: 0.2247s/iter; left time: 15.7296s
# Epoch: 8 cost time: 6.164573431015015
# Epoch: 8, Steps: 33 | Train Loss: 0.3416363 Vali Loss: 0.6660223 Test Loss: 0.3685977
# Validation loss decreased (0.679507 --> 0.666022).  Saving model ...
# Updating learning rate to 0.002845357941442444
# 	iters: 30, epoch: 9 | loss: 0.3275290
# 	speed: 0.2139s/iter; left time: 7.9146s
# Epoch: 9 cost time: 5.772385597229004
# Epoch: 9, Steps: 33 | Train Loss: 0.3400648 Vali Loss: 0.6716262 Test Loss: 0.3673960
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 0.000716397804556595
# 	iters: 30, epoch: 10 | loss: 0.3497708
# 	speed: 0.2107s/iter; left time: 0.8429s
# Epoch: 10 cost time: 5.805695056915283
# Epoch: 10, Steps: 33 | Train Loss: 0.3390886 Vali Loss: 0.6726993 Test Loss: 0.3673274
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 7.880355009381883e-07
# >>>>>>>testing : ETTh1_SimpleTM_Hybrid_dual_CombinedSparse_SimpleTM_Hybrid_dual_ETTh1_96_96_32_32_1_db1_None_None_sparse_0.15_0.3_swt_3_0.3_False_0.0005_0.02_TST_256_2025_1_1<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2785
# test shape: (10, 256, 96, 7) (10, 256, 96, 7)
# test shape: (2560, 96, 7) (2560, 96, 7)
# Collected 16 examples for combined_prediction_examples.png
# mse:0.3685978055000305, mae:0.39434385299682617
# rmse:0.607122540473938, mape:0.6597256660461426, mspe:47694.8125
# rse:0.5781371593475342, corr:24.204666137695312, smape:0.7236328125, wape:0.49288076162338257, r2:0.665757417678833
# Use GPU: cuda:0
# Total trainable parameters: 22683.0
# Memory usage for trainable parameters: 0.09 MB
# Static memory footprint (allocated): 17.55 MB
# Static memory footprint (reserved): 56.00 MB
# >>>>>>>start training : ETTh1_SimpleTM_Hybrid_dual_CombinedSparse_SimpleTM_Hybrid_dual_ETTh1_96_96_32_32_1_db1_None_None_sparse_0.15_0.3_swt_3_0.3_False_0.0005_0.02_TST_256_2025_1_2>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8449
# val 2785
# test 2785
# 	iters: 30, epoch: 1 | loss: 0.4043875
# 	speed: 0.1808s/iter; left time: 54.4159s
# Epoch: 1 cost time: 6.06831431388855
# Epoch: 1, Steps: 33 | Train Loss: 0.5125134 Vali Loss: 0.7572072 Test Loss: 0.4273189
# Validation loss decreased (inf --> 0.757207).  Saving model ...
# Updating learning rate to 0.010631971954266867
# 	iters: 30, epoch: 2 | loss: 0.3441935
# 	speed: 0.2249s/iter; left time: 60.2620s
# Epoch: 2 cost time: 6.115793466567993
# Epoch: 2, Steps: 33 | Train Loss: 0.3824925 Vali Loss: 0.6945649 Test Loss: 0.3822343
# Validation loss decreased (0.757207 --> 0.694565).  Saving model ...
# Updating learning rate to 0.019999291964499063
# 	iters: 30, epoch: 3 | loss: 0.3648474
# 	speed: 0.2221s/iter; left time: 52.1993s
# Epoch: 3 cost time: 6.028214931488037
# Epoch: 3, Steps: 33 | Train Loss: 0.3633552 Vali Loss: 0.6878253 Test Loss: 0.3742890
# Validation loss decreased (0.694565 --> 0.687825).  Saving model ...
# Updating learning rate to 0.019192606265404512
# 	iters: 30, epoch: 4 | loss: 0.3815681
# 	speed: 0.2224s/iter; left time: 44.9339s
# Epoch: 4 cost time: 6.078722715377808
# Epoch: 4, Steps: 33 | Train Loss: 0.3551064 Vali Loss: 0.6781815 Test Loss: 0.3745803
# Validation loss decreased (0.687825 --> 0.678182).  Saving model ...
# Updating learning rate to 0.01698643568322283
# 	iters: 30, epoch: 5 | loss: 0.3483514
# 	speed: 0.2206s/iter; left time: 37.2740s
# Epoch: 5 cost time: 6.038445949554443
# Epoch: 5, Steps: 33 | Train Loss: 0.3519621 Vali Loss: 0.6830815 Test Loss: 0.3712736
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 0.013716649690105047
# 	iters: 30, epoch: 6 | loss: 0.3624611
# 	speed: 0.2206s/iter; left time: 30.0081s
# Epoch: 6 cost time: 5.940227270126343
# Epoch: 6, Steps: 33 | Train Loss: 0.3475011 Vali Loss: 0.6944664 Test Loss: 0.3715412
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 0.00988104356281951
# 	iters: 30, epoch: 7 | loss: 0.3694838
# 	speed: 0.2236s/iter; left time: 23.0314s
# Epoch: 7 cost time: 6.16467022895813
# Epoch: 7, Steps: 33 | Train Loss: 0.3439997 Vali Loss: 0.6782455 Test Loss: 0.3699207
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : ETTh1_SimpleTM_Hybrid_dual_CombinedSparse_SimpleTM_Hybrid_dual_ETTh1_96_96_32_32_1_db1_None_None_sparse_0.15_0.3_swt_3_0.3_False_0.0005_0.02_TST_256_2025_1_2<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2785
# test shape: (10, 256, 96, 7) (10, 256, 96, 7)
# test shape: (2560, 96, 7) (2560, 96, 7)
# Collected 16 examples for combined_prediction_examples.png
# mse:0.37458035349845886, mae:0.400255411863327
# rmse:0.6120296716690063, mape:0.6735053658485413, mspe:49433.25390625
# rse:0.5828099846839905, corr:24.22758674621582, smape:0.7272584438323975, wape:0.5002694725990295, r2:0.6603325605392456
# Saved run log to: /kaggle/working/SimpleTM_HybridFeatureAblation_Results/logs/ETTh1_dual_CombinedSparse.log
#
# SUCCESS: Finished Hybrid dual_CombinedSparse on ETTh1
#
#
# Gathering generated plots and metric text...
# Copied metric text results to output directory.

# %%
results_file = os.path.join(OUTPUT_DIR, "result_long_term_forecast.txt")
metric_order = ["MSE", "MAE", "RMSE", "MAPE", "WAPE", "R2"]
setting_pattern = re.compile(r"^(?P<dataset>[^_]+)_SimpleTM_Hybrid_(?P<attention>original|dual)_(?P<config>[^_]+)_SimpleTM_Hybrid_")
metric_pattern = re.compile(r"([a-zA-Z0-9_]+):([^,]+)")

if not os.path.exists(results_file):
    raise FileNotFoundError(results_file)

with open(results_file, "r", encoding="utf-8") as f:
    content = f.read().strip()

rows = []
for entry in content.split("\n\n") if content else []:
    lines = [line.strip() for line in entry.splitlines() if line.strip()]
    if len(lines) < 2:
        continue
    setting = lines[0]
    metrics_line = lines[-1]
    match = setting_pattern.search(setting)
    if not match:
        continue

    row = {
        "Dataset": match.group("dataset"),
        "Model": "SimpleTM_Hybrid",
        "AttentionMode": match.group("attention"),
        "HybridConfig": match.group("config"),
        "Variant": f"Hybrid_{match.group('attention')}_{match.group('config')}",
        "Setting": setting,
    }
    for metric_name, value in metric_pattern.findall(metrics_line):
        try:
            row[metric_name.upper()] = float(value.strip())
        except ValueError:
            pass
    rows.append(row)

if not rows:
    raise RuntimeError("No valid metrics found in result file.")

raw_df = pd.DataFrame(rows).sort_values(["Dataset", "AttentionMode", "HybridConfig", "Setting"]).reset_index(drop=True)
value_columns = [col for col in metric_order if col in raw_df.columns]

raw_path = os.path.join(OUTPUT_DIR, "raw_metrics.csv")
raw_df.to_csv(raw_path, index=False)

agg_df = raw_df.groupby(["Dataset", "AttentionMode", "HybridConfig", "Variant"], as_index=False)[value_columns].mean(numeric_only=True)
count_df = raw_df.groupby(["Dataset", "AttentionMode", "HybridConfig", "Variant"], as_index=False).size().rename(columns={"size": "NumRuns"})
agg_df = agg_df.merge(count_df, on=["Dataset", "AttentionMode", "HybridConfig", "Variant"], how="left")
averaged_path = os.path.join(OUTPUT_DIR, "averaged_metrics.csv")
agg_df.to_csv(averaged_path, index=False)

comparison = agg_df.pivot_table(index=["Dataset", "AttentionMode"], columns="HybridConfig", values=value_columns, aggfunc="mean")
comparison_path = os.path.join(OUTPUT_DIR, "hybrid_feature_comparison.csv")
comparison.to_csv(comparison_path)

print("Raw runs:")
display(raw_df)
print("Averaged Hybrid feature ablation results:")
display(agg_df.sort_values(["Dataset", "AttentionMode", "HybridConfig"]))
print(f"Saved raw results to: {raw_path}")
print(f"Saved averaged results to: {averaged_path}")
print(f"Saved comparison table to: {comparison_path}")
# Out:
# Raw runs:
#    Dataset            Model AttentionMode      HybridConfig  \
# 0    ETTh1  SimpleTM_Hybrid          dual          Baseline
# 1    ETTh1  SimpleTM_Hybrid          dual          Baseline
# 2    ETTh1  SimpleTM_Hybrid          dual          Baseline
# 3    ETTh1  SimpleTM_Hybrid          dual     BranchDropout
# 4    ETTh1  SimpleTM_Hybrid          dual     BranchDropout
# 5    ETTh1  SimpleTM_Hybrid          dual     BranchDropout
# 6    ETTh1  SimpleTM_Hybrid          dual    CombinedSparse
# 7    ETTh1  SimpleTM_Hybrid          dual    CombinedSparse
# 8    ETTh1  SimpleTM_Hybrid          dual    CombinedSparse
# 9    ETTh1  SimpleTM_Hybrid          dual        OneHotGate
# 10   ETTh1  SimpleTM_Hybrid          dual        OneHotGate
# 11   ETTh1  SimpleTM_Hybrid          dual        OneHotGate
# 12   ETTh1  SimpleTM_Hybrid          dual  ResidualFallback
# 13   ETTh1  SimpleTM_Hybrid          dual  ResidualFallback
# 14   ETTh1  SimpleTM_Hybrid          dual  ResidualFallback
# 15   ETTh1  SimpleTM_Hybrid          dual        SparseGate
# 16   ETTh1  SimpleTM_Hybrid          dual        SparseGate
# 17   ETTh1  SimpleTM_Hybrid          dual        SparseGate
# 18   ETTh1  SimpleTM_Hybrid      original          Baseline
# 19   ETTh1  SimpleTM_Hybrid      original          Baseline
# 20   ETTh1  SimpleTM_Hybrid      original          Baseline
# 21   ETTh1  SimpleTM_Hybrid      original     BranchDropout
# 22   ETTh1  SimpleTM_Hybrid      original     BranchDropout
# 23   ETTh1  SimpleTM_Hybrid      original     BranchDropout
# 24   ETTh1  SimpleTM_Hybrid      original    CombinedSparse
# 25   ETTh1  SimpleTM_Hybrid      original    CombinedSparse
# 26   ETTh1  SimpleTM_Hybrid      original    CombinedSparse
# 27   ETTh1  SimpleTM_Hybrid      original        OneHotGate
# 28   ETTh1  SimpleTM_Hybrid      original        OneHotGate
# 29   ETTh1  SimpleTM_Hybrid      original        OneHotGate
# 30   ETTh1  SimpleTM_Hybrid      original  ResidualFallback
# 31   ETTh1  SimpleTM_Hybrid      original  ResidualFallback
# 32   ETTh1  SimpleTM_Hybrid      original  ResidualFallback
# 33   ETTh1  SimpleTM_Hybrid      original        SparseGate
# 34   ETTh1  SimpleTM_Hybrid      original        SparseGate
# 35   ETTh1  SimpleTM_Hybrid      original        SparseGate
#
#                              Variant  \
# 0               Hybrid_dual_Baseline
# 1               Hybrid_dual_Baseline
# 2               Hybrid_dual_Baseline
# 3          Hybrid_dual_BranchDropout
# 4          Hybrid_dual_BranchDropout
# 5          Hybrid_dual_BranchDropout
# 6         Hybrid_dual_CombinedSparse
# 7         Hybrid_dual_CombinedSparse
# 8         Hybrid_dual_CombinedSparse
# 9             Hybrid_dual_OneHotGate
# 10            Hybrid_dual_OneHotGate
# 11            Hybrid_dual_OneHotGate
# 12      Hybrid_dual_ResidualFallback
# 13      Hybrid_dual_ResidualFallback
# 14      Hybrid_dual_ResidualFallback
# 15            Hybrid_dual_SparseGate
# 16            Hybrid_dual_SparseGate
# 17            Hybrid_dual_SparseGate
# 18          Hybrid_original_Baseline
# 19          Hybrid_original_Baseline
# 20          Hybrid_original_Baseline
# 21     Hybrid_original_BranchDropout
# 22     Hybrid_original_BranchDropout
# 23     Hybrid_original_BranchDropout
# 24    Hybrid_original_CombinedSparse
# 25    Hybrid_original_CombinedSparse
# 26    Hybrid_original_CombinedSparse
# 27        Hybrid_original_OneHotGate
# 28        Hybrid_original_OneHotGate
# 29        Hybrid_original_OneHotGate
# 30  Hybrid_original_ResidualFallback
# 31  Hybrid_original_ResidualFallback
# 32  Hybrid_original_ResidualFallback
# 33        Hybrid_original_SparseGate
# 34        Hybrid_original_SparseGate
# 35        Hybrid_original_SparseGate
#
#                                               Setting       MAE       MSE  \
# 0   ETTh1_SimpleTM_Hybrid_dual_Baseline_SimpleTM_H...  0.397750  0.371997
# 1   ETTh1_SimpleTM_Hybrid_dual_Baseline_SimpleTM_H...  0.397851  0.371623
# 2   ETTh1_SimpleTM_Hybrid_dual_Baseline_SimpleTM_H...  0.400587  0.374511
# 3   ETTh1_SimpleTM_Hybrid_dual_BranchDropout_Simpl...  0.396032  0.371902
# 4   ETTh1_SimpleTM_Hybrid_dual_BranchDropout_Simpl...  0.399611  0.375934
# 5   ETTh1_SimpleTM_Hybrid_dual_BranchDropout_Simpl...  0.398003  0.371719
# 6   ETTh1_SimpleTM_Hybrid_dual_CombinedSparse_Simp...  0.396772  0.372671
# 7   ETTh1_SimpleTM_Hybrid_dual_CombinedSparse_Simp...  0.394344  0.368598
# 8   ETTh1_SimpleTM_Hybrid_dual_CombinedSparse_Simp...  0.400255  0.374580
# 9   ETTh1_SimpleTM_Hybrid_dual_OneHotGate_SimpleTM...  0.397130  0.373112
# 10  ETTh1_SimpleTM_Hybrid_dual_OneHotGate_SimpleTM...  0.396895  0.369711
# 11  ETTh1_SimpleTM_Hybrid_dual_OneHotGate_SimpleTM...  0.398363  0.371764
# 12  ETTh1_SimpleTM_Hybrid_dual_ResidualFallback_Si...  0.395982  0.371513
# 13  ETTh1_SimpleTM_Hybrid_dual_ResidualFallback_Si...  0.395622  0.370262
# 14  ETTh1_SimpleTM_Hybrid_dual_ResidualFallback_Si...  0.399092  0.372677
# 15  ETTh1_SimpleTM_Hybrid_dual_SparseGate_SimpleTM...  0.397383  0.372450
# 16  ETTh1_SimpleTM_Hybrid_dual_SparseGate_SimpleTM...  0.396972  0.371325
# 17  ETTh1_SimpleTM_Hybrid_dual_SparseGate_SimpleTM...  0.398143  0.372677
# 18  ETTh1_SimpleTM_Hybrid_original_Baseline_Simple...  0.394203  0.369085
# 19  ETTh1_SimpleTM_Hybrid_original_Baseline_Simple...  0.396241  0.371329
# 20  ETTh1_SimpleTM_Hybrid_original_Baseline_Simple...  0.399213  0.372874
# 21  ETTh1_SimpleTM_Hybrid_original_BranchDropout_S...  0.392876  0.365568
# 22  ETTh1_SimpleTM_Hybrid_original_BranchDropout_S...  0.397124  0.374408
# 23  ETTh1_SimpleTM_Hybrid_original_BranchDropout_S...  0.394294  0.368483
# 24  ETTh1_SimpleTM_Hybrid_original_CombinedSparse_...  0.393067  0.366187
# 25  ETTh1_SimpleTM_Hybrid_original_CombinedSparse_...  0.393930  0.369524
# 26  ETTh1_SimpleTM_Hybrid_original_CombinedSparse_...  0.392148  0.367562
# 27  ETTh1_SimpleTM_Hybrid_original_OneHotGate_Simp...  0.394706  0.371135
# 28  ETTh1_SimpleTM_Hybrid_original_OneHotGate_Simp...  0.395224  0.372228
# 29  ETTh1_SimpleTM_Hybrid_original_OneHotGate_Simp...  0.397888  0.372288
# 30  ETTh1_SimpleTM_Hybrid_original_ResidualFallbac...  0.394446  0.368118
# 31  ETTh1_SimpleTM_Hybrid_original_ResidualFallbac...  0.394016  0.369447
# 32  ETTh1_SimpleTM_Hybrid_original_ResidualFallbac...  0.393566  0.368051
# 33  ETTh1_SimpleTM_Hybrid_original_SparseGate_Simp...  0.394560  0.368295
# 35  0.610809  0.664765  45049.324219  0.581648  24.194841  0.727027  0.496453
#
#           R2
# 0   0.662675
# 1   0.663014
# 2   0.660396
# 3   0.662761
# 4   0.659105
# 5   0.662927
# 6   0.662064
# 7   0.665757
# 8   0.660333
# 9   0.661664
# 10  0.664748
# 11  0.662886
# 12  0.663114
# 13  0.664248
# 14  0.662059
# 15  0.662264
# 16  0.663285
# 17  0.662059
# 18  0.665315
# 19  0.663281
# 20  0.661880
# 21  0.668505
# 22  0.660488
# 23  0.665862
# 24  0.667943
# 25  0.664917
# 26  0.666697
# 27  0.663456
# 28  0.662466
# 29  0.662411
# 30  0.666192
# 31  0.664987
# 32  0.666253
# 33  0.666032
# 34  0.665970
# 35  0.661686
# Averaged Hybrid feature ablation results:
#    Dataset AttentionMode      HybridConfig                           Variant  \
# 0    ETTh1          dual          Baseline              Hybrid_dual_Baseline
# 1    ETTh1          dual     BranchDropout         Hybrid_dual_BranchDropout
# 2    ETTh1          dual    CombinedSparse        Hybrid_dual_CombinedSparse
# 3    ETTh1          dual        OneHotGate            Hybrid_dual_OneHotGate
# 4    ETTh1          dual  ResidualFallback      Hybrid_dual_ResidualFallback
# 5    ETTh1          dual        SparseGate            Hybrid_dual_SparseGate
# 6    ETTh1      original          Baseline          Hybrid_original_Baseline
# 7    ETTh1      original     BranchDropout     Hybrid_original_BranchDropout
# 8    ETTh1      original    CombinedSparse    Hybrid_original_CombinedSparse
# 9    ETTh1      original        OneHotGate        Hybrid_original_OneHotGate
# 10   ETTh1      original  ResidualFallback  Hybrid_original_ResidualFallback
# 11   ETTh1      original        SparseGate        Hybrid_original_SparseGate
#
#          MSE       MAE      RMSE      MAPE      WAPE        R2  NumRuns
# 0   0.372710  0.398729  0.610499  0.670948  0.498362  0.662028        3
# 1   0.373185  0.397882  0.610887  0.667830  0.497303  0.661598        3
# 2   0.371950  0.397124  0.609873  0.666292  0.496355  0.662718        3
# 3   0.371529  0.397463  0.609531  0.667628  0.496779  0.663099        3
# 4   0.371484  0.396899  0.609494  0.666534  0.496074  0.663140        3
# 5   0.372150  0.397499  0.610041  0.667171  0.496824  0.662536        3
# 6   0.371096  0.396552  0.609175  0.666049  0.495641  0.663492        3
# 7   0.369486  0.394765  0.607846  0.663272  0.493407  0.664952        3
# 8   0.367758  0.393049  0.606429  0.660560  0.491262  0.666519        3
# 9   0.371884  0.395939  0.609823  0.664998  0.494875  0.662778        3
# 10  0.368539  0.394009  0.607074  0.660932  0.492463  0.665811        3
# 11  0.369915  0.395592  0.608204  0.663278  0.494440  0.664563        3
# Saved raw results to: /kaggle/working/SimpleTM_HybridFeatureAblation_Results/raw_metrics.csv
# Saved averaged results to: /kaggle/working/SimpleTM_HybridFeatureAblation_Results/averaged_metrics.csv
# Saved comparison table to: /kaggle/working/SimpleTM_HybridFeatureAblation_Results/hybrid_feature_comparison.csv

# %%
import matplotlib.pyplot as plt

MAX_LEARNING_CURVES_TO_SHOW = 12
LEARNING_CURVE_DIR = os.path.join(OUTPUT_DIR, "learning_curves")
os.makedirs(LEARNING_CURVE_DIR, exist_ok=True)

epoch_pattern = re.compile(
    r"Epoch:\s*(?P<epoch>\d+),\s*Steps:\s*\d+\s*\|\s*"
    r"Train Loss:\s*(?P<train>[0-9.eE+-]+)\s*"
    r"Vali Loss:\s*(?P<vali>[0-9.eE+-]+)\s*"
    r"Test Loss:\s*(?P<test>[0-9.eE+-]+)"
)

learning_rows = []
for log_path in sorted(glob.glob(os.path.join(OUTPUT_DIR, "logs", "*.log"))):
    stem = os.path.splitext(os.path.basename(log_path))[0]
    dataset_name, attention_mode, config_tag = stem.split("_", 2)
    repeat = 0
    previous_epoch = 0
    with open(log_path, "r", encoding="utf-8") as f:
        for line in f:
            match = epoch_pattern.search(line)
            if not match:
                continue
            epoch = int(match.group("epoch"))
            if previous_epoch and epoch <= previous_epoch:
                repeat += 1
            previous_epoch = epoch
            learning_rows.append({
                "Dataset": dataset_name,
                "AttentionMode": attention_mode,
                "HybridConfig": config_tag,
                "Repeat": repeat,
                "Epoch": epoch,
                "TrainLoss": float(match.group("train")),
                "ValiLoss": float(match.group("vali")),
                "TestLoss": float(match.group("test")),
                "LogFile": log_path,
            })

learning_df = pd.DataFrame(learning_rows)
if learning_df.empty:
    print("No epoch-wise learning curves found. Run the training cell first.")
else:
    learning_csv = os.path.join(OUTPUT_DIR, "learning_curves.csv")
    learning_df.to_csv(learning_csv, index=False)
    print(f"Saved learning-curve data to: {learning_csv}")
    display(learning_df.head(20))

    shown = 0
    for (dataset_name, attention_mode), curve_df in learning_df.groupby(["Dataset", "AttentionMode"]):
        fig, ax = plt.subplots(figsize=(12, 6))
        for config_tag, mode_df in curve_df.groupby("HybridConfig"):
            mode_df = mode_df.groupby("Epoch", as_index=False)[["TrainLoss", "ValiLoss", "TestLoss"]].mean().sort_values("Epoch")
            ax.plot(mode_df["Epoch"], mode_df["ValiLoss"], marker="o", linewidth=2.0, label=f"{config_tag} val")

        ax.set_title(f"{dataset_name} | Hybrid {attention_mode}: validation learning curves")
        ax.set_xlabel("Epoch")
        ax.set_ylabel("Validation Loss")
        ax.grid(alpha=0.3)
        ax.legend(fontsize=9)
        plt.tight_layout()
        curve_path = os.path.join(LEARNING_CURVE_DIR, f"{dataset_name}_{attention_mode}_validation_learning_curve.png")
        plt.savefig(curve_path, dpi=180, bbox_inches="tight")
        if shown < MAX_LEARNING_CURVES_TO_SHOW:
            plt.show()
            shown += 1
        else:
            plt.close(fig)

    print(f"Saved learning-curve plots to: {LEARNING_CURVE_DIR}")
# Out:
# Saved learning-curve data to: /kaggle/working/SimpleTM_HybridFeatureAblation_Results/learning_curves.csv
#    Dataset AttentionMode HybridConfig  Repeat  Epoch  TrainLoss  ValiLoss  \
# 0    ETTh1          dual     Baseline       0      1   0.518358  0.777785
# 1    ETTh1          dual     Baseline       0      2   0.379796  0.709587
# 2    ETTh1          dual     Baseline       0      3   0.361400  0.695442
# 3    ETTh1          dual     Baseline       0      4   0.354093  0.683917
# 4    ETTh1          dual     Baseline       0      5   0.349532  0.685407
# 5    ETTh1          dual     Baseline       0      6   0.345225  0.701808
# 6    ETTh1          dual     Baseline       0      7   0.340415  0.690703
# 7    ETTh1          dual     Baseline       1      1   0.509690  0.744276
# 8    ETTh1          dual     Baseline       1      2   0.379438  0.705328
# 9    ETTh1          dual     Baseline       1      3   0.360563  0.700732
# 10   ETTh1          dual     Baseline       1      4   0.353797  0.713564
# 11   ETTh1          dual     Baseline       1      5   0.347977  0.700464
# 12   ETTh1          dual     Baseline       1      6   0.344108  0.693523
# 13   ETTh1          dual     Baseline       1      7   0.340668  0.689689
# 14   ETTh1          dual     Baseline       1      8   0.336103  0.683538
# 15   ETTh1          dual     Baseline       1      9   0.332479  0.686504
# 16   ETTh1          dual     Baseline       1     10   0.331233  0.686106
# 17   ETTh1          dual     Baseline       2      1   0.512373  0.753923
# 18   ETTh1          dual     Baseline       2      2   0.380480  0.705462
# 19   ETTh1          dual     Baseline       2      3   0.361422  0.698798
#
#     TestLoss                                            LogFile
# 0   0.433957  /kaggle/working/SimpleTM_HybridFeatureAblation...
# 1   0.387794  /kaggle/working/SimpleTM_HybridFeatureAblation...
# 2   0.374705  /kaggle/working/SimpleTM_HybridFeatureAblation...
# 3   0.371997  /kaggle/working/SimpleTM_HybridFeatureAblation...
# 4   0.372946  /kaggle/working/SimpleTM_HybridFeatureAblation...
# 5   0.368790  /kaggle/working/SimpleTM_HybridFeatureAblation...
# 6   0.368370  /kaggle/working/SimpleTM_HybridFeatureAblation...
# 7   0.424333  /kaggle/working/SimpleTM_HybridFeatureAblation...
# 8   0.384576  /kaggle/working/SimpleTM_HybridFeatureAblation...
# 9   0.375231  /kaggle/working/SimpleTM_HybridFeatureAblation...
# 10  0.376411  /kaggle/working/SimpleTM_HybridFeatureAblation...
# 11  0.372250  /kaggle/working/SimpleTM_HybridFeatureAblation...
# 12  0.371395  /kaggle/working/SimpleTM_HybridFeatureAblation...
# 13  0.368753  /kaggle/working/SimpleTM_HybridFeatureAblation...
# 14  0.371623  /kaggle/working/SimpleTM_HybridFeatureAblation...
# 15  0.368988  /kaggle/working/SimpleTM_HybridFeatureAblation...
# 16  0.368960  /kaggle/working/SimpleTM_HybridFeatureAblation...
# 17  0.425234  /kaggle/working/SimpleTM_HybridFeatureAblation...
# 18  0.383951  /kaggle/working/SimpleTM_HybridFeatureAblation...
# 19  0.377489  /kaggle/working/SimpleTM_HybridFeatureAblation...
# Saved learning-curve plots to: /kaggle/working/SimpleTM_HybridFeatureAblation_Results/learning_curves

# %%
if "agg_df" in globals() and not agg_df.empty:
    metric = "MSE" if "MSE" in agg_df.columns else value_columns[0]
    for dataset_name, ds_df in agg_df.groupby("Dataset"):
        for attention_mode, mode_df in ds_df.groupby("AttentionMode"):
            plot_df = mode_df.set_index("HybridConfig")[[metric]].sort_values(metric)
            ax = plot_df.plot(kind="bar", figsize=(12, 5), legend=False, color="#4C78A8")
            ax.set_title(f"{dataset_name}: Hybrid {attention_mode} feature ablation ({metric}, lower is better)")
            ax.set_xlabel("Hybrid Config")
            ax.set_ylabel(metric)
            ax.grid(axis="y", alpha=0.3)
            plt.xticks(rotation=30, ha="right")
            plt.tight_layout()
            plot_path = os.path.join(OUTPUT_DIR, f"{dataset_name}_{attention_mode}_hybrid_feature_{metric}.png")
            plt.savefig(plot_path, dpi=180, bbox_inches="tight")
            plt.show()

    best_rows = agg_df.sort_values(["Dataset", "AttentionMode", metric]).groupby(["Dataset", "AttentionMode"], as_index=False).first()
    print(f"Best config by {metric}:")
    display(best_rows[["Dataset", "AttentionMode", "HybridConfig", metric, "MAE"] if "MAE" in best_rows.columns else ["Dataset", "AttentionMode", "HybridConfig", metric]])
# Out:
# Best config by MSE:
#   Dataset AttentionMode      HybridConfig       MSE       MAE
# 0   ETTh1          dual  ResidualFallback  0.371484  0.396899
# 1   ETTh1      original    CombinedSparse  0.367758  0.393049

# %%
print("Packing logs, checkpoints, plots, and CSV results...")
archive_path = shutil.make_archive("/kaggle/working/SimpleTM_HybridFeatureAblation_Results", "zip", OUTPUT_DIR)
print(f"DONE. Download this archive from the Kaggle Output pane: {archive_path}")
# Out:
# Packing logs, checkpoints, plots, and CSV results...
# DONE. Download this archive from the Kaggle Output pane: /kaggle/working/SimpleTM_HybridFeatureAblation_Results.zip
