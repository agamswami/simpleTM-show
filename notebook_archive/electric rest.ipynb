# %% [markdown]
# # SimpleTMG - electric rest

# %%
# !pip install PyWavelets gdown --quiet
import os
import json
import shutil
import subprocess
import pandas as pd
import torch

print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
# Out:
# PyTorch version: 2.10.0+cu128
# CUDA available: True
# GPU: Tesla T4

# %%
REPO_URL = "https://github.com/agamswami/simpleTM-show"
REPO_DIR = "/kaggle/working/SimpleTM"

if not os.path.exists(REPO_DIR):
    # !git clone {REPO_URL} {REPO_DIR}

os.chdir(REPO_DIR)
print(f"Working directory: {os.getcwd()}")
# !sed -i 's/np\.Inf/np.inf/g' utils/tools.py
# Out:
# Cloning into '/kaggle/working/SimpleTM'...
# remote: Enumerating objects: 245, done.
# remote: Counting objects: 100% (245/245), done.
# remote: Compressing objects: 100% (138/138), done.
# remote: Total 245 (delta 115), reused 220 (delta 90), pack-reused 0 (from 0)
# Receiving objects: 100% (245/245), 25.93 MiB | 37.30 MiB/s, done.
# Resolving deltas: 100% (115/115), done.
# Working directory: /kaggle/working/SimpleTM

# %%
FILE_ID = "1JOgmL2ntyxKg6eB132ytCbVZumiHnDLR"
OUTPUT_PATH = "/kaggle/working/dataset.zip"
DATASET_DIR = "./dataset"

if not os.path.exists(DATASET_DIR):
    # !gdown https://drive.google.com/uc?id={FILE_ID} -O {OUTPUT_PATH}
    import zipfile
    os.makedirs(DATASET_DIR, exist_ok=True)
    with zipfile.ZipFile(OUTPUT_PATH, 'r') as zip_ref:
        zip_ref.extractall(DATASET_DIR)
    print("Dataset extracted successfully.")
else:
    print("Dataset already exists.")

for root, dirs, files in os.walk(DATASET_DIR):
    level = root.replace(DATASET_DIR, '').count(os.sep)
    indent = ' ' * 2 * level
    print(f'{indent}{os.path.basename(root)}/')
    subindent = ' ' * 2 * (level + 1)
    for file in files[:10]:
        print(f'{subindent}{file}')
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1JOgmL2ntyxKg6eB132ytCbVZumiHnDLR
# From (redirected): https://drive.google.com/uc?id=1JOgmL2ntyxKg6eB132ytCbVZumiHnDLR&confirm=t&uuid=6849ff08-7962-4246-be01-fddc0cc4f777
# To: /kaggle/working/dataset.zip
# 100%|████████████████████████████████████████| 172M/172M [00:02<00:00, 73.7MB/s]
# Dataset extracted successfully.
# dataset/
#   SimpleTM_datasets/
#     .DS_Store
#     weather/
#       weather.csv
#     Solar/
#       solar_AL.txt
#     smartbuilding/
#       smart.csv
#     PEMS/
#       PEMS03.npz
#       PEMS04.npz
#       PEMS08.npz
#       PEMS07.npz
#     ETT-small/
#       ETTm2.csv
#       ETTh2.csv
#       ETTm1.csv
#       ETTh1.csv
#     electricity/
#       electricity.csv
#       .DS_Store
#     traffic/
#       .DS_Store
#       traffic.csv
#   __MACOSX/
#     ._SimpleTM_datasets
#     SimpleTM_datasets/
#       ._Solar
#       ._.DS_Store
#       ._weather
#       ._electricity
#       ._PEMS
#       ._ETT-small
#       ._traffic
#       weather/
#         ._weather.csv
#       Solar/
#         ._solar_AL.txt
#       PEMS/
#         ._PEMS07.npz
#         ._PEMS08.npz
#         ._PEMS04.npz
#         ._PEMS03.npz
#       ETT-small/
#         ._ETTm2.csv
#         ._ETTm1.csv
#         ._ETTh2.csv
#         ._ETTh1.csv
#       electricity/
#         ._.DS_Store
#         ._electricity.csv
#       traffic/
#         ._traffic.csv
#         ._.DS_Store

# %%
SELECTED_DATASETS = None
# Example: SELECTED_DATASETS = ["ETTh1", "ETTm1", "smartbuilding"]

all_datasets = [
    # Official SimpleTM paper script settings for pred_len=96
    # {"name": "ETTh1", "data": "ETTh1", "root": "./dataset/SimpleTM_datasets/ETT-small", "path": "ETTh1.csv", "enc_in": 7, "d_model": 32, "d_ff": 32, "e_layers": 1, "wv": "db1", "m": 3, "alpha": 0.3, "learning_rate": 0.02, "batch_size": 256, "train_epochs": 10, "patience": 3, "use_norm": 1, "lradj": "TST", "freq": "h", "itr": 3, "l1_weight": 0.0005},
    # {"name": "ETTh2", "data": "ETTh2", "root": "./dataset/SimpleTM_datasets/ETT-small", "path": "ETTh2.csv", "enc_in": 7, "d_model": 32, "d_ff": 32, "e_layers": 1, "wv": "bior3.1", "m": 1, "alpha": 0.1, "learning_rate": 0.006, "batch_size": 256, "train_epochs": 10, "patience": 3, "use_norm": 1, "lradj": "TST", "freq": "h", "itr": 3, "l1_weight": 0.0005},
    # {"name": "ETTm1", "data": "ETTm1", "root": "./dataset/SimpleTM_datasets/ETT-small", "path": "ETTm1.csv", "enc_in": 7, "d_model": 32, "d_ff": 32, "e_layers": 1, "wv": "db1", "m": 3, "alpha": 0.1, "learning_rate": 0.02, "batch_size": 256, "train_epochs": 10, "patience": 3, "use_norm": 1, "lradj": "TST", "freq": "t", "itr": 3, "l1_weight": 0.005},
    # {"name": "ETTm2", "data": "ETTm2", "root": "./dataset/SimpleTM_datasets/ETT-small", "path": "ETTm2.csv", "enc_in": 7, "d_model": 32, "d_ff": 32, "e_layers": 1, "wv": "bior3.1", "m": 3, "alpha": 0.3, "learning_rate": 0.006, "batch_size": 256, "train_epochs": 10, "patience": 3, "use_norm": 1, "lradj": "TST", "freq": "t", "itr": 3, "l1_weight": 0.0005},
    # {"name": "weather", "data": "custom", "root": "./dataset/SimpleTM_datasets/weather", "path": "weather.csv", "enc_in": 21, "d_model": 32, "d_ff": 32, "e_layers": 4, "wv": "db4", "m": 3, "alpha": 0.3, "learning_rate": 0.01, "batch_size": 256, "train_epochs": 10, "patience": 3, "use_norm": 1, "lradj": "TST", "freq": "h", "itr": 3, "l1_weight": 5e-05},
    {"name": "electricity", "data": "custom", "root": "./dataset/SimpleTM_datasets/electricity", "path": "electricity.csv", "enc_in": 321, "d_model": 256, "d_ff": 1024, "e_layers": 1, "wv": "db1", "m": 3, "alpha": 0.0, "learning_rate": 0.01, "batch_size": 256, "train_epochs": 10, "patience": 3, "use_norm": 1, "lradj": "TST", "freq": "h", "itr": 1, "l1_weight": 0.0},
    # {"name": "traffic", "data": "custom", "root": "./dataset/SimpleTM_datasets/traffic", "path": "traffic.csv", "enc_in": 862, "d_model": 512, "d_ff": 1024, "e_layers": 2, "wv": "db1", "m": 3, "alpha": 0.1, "learning_rate": 0.003, "batch_size": 24, "train_epochs": 10, "patience": 3, "use_norm": 1, "lradj": "TST", "freq": "h", "itr": 1, "l1_weight": 0.0},
    # {"name": "Solar", "data": "Solar", "root": "./dataset/SimpleTM_datasets/Solar", "path": "solar_AL.txt", "enc_in": 137, "d_model": 128, "d_ff": 256, "e_layers": 1, "wv": "db8", "m": 3, "alpha": 0.0, "learning_rate": 0.01, "batch_size": 256, "train_epochs": 10, "patience": 3, "use_norm": 0, "lradj": "TST", "freq": "h", "itr": 3, "l1_weight": 0.005},
    # {"name": "PEMS03", "data": "PEMS", "root": "./dataset/SimpleTM_datasets/PEMS", "path": "PEMS03.npz", "enc_in": 358, "d_model": 256, "d_ff": 1024, "e_layers": 1, "wv": "bior3.1", "m": 3, "alpha": 0.1, "learning_rate": 0.002, "batch_size": 16, "train_epochs": 20, "patience": 10, "use_norm": 0, "lradj": "TST", "freq": "h", "itr": 3, "l1_weight": 0.005},
    # {"name": "PEMS04", "data": "PEMS", "root": "./dataset/SimpleTM_datasets/PEMS", "path": "PEMS04.npz", "enc_in": 307, "d_model": 256, "d_ff": 1024, "e_layers": 1, "wv": "bior3.1", "m": 3, "alpha": 0.1, "learning_rate": 0.002, "batch_size": 16, "train_epochs": 20, "patience": 10, "use_norm": 0, "lradj": "TST", "freq": "h", "itr": 3, "l1_weight": 5e-05},
    # {"name": "PEMS07", "data": "PEMS", "root": "./dataset/SimpleTM_datasets/PEMS", "path": "PEMS07.npz", "enc_in": 883, "d_model": 256, "d_ff": 512, "e_layers": 1, "wv": "db1", "m": 3, "alpha": 0.1, "learning_rate": 0.002, "batch_size": 16, "train_epochs": 20, "patience": 10, "use_norm": 0, "lradj": "TST", "freq": "h", "itr": 3, "l1_weight": 5e-05},
    # {"name": "PEMS08", "data": "PEMS", "root": "./dataset/SimpleTM_datasets/PEMS", "path": "PEMS08.npz", "enc_in": 170, "d_model": 256, "d_ff": 1024, "e_layers": 1, "wv": "db12", "m": 3, "alpha": 0.0, "learning_rate": 0.001, "batch_size": 16, "train_epochs": 20, "patience": 10, "use_norm": 0, "lradj": "TST", "freq": "h", "itr": 3, "l1_weight": 0.0},

    # No official script exists for smartbuilding, so use one fixed recipe for every variant on this dataset.
    # {"name": "smartbuilding", "data": "custom", "root": "./dataset/SimpleTM_datasets/smartbuilding", "path": "smart.csv", "enc_in": 37, "d_model": 64, "d_ff": 128, "e_layers": 1, "wv": "db4", "m": 3, "alpha": 0.3, "learning_rate": 0.003, "batch_size": 64, "train_epochs": 20, "patience": 5, "use_norm": 1, "lradj": "TST", "freq": "h", "itr": 3, "l1_weight": 5e-05, "target": "Floor_Total(kW)"},
]

experiments = [
    {"tag": "SWT_original", "model": "SimpleTM_SWT", "attention_mode": "original"},
    {"tag": "SWT_dual", "model": "SimpleTM_SWT", "attention_mode": "dual"},
    {"tag": "FFT_original", "model": "SimpleTM_FFT", "attention_mode": "original"},
    {"tag": "FFT_dual", "model": "SimpleTM_FFT", "attention_mode": "dual"},
    {"tag": "Conv_original", "model": "SimpleTM_Conv", "attention_mode": "original"},
    {"tag": "Conv_dual", "model": "SimpleTM_Conv", "attention_mode": "dual"},
    # {"tag": "Hybrid_original", "model": "SimpleTM_Hybrid", "attention_mode": "original"},
    # {"tag": "Hybrid_dual", "model": "SimpleTM_Hybrid", "attention_mode": "dual"},
]

if SELECTED_DATASETS is not None:
    datasets = [ds for ds in all_datasets if ds["name"] in SELECTED_DATASETS]
else:
    datasets = all_datasets

print("Datasets selected:")
for ds in datasets:
    print(f"- {ds['name']}: e_layers={ds['e_layers']}, d_model={ds['d_model']}, d_ff={ds['d_ff']}, lr={ds['learning_rate']}, batch={ds['batch_size']}, itr={ds['itr']}, wv={ds['wv']}, m={ds['m']}, alpha={ds['alpha']}, l1={ds['l1_weight']}")

print("\nExperiments selected:")
for exp in experiments:
    print(f"- {exp['tag']}")

OUTPUT_DIR = "/kaggle/working/SimpleTM_Paper96_AllVariants_Results"
if os.path.exists(OUTPUT_DIR):
    shutil.rmtree(OUTPUT_DIR)
os.makedirs(OUTPUT_DIR, exist_ok=True)

if os.path.exists('./checkpoints'):
    shutil.rmtree('./checkpoints')
if os.path.exists('result_long_term_forecast.txt'):
    os.remove('result_long_term_forecast.txt')
# Out:
# Datasets selected:
# - electricity: e_layers=1, d_model=256, d_ff=1024, lr=0.01, batch=256, itr=1, wv=db1, m=3, alpha=0.0, l1=0.0
#
# Experiments selected:
# - SWT_original
# - SWT_dual
# - FFT_original
# - FFT_dual
# - Conv_original
# - Conv_dual

# %%
for ds in datasets:
    print("\n" + "=" * 100)
    print(f"DATASET: {ds['name']} | variates={ds['enc_in']} | official_pred96_recipe")
    print("=" * 100 + "\n")

    for exp in experiments:
        print(f">>> Training {exp['tag']} on {ds['name']} <<<\n")
        unique_model_id = f"{ds['name']}_{exp['model']}_{exp['attention_mode']}"

        cmd = [
            "python", "-u", "run.py",
            "--is_training", "1",
            "--model", exp["model"],
            "--attention_mode", exp["attention_mode"],
            "--model_id", unique_model_id,
            "--data", ds["data"],
            "--root_path", ds["root"],
            "--data_path", ds["path"],
            "--features", "M",
            "--freq", ds["freq"],
            "--seq_len", "96",
            "--pred_len", "96",
            "--e_layers", str(ds["e_layers"]),
            "--d_model", str(ds["d_model"]),
            "--d_ff", str(ds["d_ff"]),
            "--enc_in", str(ds["enc_in"]),
            "--dec_in", str(ds["enc_in"]),
            "--c_out", str(ds["enc_in"]),
            "--wv", ds["wv"],
            "--m", str(ds["m"]),
            "--alpha", str(ds["alpha"]),
            "--l1_weight", str(ds["l1_weight"]),
            "--learning_rate", str(ds["learning_rate"]),
            "--batch_size", str(ds["batch_size"]),
            "--train_epochs", str(ds["train_epochs"]),
            "--patience", str(ds["patience"]),
            "--itr", str(ds["itr"]),
            "--num_workers", "2",
            "--lradj", ds["lradj"],
            "--use_norm", str(ds["use_norm"]),
            "--checkpoints", f"{OUTPUT_DIR}/checkpoints/",
            "--fix_seed", "2025",
            "--des", "Paper96",
        ]

        if "conv_kernel_sizes" in ds:
            cmd.extend(["--conv_kernel_sizes", ds["conv_kernel_sizes"]])

        if "target" in ds:
            cmd.extend(["--target", ds["target"]])

        process = subprocess.Popen(
            cmd,
            stdout=subprocess.PIPE,
            stderr=subprocess.STDOUT,
            text=True,
        )
        for line in process.stdout:
            print(line, end="")
        process.wait()

        if process.returncode == 0:
            print(f"\nSUCCESS: Finished {exp['tag']} on {ds['name']}\n")
        else:
            raise RuntimeError(f"Run failed for {ds['name']} | {exp['tag']} with exit code {process.returncode}")

print("\nGathering generated PDF plots...")
if os.path.exists('./checkpoints'):
    for root_dir, dirs, files in os.walk('./checkpoints'):
        for file in files:
            if file.endswith('.pdf') or file.endswith('.png'):
                folder_name = os.path.basename(root_dir)
                source_path = os.path.join(root_dir, file)
                target_plot_dir = os.path.join(OUTPUT_DIR, 'plots', folder_name)
                os.makedirs(target_plot_dir, exist_ok=True)
                shutil.copy(source_path, os.path.join(target_plot_dir, file))
    print(f"Copied PDF plots to {OUTPUT_DIR}/plots/")

if os.path.exists('result_long_term_forecast.txt'):
    shutil.copy('result_long_term_forecast.txt', os.path.join(OUTPUT_DIR, 'result_long_term_forecast.txt'))
    print("Copied metric text results to output directory.")
# Out:
# ====================================================================================================
# DATASET: electricity | variates=321 | official_pred96_recipe
# ====================================================================================================
#
# >>> Training SWT_original on electricity <<<
#
# Args in experiment:
# Namespace(is_training=1, model_id='electricity_SimpleTM_SWT_original', model='SimpleTM_SWT', data='custom', root_path='./dataset/SimpleTM_datasets/electricity', data_path='electricity.csv', features='M', target='OT', freq='h', checkpoints='/kaggle/working/SimpleTM_Paper96_AllVariants_Results/checkpoints/', seq_len=96, label_len=0, pred_len=96, enc_in=321, dec_in=321, c_out=321, n_heads=8, d_layers=1, moving_avg=25, factor=1, distil=True, dropout=0.1, geomattn_dropout=0.5, embed='timeF', activation='gelu', do_predict=False, num_workers=2, itr=1, train_epochs=10, batch_size=256, patience=3, learning_rate=0.01, des='Paper96', loss='MSE', lradj='TST', pct_start=0.2, use_amp=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', exp_name='MTSF', channel_independence=False, inverse=False, class_strategy='projection', target_root_path='./data/electricity/', target_data_path='electricity.csv', efficient_training=False, use_norm=1, partial_start_index=0, requires_grad=True, wv='db1', m=3, kernel_size=None, conv_kernel_sizes=None, alpha=0.0, l1_weight=0.0, d_model=256, d_ff=1024, e_layers=1, compile=False, output_attention=False, attention_mode='original', fix_seed=2025)
# Use GPU: cuda:0
# Total trainable parameters: 842344
# Memory usage for trainable parameters: 3.21 MB
# Static memory footprint (allocated): 3.22 MB
# Static memory footprint (reserved): 4.00 MB
# >>>>>>>start training : electricity_SimpleTM_SWT_original_SimpleTM_SWT_original_custom_96_96_256_1024_1_db1_None_None_3_0.0_0.0_0.01_TST_256_2025_1_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 18221
# val 2537
# test 5165
# 	iters: 30, epoch: 1 | loss: 0.2732182
# 	speed: 1.0192s/iter; left time: 694.0942s
# 	iters: 60, epoch: 1 | loss: 0.2225786
# 	speed: 0.9798s/iter; left time: 637.8305s
# Epoch: 1 cost time: 71.72820782661438
# Epoch: 1, Steps: 71 | Train Loss: 0.3156474 Vali Loss: 0.1825091 Test Loss: 0.2016231
# Validation loss decreased (inf --> 0.182509).  Saving model ...
# Updating learning rate to 0.005253472811420154
# 	iters: 30, epoch: 2 | loss: 0.3261985
# 	speed: 1.8039s/iter; left time: 1100.3856s
# 	iters: 60, epoch: 2 | loss: 0.3680193
# 	speed: 1.0592s/iter; left time: 614.3596s
# Epoch: 2 cost time: 75.35740089416504
# Epoch: 2, Steps: 71 | Train Loss: 0.3661000 Vali Loss: 0.2848101 Test Loss: 0.3118095
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 0.009999923521345575
# 	iters: 30, epoch: 3 | loss: 0.2749160
# 	speed: 1.9158s/iter; left time: 1032.6013s
# 	iters: 60, epoch: 3 | loss: 0.2729221
# 	speed: 1.0724s/iter; left time: 545.8420s
# Epoch: 3 cost time: 77.23435187339783
# Epoch: 3, Steps: 71 | Train Loss: 0.2840507 Vali Loss: 0.2290933 Test Loss: 0.2532758
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 0.009608745565568389
# 	iters: 30, epoch: 4 | loss: 0.2486500
# 	speed: 1.9316s/iter; left time: 904.0063s
# 	iters: 60, epoch: 4 | loss: 0.2478475
# 	speed: 1.0704s/iter; left time: 468.8450s
# Epoch: 4 cost time: 77.17216348648071
# Epoch: 4, Steps: 71 | Train Loss: 0.2526329 Vali Loss: 0.2114194 Test Loss: 0.2340590
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : electricity_SimpleTM_SWT_original_SimpleTM_SWT_original_custom_96_96_256_1024_1_db1_None_None_3_0.0_0.0_0.01_TST_256_2025_1_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 5165
# test shape: (20, 256, 96, 321) (20, 256, 96, 321)
# test shape: (5120, 96, 321) (5120, 96, 321)
# Collected 16 examples for combined_prediction_examples.png
# mse:0.20162376761436462, mae:0.2862529158592224
# rmse:0.44902536273002625, mape:0.507783830165863, mspe:462698.4375
# rse:0.4466225206851959, corr:45.39628601074219, smape:0.5456416010856628, wape:0.3450276553630829, r2:0.8005282878875732
#
# SUCCESS: Finished SWT_original on electricity
#
# >>> Training SWT_dual on electricity <<<
#
# Args in experiment:
# Namespace(is_training=1, model_id='electricity_SimpleTM_SWT_dual', model='SimpleTM_SWT', data='custom', root_path='./dataset/SimpleTM_datasets/electricity', data_path='electricity.csv', features='M', target='OT', freq='h', checkpoints='/kaggle/working/SimpleTM_Paper96_AllVariants_Results/checkpoints/', seq_len=96, label_len=0, pred_len=96, enc_in=321, dec_in=321, c_out=321, n_heads=8, d_layers=1, moving_avg=25, factor=1, distil=True, dropout=0.1, geomattn_dropout=0.5, embed='timeF', activation='gelu', do_predict=False, num_workers=2, itr=1, train_epochs=10, batch_size=256, patience=3, learning_rate=0.01, des='Paper96', loss='MSE', lradj='TST', pct_start=0.2, use_amp=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', exp_name='MTSF', channel_independence=False, inverse=False, class_strategy='projection', target_root_path='./data/electricity/', target_data_path='electricity.csv', efficient_training=False, use_norm=1, partial_start_index=0, requires_grad=True, wv='db1', m=3, kernel_size=None, conv_kernel_sizes=None, alpha=0.0, l1_weight=0.0, d_model=256, d_ff=1024, e_layers=1, compile=False, output_attention=False, attention_mode='dual', fix_seed=2025)
# Use GPU: cuda:0
# Total trainable parameters: 1387377
# Memory usage for trainable parameters: 5.29 MB
# Static memory footprint (allocated): 5.30 MB
# Static memory footprint (reserved): 6.00 MB
# >>>>>>>start training : electricity_SimpleTM_SWT_dual_SimpleTM_SWT_dual_custom_96_96_256_1024_1_db1_None_None_3_0.0_0.0_0.01_TST_256_2025_1_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 18221
# val 2537
# test 5165
# 	iters: 30, epoch: 1 | loss: 0.2774523
# 	speed: 1.2816s/iter; left time: 872.7984s
# 	iters: 60, epoch: 1 | loss: 0.2400238
# 	speed: 1.2499s/iter; left time: 813.6685s
# Epoch: 1 cost time: 90.31856918334961
# Epoch: 1, Steps: 71 | Train Loss: 0.3167876 Vali Loss: 0.1809614 Test Loss: 0.2004950
# Validation loss decreased (inf --> 0.180961).  Saving model ...
# Updating learning rate to 0.005253472811420154
# 	iters: 30, epoch: 2 | loss: 0
electricity <<<
#
# Args in experiment:
# Namespace(is_training=1, model_id='electricity_SimpleTM_FFT_dual', model='SimpleTM_FFT', data='custom', root_path='./dataset/SimpleTM_datasets/electricity', data_path='electricity.csv', features='M', target='OT', freq='h', checkpoints='/kaggle/working/SimpleTM_Paper96_AllVariants_Results/checkpoints/', seq_len=96, label_len=0, pred_len=96, enc_in=321, dec_in=321, c_out=321, n_heads=8, d_layers=1, moving_avg=25, factor=1, distil=True, dropout=0.1, geomattn_dropout=0.5, embed='timeF', activation='gelu', do_predict=False, num_workers=2, itr=1, train_epochs=10, batch_size=256, patience=3, learning_rate=0.01, des='Paper96', loss='MSE', lradj='TST', pct_start=0.2, use_amp=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', exp_name='MTSF', channel_independence=False, inverse=False, class_strategy='projection', target_root_path='./data/electricity/', target_data_path='electricity.csv', efficient_training=False, use_norm=1, partial_start_index=0, requires_grad=True, wv='db1', m=3, kernel_size=None, conv_kernel_sizes=None, alpha=0.0, l1_weight=0.0, d_model=256, d_ff=1024, e_layers=1, compile=False, output_attention=False, attention_mode='dual', fix_seed=2025)
# Use GPU: cuda:0
# Total trainable parameters: 1384817
# Memory usage for trainable parameters: 5.28 MB
# Static memory footprint (allocated): 5.29 MB
# Static memory footprint (reserved): 6.00 MB
# >>>>>>>start training : electricity_SimpleTM_FFT_dual_SimpleTM_FFT_dual_custom_96_96_256_1024_1_db1_None_None_3_0.0_0.0_0.01_TST_256_2025_1_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 18221
# val 2537
# test 5165
# 	iters: 30, epoch: 1 | loss: 0.2791025
# 	speed: 1.1670s/iter; left time: 794.7213s
# 	iters: 60, epoch: 1 | loss: 0.2267693
# 	speed: 1.1415s/iter; left time: 743.0872s
# Epoch: 1 cost time: 82.32523727416992
# Epoch: 1, Steps: 71 | Train Loss: 0.3162095 Vali Loss: 0.1822338 Test Loss: 0.2018862
# Validation loss decreased (inf --> 0.182234).  Saving model ...
# Updating learning rate to 0.005253472811420154
# 	iters: 30, epoch: 2 | loss: 0.6682177
# 	speed: 2.0281s/iter; left time: 1237.1271s
# 	iters: 60, epoch: 2 | loss: 0.3792972
# 	speed: 1.1028s/iter; left time: 639.6434s
# Epoch: 2 cost time: 80.34949469566345
# Epoch: 2, Steps: 71 | Train Loss: 0.4628174 Vali Loss: 0.3171158 Test Loss: 0.3451115
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 0.009999923521345575
# 	iters: 30, epoch: 3 | loss: 0.3638212
# 	speed: 2.0113s/iter; left time: 1084.1115s
# 	iters: 60, epoch: 3 | loss: 0.3605247
# 	speed: 1.0932s/iter; left time: 556.4584s
# Epoch: 3 cost time: 78.55584955215454
# Epoch: 3, Steps: 71 | Train Loss: 0.3656631 Vali Loss: 0.3022302 Test Loss: 0.3299621
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 0.009608745565568389
# 	iters: 30, epoch: 4 | loss: 0.3556270
# 	speed: 1.9731s/iter; left time: 923.4095s
# 	iters: 60, epoch: 4 | loss: 0.3177442
# 	speed: 1.0942s/iter; left time: 479.2485s
# Epoch: 4 cost time: 78.29350924491882
# Epoch: 4, Steps: 71 | Train Loss: 0.3360422 Vali Loss: 0.2531359 Test Loss: 0.2815611
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : electricity_SimpleTM_FFT_dual_SimpleTM_FFT_dual_custom_96_96_256_1024_1_db1_None_None_3_0.0_0.0_0.01_TST_256_2025_1_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 5165
# test shape: (20, 256, 96, 321) (20, 256, 96, 321)
# test shape: (5120, 96, 321) (5120, 96, 321)
# Collected 16 examples for combined_prediction_examples.png
# mse:0.20188623666763306, mae:0.28703463077545166
# rmse:0.4493175148963928, mape:0.5077611207962036, mspe:732638.375
# rse:0.4469131529331207, corr:45.307952880859375, smape:0.5473673939704895, wape:0.34596988558769226, r2:0.8002686500549316
#
# SUCCESS: Finished FFT_dual on electricity
#
# >>> Training Conv_original on electricity <<<
#
# Args in experiment:
# Namespace(is_training=1, model_id='electricity_SimpleTM_Conv_original', model='SimpleTM_Conv', data='custom', root_path='./dataset/SimpleTM_datasets/electricity', data_path='electricity.csv', features='M', target='OT', freq='h', checkpoints='/kaggle/working/SimpleTM_Paper96_AllVariants_Results/checkpoints/', seq_len=96, label_len=0, pred_len=96, enc_in=321, dec_in=321, c_out=321, n_heads=8, d_layers=1, moving_avg=25, factor=1, distil=True, dropout=0.1, geomattn_dropout=0.5, embed='timeF', activation='gelu', do_predict=False, num_workers=2, itr=1, train_epochs=10, batch_size=256, patience=3, learning_rate=0.01, des='Paper96', loss='MSE', lradj='TST', pct_start=0.2, use_amp=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', exp_name='MTSF', channel_independence=False, inverse=False, class_strategy='projection', target_root_path='./data/electricity/', target_data_path='electricity.csv', efficient_training=False, use_norm=1, partial_start_index=0, requires_grad=True, wv='db1', m=3, kernel_size=None, conv_kernel_sizes=None, alpha=0.0, l1_weight=0.0, d_model=256, d_ff=1024, e_layers=1, compile=False, output_attention=False, attention_mode='original', fix_seed=2025)
# Use GPU: cuda:0
# Total trainable parameters: 1110522
# Memory usage for trainable parameters: 4.24 MB
# Static memory footprint (allocated): 4.24 MB
# Static memory footprint (reserved): 6.00 MB
# >>>>>>>start training : electricity_SimpleTM_Conv_original_SimpleTM_Conv_original_custom_96_96_256_1024_1_db1_None_None_3_0.0_0.0_0.01_TST_256_2025_1_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 18221
# val 2537
# test 5165
# 	iters: 30, epoch: 1 | loss: 0.2768241
# 	speed: 1.1369s/iter; left time: 774.2595s
# 	iters: 60, epoch: 1 | loss: 0.2264724
# 	speed: 1.1151s/iter; left time: 725.8983s
# Epoch: 1 cost time: 80.27880334854126
# Epoch: 1, Steps: 71 | Train Loss: 0.3179789 Vali Loss: 0.1804714 Test Loss: 0.2001165
# Validation loss decreased (inf --> 0.180471).  Saving model ...
# Updating learning rate to 0.005253472811420154
# 	iters: 30, epoch: 2 | loss: 0.1931729
# 	speed: 1.9476s/iter; left time: 1188.0534s
# 	iters: 60, epoch: 2 | loss: 0.7055815
# 	speed: 1.1083s/iter; left time: 642.8374s
# Epoch: 2 cost time: 79.74045872688293
# Epoch: 2, Steps: 71 | Train Loss: 0.4245992 Vali Loss: 0.3815061 Test Loss: 0.4022864
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 0.009999923521345575
# 	iters: 30, epoch: 3 | loss: 0.3675617
# 	speed: 1.9239s/iter; left time: 1037.0078s
# 	iters: 60, epoch: 3 | loss: 0.3471511
# 	speed: 1.0723s/iter; left time: 545.7824s
# Epoch: 3 cost time: 77.25399255752563
# Epoch: 3, Steps: 71 | Train Loss: 0.3694906 Vali Loss: 0.2903670 Test Loss: 0.3174100
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 0.009608745565568389
# 	iters: 30, epoch: 4 | loss: 0.3288073
# 	speed: 1.9174s/iter; left time: 897.3564s
# 	iters: 60, epoch: 4 | loss: 0.3142566
# 	speed: 1.0738s/iter; left time: 470.3413s
# Epoch: 4 cost time: 77.52645206451416
# Epoch: 4, Steps: 71 | Train Loss: 0.3239043 Vali Loss: 0.2715042 Test Loss: 0.3026577
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : electricity_SimpleTM_Conv_original_SimpleTM_Conv_original_custom_96_96_256_1024_1_db1_None_None_3_0.0_0.0_0.01_TST_256_2025_1_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 5165
# test shape: (20, 256, 96, 321) (20, 256, 96, 321)
# test shape: (5120, 96, 321) (5120, 96, 321)
# Collected 16 examples for combined_prediction_examples.png
# mse:0.2001163512468338, mae:0.28925713896751404
# rmse:0.447343647480011, mape:0.5147531032562256, mspe:648742.625
# rse:0.44494983553886414, corr:45.40629196166992, smape:0.5505813360214233, wape:0.34864869713783264, r2:0.8020195960998535
#
# SUCCESS: Finished Conv_original on electricity
#
# >>> Training Conv_dual on electricity <<<
#
# Args in experiment:
# Namespace(is_training=1, model_id='electricity_SimpleTM_Conv_dual', model='SimpleTM_Conv', data='custom', root_path='./dataset/SimpleTM_datasets/electricity', data_path='electricity.csv', features='M', target='OT', freq='h', checkpoints='/kaggle/working/SimpleTM_Paper96_AllVariants_Results/checkpoints/', seq_len=96, label_len=0, pred_len=96, enc_in=321, dec_in=321, c_out=321, n_heads=8, d_layers=1, moving_avg=25, factor=1, distil=True, dropout=0.1, geomattn_dropout=0.5, embed='timeF', activation='gelu', do_predict=False, num_workers=2, itr=1, train_epochs=10, batch_size=256, patience=3, learning_rate=0.01, des='Paper96', loss='MSE', lradj='TST', pct_start=0.2, use_amp=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', exp_name='MTSF', channel_independence=False, inverse=False, class_strategy='projection', target_root_path='./data/electricity/', target_data_path='electricity.csv', efficient_training=False, use_norm=1, partial_start_index=0, requires_grad=True, wv='db1', m=3, kernel_size=None, conv_kernel_sizes=None, alpha=0.0, l1_weight=0.0, d_model=256, d_ff=1024, e_layers=1, compile=False, output_attention=False, attention_mode='dual', fix_seed=2025)
# Use GPU: cuda:0
# Total trainable parameters: 1655555
# Memory usage for trainable parameters: 6.32 MB
# Static memory footprint (allocated): 6.32 MB
# Static memory footprint (reserved): 8.00 MB
# >>>>>>>start training : electricity_SimpleTM_Conv_dual_SimpleTM_Conv_dual_custom_96_96_256_1024_1_db1_None_None_3_0.0_0.0_0.01_TST_256_2025_1_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 18221
# val 2537
# test 5165
# 	iters: 30, epoch: 1 | loss: 0.2706762
# 	speed: 1.2918s/iter; left time: 879.7380s
# 	iters: 60, epoch: 1 | loss: 0.2325954
# 	speed: 1.2455s/iter; left time: 810.8330s
# Epoch: 1 cost time: 90.46796560287476
# Epoch: 1, Steps: 71 | Train Loss: 0.3122079 Vali Loss: 0.1781639 Test Loss: 0.1985524
# Validation loss decreased (inf --> 0.178164).  Saving model ...
# Updating learning rate to 0.005253472811420154
# 	iters: 30, epoch: 2 | loss: 0.1850181
# 	speed: 2.1793s/iter; left time: 1329.3605s
# 	iters: 60, epoch: 2 | loss: 0.1672775
# 	speed: 1.2324s/iter; left time: 714.7945s
# Epoch: 2 cost time: 89.0816912651062
# Epoch: 2, Steps: 71 | Train Loss: 0.1879214 Vali Loss: 0.1420044 Test Loss: 0.1619710
# Validation loss decreased (0.178164 --> 0.142004).  Saving model ...
# Updating learning rate to 0.009999923521345575
# 	iters: 30, epoch: 3 | loss: 0.1586832
# 	speed: 2.2130s/iter; left time: 1192.8192s
# 	iters: 60, epoch: 3 | loss: 0.1559694
# 	speed: 1.2374s/iter; left time: 629.8247s
# Epoch: 3 cost time: 88.987313747406
# Epoch: 3, Steps: 71 | Train Loss: 0.1604965 Vali Loss: 0.1298696 Test Loss: 0.1497825
# Validation loss decreased (0.142004 --> 0.129870).  Saving model ...
# Updating learning rate to 0.009608745565568389
# 	iters: 30, epoch: 4 | loss: 0.1489554
# 	speed: 2.2501s/iter; left time: 1053.0267s
# 	iters: 60, epoch: 4 | loss: 0.1603545
dual_custom_96_96_256_1024_1_db1_None_None_3_0.0_0.0_0.01_TST_256_2025_1_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 5165
# test shape: (20, 256, 96, 321) (20, 256, 96, 321)
# test shape: (5120, 96, 321) (5120, 96, 321)
# Collected 16 examples for combined_prediction_examples.png
# mse:0.13940201699733734, mae:0.2353534698486328
# rmse:0.3733657896518707, mape:0.44684746861457825, mspe:597600.6875
# rse:0.37136784195899963, corr:46.30696105957031, smape:0.46973127126693726, wape:0.28367727994918823, r2:0.8620859384536743
#
# SUCCESS: Finished Conv_dual on electricity
#
#
# Gathering generated PDF plots...
# Copied PDF plots to /kaggle/working/SimpleTM_Paper96_AllVariants_Results/plots/
# Copied metric text results to output directory.

# %%
import re

results_file = os.path.join(OUTPUT_DIR, 'result_long_term_forecast.txt')
metric_order = ['MSE', 'MAE', 'RMSE', 'MAPE', 'WAPE', 'R2']
pattern = re.compile(r'^(?P<dataset>[^_]+)_(?P<model>SimpleTM_(?:SWT|FFT|Conv|Hybrid))_(?P<attention>original|dual)_')
metric_pattern = re.compile(r'([a-zA-Z0-9_]+):([^,]+)')

if os.path.exists(results_file):
    with open(results_file, 'r', encoding='utf-8') as f:
        content = f.read().strip()

    entries = content.split('\n\n') if content else []
    rows = []
    for entry in entries:
        lines = [line.strip() for line in entry.splitlines() if line.strip()]
        if len(lines) < 2:
            continue
        setting = lines[0]
        metrics_line = lines[-1]
        match = pattern.search(setting)
        if not match:
            continue

        model_type = match.group('model')
        attention_mode = match.group('attention')
        tokenization = model_type.replace('SimpleTM_', '')
        row = {
            'Dataset': match.group('dataset'),
            'Model': model_type,
            'AttentionMode': attention_mode,
            'Variant': f'{tokenization}_{attention_mode}',
            'Setting': setting,
        }
        for metric_name, value in metric_pattern.findall(metrics_line):
            try:
                row[metric_name.upper()] = float(value.strip())
            except ValueError:
                pass
        rows.append(row)

    if rows:
        raw_df = pd.DataFrame(rows).sort_values(['Dataset', 'Model', 'AttentionMode', 'Setting']).reset_index(drop=True)
        value_columns = [col for col in metric_order if col in raw_df.columns]
        raw_columns = ['Dataset', 'Model', 'AttentionMode', 'Variant', 'Setting'] + value_columns
        raw_df = raw_df[raw_columns]
        print('Raw runs:')
        print(raw_df.to_string(index=False))

        raw_path = os.path.join(OUTPUT_DIR, 'raw_metrics.csv')
        raw_df.to_csv(raw_path, index=False)

        agg_df = raw_df.groupby(['Dataset', 'Variant'], as_index=False)[value_columns].mean()
        counts_df = raw_df.groupby(['Dataset', 'Variant'], as_index=False).size().rename(columns={'size': 'NumRuns'})
        agg_df = agg_df.merge(counts_df, on=['Dataset', 'Variant'], how='left')
        ordered_columns = ['Dataset', 'Variant'] + value_columns + ['NumRuns']
        agg_df = agg_df[ordered_columns]
        print('\nAveraged results across repeated itr runs:')
        print(agg_df.sort_values(['Dataset', 'Variant']).to_string(index=False))

        averaged_path = os.path.join(OUTPUT_DIR, 'averaged_metrics.csv')
        agg_df.to_csv(averaged_path, index=False)

        pivot_df = agg_df.pivot(index='Dataset', columns='Variant', values=value_columns)
        variant_order = ['SWT_original', 'SWT_dual', 'FFT_original', 'FFT_dual', 'Conv_original', 'Conv_dual', 'Hybrid_original', 'Hybrid_dual']
        pivot_df = pivot_df.reindex(columns=variant_order, level=1)
        final_path = os.path.join(OUTPUT_DIR, 'final_metrics.csv')
        pivot_df.to_csv(final_path)

        print(f'\nSaved raw results to: {raw_path}')
        print(f'Saved averaged results to: {averaged_path}')
        print(f'Saved final table to: {final_path}')
    else:
        print('No valid metrics found in result file.')
else:
    print('Result file not found.')
# Out:
# Raw runs:
#     Dataset         Model AttentionMode       Variant                                                                                                                         Setting      MSE      MAE     RMSE     MAPE     WAPE       R2
# electricity SimpleTM_Conv          dual     Conv_dual         electricity_SimpleTM_Conv_dual_SimpleTM_Conv_dual_custom_96_96_256_1024_1_db1_None_None_3_0.0_0.0_0.01_TST_256_2025_1_0 0.139402 0.235353 0.373366 0.446847 0.283677 0.862086
# electricity SimpleTM_Conv      original Conv_original electricity_SimpleTM_Conv_original_SimpleTM_Conv_original_custom_96_96_256_1024_1_db1_None_None_3_0.0_0.0_0.01_TST_256_2025_1_0 0.200116 0.289257 0.447344 0.514753 0.348649 0.802020
# electricity  SimpleTM_FFT          dual      FFT_dual           electricity_SimpleTM_FFT_dual_SimpleTM_FFT_dual_custom_96_96_256_1024_1_db1_None_None_3_0.0_0.0_0.01_TST_256_2025_1_0 0.201886 0.287035 0.449318 0.507761 0.345970 0.800269
# electricity  SimpleTM_FFT      original  FFT_original   electricity_SimpleTM_FFT_original_SimpleTM_FFT_original_custom_96_96_256_1024_1_db1_None_None_3_0.0_0.0_0.01_TST_256_2025_1_0 0.175175 0.262820 0.418540 0.479846 0.316784 0.826694
# electricity  SimpleTM_SWT          dual      SWT_dual           electricity_SimpleTM_SWT_dual_SimpleTM_SWT_dual_custom_96_96_256_1024_1_db1_None_None_3_0.0_0.0_0.01_TST_256_2025_1_0 0.144575 0.238217 0.380230 0.448489 0.287129 0.856968
# electricity  SimpleTM_SWT      original  SWT_original   electricity_SimpleTM_SWT_original_SimpleTM_SWT_original_custom_96_96_256_1024_1_db1_None_None_3_0.0_0.0_0.01_TST_256_2025_1_0 0.201624 0.286253 0.449025 0.507784 0.345028 0.800528
#
# Averaged results across repeated itr runs:
#     Dataset       Variant      MSE      MAE     RMSE     MAPE     WAPE       R2  NumRuns
# electricity     Conv_dual 0.139402 0.235353 0.373366 0.446847 0.283677 0.862086        1
# electricity Conv_original 0.200116 0.289257 0.447344 0.514753 0.348649 0.802020        1
# electricity      FFT_dual 0.201886 0.287035 0.449318 0.507761 0.345970 0.800269        1
# electricity  FFT_original 0.175175 0.262820 0.418540 0.479846 0.316784 0.826694        1
# electricity      SWT_dual 0.144575 0.238217 0.380230 0.448489 0.287129 0.856968        1
# electricity  SWT_original 0.201624 0.286253 0.449025 0.507784 0.345028 0.800528        1
#
# Saved raw results to: /kaggle/working/SimpleTM_Paper96_AllVariants_Results/raw_metrics.csv
# Saved averaged results to: /kaggle/working/SimpleTM_Paper96_AllVariants_Results/averaged_metrics.csv
# Saved final table to: /kaggle/working/SimpleTM_Paper96_AllVariants_Results/final_metrics.csv

# %%
print("Packing logs, weights, plots, and results...")
archive_path = shutil.make_archive('/kaggle/working/SimpleTM_Paper96_AllVariants_Results', 'zip', OUTPUT_DIR)
print(f"\nDONE! Download {archive_path} from the Kaggle Output pane.")
# Out:
# Packing logs, weights, plots, and results...
#
# DONE! Download /kaggle/working/SimpleTM_Paper96_AllVariants_Results.zip from the Kaggle Output pane.
